# %%
from __future__ import print_function
import numpy as np
import pandas as pd
import os, glob2
import requests, json
from lxml import html
from astropy.time import Time
import pickle
from astropy.table import Table
from astropy.io import ascii
import os
import requests
import json
from datetime import datetime
from astropy.cosmology import FlatLambdaCDM
import astropy.units as u
from astropy import constants as const
import sys, getopt, argparse
import re
from time import sleep
from astropy.io import fits
from subprocess import call
from lxml import html
import webbrowser as wb
from urllib.error import HTTPError
import xlsxwriter

# %%
global TOKEN, BASEURL
GETTOKEN = '8e31426a-f04d-4a32-b470-54102e2d568d'      # Fritz API Key
BASEURL = 'https://fritz.science/'                     # Fritz base url

# %%
API_KEY = "54916f1700966b3bd325fc1189763d86512bda1d"     # TNS API Key

# TNS URLs for real uploads
TNS_BASE_URL = "https://www.wis-tns.org/api/"
upload_url = "https://www.wis-tns.org/api/file-upload"
report_url = "https://www.wis-tns.org/api/bulk-report"
reply_url = "https://www.wis-tns.org/api/bulk-report-reply"

# SANDBOX URLs for TNS upload trials
SAND_TNS_BASE_URL = "https://sandbox.wis-tns.org/api/"
SAND_upload_url = "https://sandbox.wis-tns.org/api/file-upload"
SAND_report_url = "https://sandbox.wis-tns.org/api/bulk-report"
SAND_reply_url = "https://sandbox.wis-tns.org/api/bulk-report-reply"

# %%
def api(method, endpoint, data=None):
    ''' Info : Basic API query, takes input the method (eg. GET, POST, etc.), the endpoint (i.e. API url) 
               and additional data for filtering
        Returns : response in json format
        CAUTION! : If the query doesn't go through, try putting the 'data' input in 'data' or 'params' 
                    argument in requests.request call
    '''
    headers = {'Authorization': f'token {GETTOKEN}'}
    response = requests.request(method, endpoint, json=data, headers=headers)
    return response.json()



def get_source_api(ztfname):
    ''' Info : Query a single source, takes input ZTF name
        Returns : all basic data of that source (excludes photometry and spectra, 
                  includes redshift, classification, comments, etc.)
    '''
    url = BASEURL+'api/sources/'+ztfname+'?includeComments=true'
    response = api('GET',url)
    return response['data']    



def get_group_ids(groupnames=['Redshift Completeness Factor', 'Census of the Local Universe Caltech']):
    ''' Info : Query group ids of groups specified
        Input : Name or names of groups in an array []
        Returns : List of group  names and their group ids 
    '''
    
    url = BASEURL+'api/groups'
    headers = {'Authorization': f'token {GETTOKEN}'}
    groupnames = np.atleast_1d(groupnames)
    grpids = []
    for grpname in groupnames:
        response = requests.request('GET',url,params={'name':grpname}, headers=headers).json()
        answer = str(grpname)+' = '+str(response['data'][0]['id'])
        grpids.append(answer)
        
    return grpids



def get_number_of_sources(group_id, date):
    ''' Info : Query number of sources saved in a group after a certain date
        Input : group id, date [yyyy-mm-dd]
        Returns : Number of sources saved after a given date to the specified group
    '''
    
    url = BASEURL+'api/sources?saveSummary=true&group_ids='+group_id+'&savedAfter='+date+'T00:00:00.000001'
    response = api('GET',url)
    return len(response['data']['sources'])



def get_group_sources(group_id, date):
    ''' Info : Query all sources saved in a group after a certain date
        Input : group id, date [yyyy-mm-dd]
        Returns : List of jsons of all sources in group(s)
        Comment : Takes a little time based on the date
    '''
    
    sources = []
    
    for i in range (get_number_of_sources(group_id, date)):
    
        url = BASEURL+'api/sources?saveSummary=true&group_ids='+group_id+'&savedAfter='+date+'T00:00:00.000001'
        response = api('GET',url)
        ztfname = response['data']['sources'][i]['obj_id']
        sources.append(ztfname)
        
    return sources 



def get_total_number_of_sources(group_id):
    ''' Info : Query total number of sources saved in a group
        Input : group id
        Returns : Total number of sources saved in a group
    '''
    
    url = BASEURL+'api/sources?saveSummary=true&group_ids='+group_id
    response = api('GET',url)
    return len(response['data']['sources'])


def get_all_group_sources(group_id):
    ''' Info : Query all sources saved in a group
        Input : group id
        Returns : List of jsons of all sources in group(s)
        Comment : Takes a long time
    '''
    
    sources = []
    
    for i in range (get_number_of_sources(group_id)):
    
        url = BASEURL+'api/sources?saveSummary=true&group_ids='+group_id
        response = api('GET',url)
        ztfname = response['data']['sources'][i]['obj_id']
        sources.append(ztfname)
        
    return sources 


def get_IAUname(ztfname):
    
    ''' Info : Query the TNS name for any source
        Input : ZTFname
        Returns : ATname
    '''
    
    url = BASEURL+'api/alerts_aux/'+ztfname
    response = api('GET',url)
    return response["data"]["cross_matches"]["TNS"]


def get_classification(ztfname):
                        
    ''' Info : Query the classification and classification date for any source
        Input : ZTFname
        Returns : Classification and Classification date
        Comment : You need to choose the classification if there are multiple classifications
    '''
    
    url = BASEURL+'api/sources/'+ztfname+'/classifications'
    response = api('GET',url)
    output = response['data']
    
    if (len(output)< 1):
        classification = "No Classification found"
        classification_date = "None"
    
    if (len(output)==1):
        
        classification = response['data'][0]['classification']
        classification_date = response['data'][0]['created_at'].split('T')[0]
        
    if (len(output) > 1):
        
        classification = []
        classification_date = []
                    
        for i in range (len(output)):
            
            classify = response['data'][i]['classification']  
            classify_date = response['data'][i]['created_at']
                    
            classification.append(classify)
            classification_date.append(classify_date)
                    
        for i in range (len(classification)):
        
            print ((i+1),")", "Classification: ", classification[i],  "\t Classification date:", classification_date[i].split('T')[0])

        user_input = input("Choose classification: ")

        classification = classification[int(user_input)-1]
        classification_date = classification_date[int(user_input)-1].split('T')[0]        
        
    return classification, classification_date


def get_redshift(ztfname):
                    
    ''' Info : Query the redshift for any source
        Input : ZTFname
        Returns : redshift
    '''
    
    url = BASEURL+'api/sources/'+ztfname
    response = api('GET',url)
    
    redshift = response['data']['redshift']
    
    if (redshift == None):
        redshift = "No redshift found"
    
    return redshift


def get_TNS_information(ztfname):
    
    url = BASEURL+'api/sources/'+ztfname
    response = api('GET',url)
        
    IAU = get_IAUname(ztfname)

    if not IAU:
        IAU = "Not reported to TNS"
        
    else:   
        IAU = IAU[0]['name']
              
    clas = get_classification(ztfname)
        
    if clas[1] == 'None':
        clas = "Not classified yet"
        
    else: 
        clas = ('Classification: '+str(clas[0])+','+' Classification date: '+str(clas[1]))
           
    redshift = get_redshift(ztfname)
           
    if redshift == None:
        redshift = "No redshift found"
        
    else:
        redshift = ('redshift:'+str(redshift))        
        
    return ztfname, IAU, clas, redshift

   
def convert_to_jd(date):

    d = Time(date, format='fits')
    dat = d.jd
    return dat


def get_spectrum_api(spectrum_id):
    ''' Info : Query all spectra corresponding to a source, takes input ZTF name
        Returns : list of spectrum jsons
    '''
    url = BASEURL+'api/spectrum/'+str(spectrum_id)
    response = api('GET',url)
    return response


def get_all_spectra_len(ztfname):
    
    url = BASEURL+'api/sources/'+ztfname+'/spectra'
    response = api('GET',url)
    return len(response['data']['spectra'])


def get_all_spectra_id(ztfname):
    ''' Info : Query all spectra corresponding to a source, takes input ZTF name
        Returns : list of spectrum jsons
    '''

    spec_id = []
    
    for i in range (get_all_spectra_len(ztfname)):
    
        url = BASEURL+'api/sources/'+ztfname+'/spectra'
        response = api('GET',url)
        
        specid = response['data']['spectra'][i]['id']
        spec_id.append(specid)
        
    return spec_id


def get_required_spectrum_id(ztfname):
    
    flag = 0
    
    spec = (get_all_spectra_len(ztfname))
    
    name = []
    date = []
    
    if spec == 0:
        
        specid = "No Spectra Found"
        flag = 1
        
    if flag == 0:
        
        spec_id = get_all_spectra_id(ztfname)
        
        for s in range (spec):
            
            url = BASEURL+'api/sources/'+ztfname+'/spectra'
            response = api('GET',url)

            spec_name = response['data']['spectra'][s]['original_file_filename']
            spec_date = response['data']['spectra'][s]['observed_at']
            
            name.append(spec_name)
            date.append(spec_date.split('T')[0])

        print ("Please choose from the following spectra: \n")

        for i in range (len(name)):
            print ((i+1),")", "spectrum name: ", name[i], "spectrum date:", date[i])
            
        wb.open(BASEURL+'source/'+ztfname, new=2) 

        user_input = input("Choose spectrum to upload: ")

        specid = spec_id[int(user_input)-1]

    return specid



def write_ascii_file(ztfname):
    
    specid = get_required_spectrum_id(ztfname)
    
    flag = 0
    
    if (specid == 'No Spectra Found'):
        spectrum_name = 'No Spectra Found'
        print (spectrum_name)
        flag = 1
    
    if flag == 0:
        
        a = get_spectrum_api(specid)

        inst = (a['data']['instrument_name'])
        #print (inst)
    
        if inst == 'SEDM':
        
            header = (a['data']['altdata'])
            path = os.getcwd()

            s = (ztfname+'_'+str(header['OBSDATE'])+'_'+str(inst)+'.ascii')

            with open(path+'/data/'+s,'w') as f:
                f.write(a['data']['original_file_string'])
            f.close()

            #print (s,'\n')
            spectrum_name = s
        
    
        if inst == 'SPRAT':
        
        
            header = (a['data']['altdata'])
            
            path = os.getcwd()

            s = (ztfname+'_'+str(header['OBSDATE'].split('T')[0])+'_'+str(inst)+'.ascii')

            with open(path+'/data/'+s,'w') as f:
                f.write(a['data']['original_file_string'])
            f.close()

            #print (s,'\n')
            spectrum_name = s
            
            
        if inst == 'ALFOSC':
        
            OBSDATE = a['data']['observed_at'].split('T')[0]
            path = os.getcwd()

            s = (ztfname+'_'+str(OBSDATE)+'_'+str(inst)+'.ascii')

            with open(path+'/data/'+s,'w') as f:
                f.write(a['data']['original_file_string'])
            f.close()

            #print (s,'\n')
            spectrum_name = s


        if inst == 'DBSP':
            
            wav = (a['data']['wavelengths'])
            flux = (a['data']['fluxes'])
            err = (a['data']['errors'])
            
            OBSDATE = a['data']['observed_at'].split('T')[0]

            path = os.getcwd()

            s = (ztfname+'_'+str(OBSDATE)+'_'+str(inst)+'.ascii')
            
            if err == None:
                
                with open(path+'/data/'+s,'w') as f:
                
                    for i in range(len(wav)):
                        f.write(str(wav[i])+'\t'+str(flux[i])+'\n')
                f.close()

                #print (s,'\n')
                spectrum_name = s
                
            else:

                with open(path+'/data/'+s,'w') as f:

                    for i in range(len(wav)):
                        f.write(str(wav[i])+'\t'+str(flux[i])+'\t'+str(err[i])+'\n')
                f.close()

                #print (s,'\n')
                spectrum_name = s
            
            
        if inst == 'DIS':

            #obsdate = a['data']['original_file_string'].split('#')[6]
            #a,b = obsdate.split(' ', 1)
            #c,OBSDATE = b.split(' ', 1)
            #OBSDATE = OBSDATE.split('T')[0]
            
            obsdate = a['data']['observed_at']
            OBSDATE = obsdate.split('T')[0]
            
            path = os.getcwd()
            path = path+'/data/'

            s = (ztfname+'_'+str(OBSDATE)+'_'+str(inst)+'.ascii')
            
            a = get_spectrum_api(specid)

            with open(path+s,'w') as f:
                f.write(a['data']['original_file_string'])
            f.close()

            #print (s,'\n')
            spectrum_name = s
            
            
        if inst == 'KAST':

            
            obsdate = a['data']['observed_at']
            OBSDATE = obsdate.split('T')[0]
            
            path = os.getcwd()
            path = path+'/data/'

            s = (ztfname+'_'+str(OBSDATE)+'_'+str(inst)+'.ascii')
            
            a = get_spectrum_api(specid)

            with open(path+s,'w') as f:
                f.write(a['data']['original_file_string'])
            f.close()

            #print (s,'\n')
            spectrum_name = s
            
            
        if inst == 'LRIS':
            
            wav = (a['data']['wavelengths'])
            flux = (a['data']['fluxes'])
            err = (a['data']['errors'])
            
            OBSDATE = a['data']['observed_at'].split('T')[0]

            path = os.getcwd()

            s = (ztfname+'_'+str(OBSDATE)+'_'+str(inst)+'.ascii')
            
            if err == None:
                
                with open(path+'/data/'+s,'w') as f:
                
                    for i in range(len(wav)):
                        f.write(str(wav[i])+'\t'+str(flux[i])+'\n')
                f.close()

                #print (s,'\n')
                spectrum_name = s
                
            else:

                with open(path+'/data/'+s,'w') as f:

                    for i in range(len(wav)):
                        f.write(str(wav[i])+'\t'+str(flux[i])+'\t'+str(err[i])+'\n')
                f.close()

                #print (s,'\n')
                spectrum_name = s
            
    return spectrum_name, specid



def APO(specid):
    
    a = get_spectrum_api(specid)
    inst = (a['data']['instrument_name'])
    
    obsdate = a['data']['original_file_string']['observed_at']
    
    OBSDATE = obsdate
    
    a = get_spectrum_api(specid)

    exptime = a['data']['original_file_string'].split('#')[9]
    a,b = exptime.split(' ', 1)
    c,EXPTIME = b.split(' ', 1)
    
    a = get_spectrum_api(specid)

    observers = (a['data']['original_file_string'].split('#')[10])
    a,b = observers.split(' ', 1)
    c,OBSERVERS = b.split(' ', 1)
    
    a = get_spectrum_api(specid)

    reducers = a['data']['original_file_string'].split('#')[11]
    a,b = reducers.split(' ', 1)
    c,d = b.split(' ', 1)
    REDUCERS,e = d.split('\n', 1)
    
    return OBSDATE.split(' \n')[0], EXPTIME.split(' \n')[0], OBSERVERS.split(' \n')[0], REDUCERS


def pprint(*args, **kwargs):
    """
    slightly more convenient function instead of print(get_pprint)

    params:
        *args (arguments to pass to get_pprint)
        **kwargs (keyword arguments to pass to get_pprint)
    """
    print(get_pprint(*args, **kwargs))
    

def post_comment(ztfname, text):
    
    
    data = {  "obj_id": ztfname,
              "text": text,
           }

    url = BASEURL+'api/comment'
    
    response = api('POST', url, data=data)
    
    return response

def delete_spectrum(spectrum_id):
    url = BASEURL+'api/spectrum/'+spectrum_id
    
    response = api('DELETE', url)
    
    return response


def retrieve_spectrum(spectrum_id):
    url = BASEURL+'api/spectrum/'+spectrum_id
    
    response = api('GET', url)
    
    return response

# %%
get_classification('ZTF21aavqwhh')
# Out:
# ('Ia', '2021-04-19')

# %%
get_required_spectrum_id('ZTF21aaqldsk')
# Out:
# Please choose from the following spectra:
#
# 1 ) spectrum name:  spec_auto_redo131104_lstep1__crr_b_ifu20210408_06_14_37_ZTF21aaqldsk.txt spectrum date: 2021-04-08
# 2 ) spectrum name:  merge_ZTF21aaqldsk.txt spectrum date: 2021-04-12
# 3 ) spectrum name:  spec_auto_redo064457_lstep1__crr_b_ifu20210421_05_07_36_ZTF21aaqldsk.txt spectrum date: 2021-04-21
# Choose spectrum to upload: 2
# 2333

# %%
get_spectrum_api(2333)['data']
# Out:
# {'instrument_id': 9,
#  'modified': '2021-04-21T03:12:17.910062',
#  'followup_request_id': None,
#  'wavelengths': [3210.4,
#   3211.4,
#   3212.4,
#   3213.4,
#   3214.4,
#   3215.4,
#   3216.4,
#   3217.4,
#   3218.4,
#   3219.4,
#   3220.4,
#   3221.4,
#   3222.4,
#   3223.4,
#   3224.4,
#   3225.4,
#   3226.4,
#   3227.4,
#   3228.4,
#   3229.4,
#   3230.4,
#   3231.4,
#   3232.4,
#   3233.4,
#   3234.4,
#   3235.4,
#   3236.4,
#   3237.4,
#   3238.4,
#   3239.4,
#   3240.4,
#   3241.4,
#   3242.4,
#   3243.4,
#   3244.4,
#   3245.4,
#   3246.4,
#   3247.4,
#   3248.4,
#   3249.4,
#   3250.4,
#   3251.4,
#   3252.4,
#   3253.4,
#   3254.4,
#   3255.4,
#   3256.4,
#   3257.4,
#   3258.4,
#   3259.4,
#   3260.4,
#   3261.4,
#   3262.4,
#   3263.4,
#   3264.4,
#   3265.4,
#   3266.4,
#   3267.4,
#   3268.4,
#   3269.4,
#   3270.4,
#   3271.4,
#   3272.4,
#   3273.4,
#   3274.4,
#   3275.4,
#   3276.4,
#   3277.4,
#   3278.4,
#   3279.4,
#   3280.4,
#   3281.4,
#   3282.4,
#   3283.4,
#   3284.4,
#   3285.4,
#   3286.4,
#   3287.4,
#   3288.4,
#   3289.4,
#   3290.4,
#   3291.4,
#   3292.4,
#   3293.4,
#   3294.4,
#   3295.4,
#   3296.4,
#   3297.4,
#   3298.4,
#   3299.4,
#   3300.4,
#   3301.4,
#   3302.4,
#   3303.4,
#   3304.4,
#   3305.4,
#   3306.4,
#   3307.4,
#   3308.4,
#   3309.4,
#   3310.4,
#   3311.4,
#   3312.4,
#   3313.4,
#   3314.4,
#   3315.4,
#   3316.4,
#   3317.4,
#   3318.4,
#   3319.4,
#   3320.4,
#   3321.4,
#   3322.4,
#   3323.4,
#   3324.4,
#   3325.4,
#   3326.4,
#   3327.4,
#   3328.4,
#   3329.4,
#   3330.4,
#   3331.4,
#   3332.4,
#   3333.4,
#   3334.4,
#   3335.4,
#   3336.4,
#   3337.4,
#   3338.4,
#   3339.4,
#   3340.4,
#   3341.4,
#   3342.4,
#   3343.4,
#   3344.4,
#   3345.4,
#   3346.4,
#   3347.4,
#   3348.4,
#   3349.4,
#   3350.4,
#   3351.4,
#   3352.4,
#   3353.4,
#   3354.4,
#   3355.4,
#   3356.4,
#   3357.4,
#   3358.4,
#   3359.4,
#   3360.4,
#   3361.4,
#   3362.4,
#   3363.4,
#   3364.4,
#   3365.4,
#   3366.4,
#   3367.4,
#   3368.4,
#   3369.4,
#   3370.4,
#   3371.4,
#   3372.4,
#   3373.4,
#   3374.4,
#   3375.4,
#   3376.4,
#   3377.4,
#   3378.4,
#   3379.4,
#   3380.4,
#   3381.4,
#   3382.4,
#   3383.4,
#   3384.4,
#   3385.4,
#   3386.4,
#   3387.4,
#   3388.4,
#   3389.4,
#   3390.4,
#   3391.4,
#   3392.4,
#   3393.4,
#   3394.4,
#   3395.4,
#   3396.4,
#   3397.4,
#   3398.4,
#   3399.4,
#   3400.4,
#   3401.4,
#   3402.4,
#   3403.4,
#   3404.4,
#   3405.4,
#   3406.4,
#   3407.4,
#   3408.4,
#   3409.4,
#   3410.4,
#   3411.4,
#   3412.4,
#   3413.4,
#   3414.4,
#   3415.4,
#   3416.4,
#   3417.4,
#   3418.4,
#   3419.4,
#   3420.4,
#   3421.4,
#   3422.4,
#   3423.4,
#   3424.4,
#   3425.4,
#   3426.4,
#   3427.4,
#   3428.4,
#   3429.4,
#   3430.4,
#   3431.4,
#   3432.4,
#   3433.4,
#   3434.4,
#   3435.4,
#   3436.4,
#   3437.4,
#   3438.4,
#   3439.4,
#   3440.4,
#   3441.4,
#   3442.4,
#   3443.4,
#   3444.4,
#   3445.4,
#   3446.4,
#   3447.4,
#   3448.4,
#   3449.4,
#   3450.4,
#   3451.4,
#   3452.4,
#   3453.4,
#   3454.4,
#   3455.4,
#   3456.4,
#   3457.4,
#   3458.4,
#   3459.4,
#   3460.4,
#   3461.4,
#   3462.4,
#   3463.4,
#   3464.4,
#   3465.4,
#   3466.4,
#   3467.4,
#   3468.4,
#   3469.4,
#   3470.4,
#   3471.4,
#   3472.4,
#   3473.4,
#   3474.4,
#   3475.4,
#   3476.4,
#   3477.4,
#   3478.4,
#   3479.4,
#   3480.4,
#   3481.4,
#   3482.4,
#   3483.4,
#   3484.4,
#   3485.4,
#   3486.4,
#   3487.4,
#   3488.4,
#   3489.4,
#   3490.4,
#   3491.4,
#   3492.4,
#   3493.4,
#   3494.4,
#   3495.4,
#   3496.4,
#   3497.4,
#   3498.4,
#   3499.4,
#   3500.4,
#   3501.4,
#   3502.4,
#   3503.4,
#   3504.4,
#   3505.4,
#   3506.4,
#   3507.4,
#   3508.4,
#   3509.4,
#   3510.4,
#   3511.4,
#   3512.4,
#   3513.4,
#   3514.4,
#   3515.4,
#   3516.4,
#   3517.4,
#   3518.4,
#   3519.4,
#   3520.4,
#   3521.4,
#   3522.4,
#   3523.4,
#   3524.4,
#   3525.4,
#   3526.4,
#   3527.4,
#   3528.4,
#   3529.4,
#   3530.4,
#   3531.4,
#   3532.4,
#   3533.4,
#   3534.4,
#   3535.4,
#   3536.4,
#   3537.4,
#   3538.4,
#   3539.4,
#   3540.4,
#   3541.4,
#   3542.4,
#   3543.4,
#   3544.4,
#   3545.4,
#   3546.4,
#   3547.4,
#   3548.4,
#   3549.4,
#   3550.4,
#   3551.4,
#   3552.4,
#   3553.4,
#   3554.4,
#   3555.4,
#   3556.4,
#   3557.4,
#   3558.4,
#   3559.4,
#   3560.4,
#   3561.4,
#   3562.4,
#   3563.4,
#   3564.4,
#   3565.4,
#   3566.4,
#   3567.4,
#   3568.4,
#   3569.4,
#   3570.4,
#   3571.4,
#   3572.4,
#   3573.4,
#   3574.4,
#   3575.4,
#   3576.4,
#   3577.4,
#   3578.4,
#   3579.4,
#   3580.4,
#   3581.4,
#   3582.4,
#   3583.4,
#   3584.4,
#   3585.4,
#   3586.4,
#   3587.4,
#   3588.4,
#   3589.4,
#   3590.4,
#   3591.4,
#   3592.4,
#   3593.4,
#   3594.4,
#   3595.4,
#   3596.4,
#   3597.4,
#   3598.4,
#   3599.4,
#   3600.4,
#   3601.4,
#   3602.4,
#   3603.4,
#   3604.4,
#   3605.4,
#   3606.4,
#   3607.4,
#   3608.4,
#   3609.4,
#   3610.4,
#   3611.4,
#   3612.4,
#   3613.4,
#   3614.4,
#   3615.4,
#   3616.4,
#   3617.4,
#   3618.4,
#   3619.4,
#   3620.4,
#   3621.4,
#   3622.4,
#   3623.4,
#   3624.4,
#   3625.4,
#   3626.4,
#   3627.4,
#   3628.4,
#   3629.4,
#   3630.4,
#   3631.4,
#   3632.4,
#   3633.4,
#   3634.4,
#   3635.4,
#   3636.4,
#   3637.4,
#   3638.4,
#   3639.4,
#   3640.4,
#   3641.4,
#   3642.4,
#   3643.4,
#   3644.4,
#   3645.4,
#   3646.4,
#   3647.4,
#   3648.4,
#   3649.4,
#   3650.4,
#   3651.4,
#   3652.4,
#   3653.4,
#   3654.4,
#   3655.4,
#   3656.4,
#   3657.4,
#   3658.4,
#   3659.4,
#   3660.4,
#   3661.4,
#   3662.4,
#   3663.4,
#   3664.4,
#   3665.4,
#   3666.4,
#   3667.4,
#   3668.4,
#   3669.4,
#   3670.4,
#   3671.4,
#   3672.4,
#   3673.4,
#   3674.4,
#   3675.4,
#   3676.4,
#   3677.4,
#   3678.4,
#   3679.4,
#   3680.4,
#   3681.4,
#   3682.4,
#   3683.4,
#   3684.4,
#   3685.4,
#   3686.4,
#   3687.4,
#   3688.4,
#   3689.4,
#   3690.4,
#   3691.4,
#   3692.4,
#   3693.4,
#   3694.4,
#   3695.4,
#   3696.4,
#   3697.4,
#   3698.4,
#   3699.4,
#   3700.4,
#   3701.4,
#   3702.4,
#   3703.4,
#   3704.4,
#   3705.4,
#   3706.4,
#   3707.4,
#   3708.4,
#   3709.4,
#   3710.4,
#   3711.4,
#   3712.4,
#   3713.4,
#   3714.4,
#   3715.4,
#   3716.4,
#   3717.4,
#   3718.4,
#   3719.4,
#   3720.4,
#   3721.4,
#   3722.4,
#   3723.4,
#   3724.4,
#   3725.4,
#   3726.4,
#   3727.4,
#   3728.4,
#   3729.4,
#   3730.4,
#   3731.4,
#   3732.4,
#   3733.4,
#   3734.4,
#   3735.4,
#   3736.4,
#   3737.4,
#   3738.4,
#   3739.4,
#   3740.4,
#   3741.4,
#   3742.4,
#   3743.4,
#   3744.4,
#   3745.4,
#   3746.4,
#   3747.4,
#   3748.4,
#   3749.4,
#   3750.4,
#   3751.4,
#   3752.4,
#   3753.4,
#   3754.4,
#   3755.4,
#   3756.4,
#   3757.4,
#   3758.4,
#   3759.4,
#   3760.4,
#   3761.4,
#   3762.4,
#   3763.4,
#   3764.4,
#   3765.4,
#   3766.4,
#   3767.4,
#   3768.4,
#   3769.4,
#   3770.4,
#   3771.4,
#   3772.4,
#   3773.4,
#   3774.4,
#   3775.4,
#   3776.4,
#   3777.4,
#   3778.4,
#   3779.4,
#   3780.4,
#   3781.4,
#   3782.4,
#   3783.4,
#   3784.4,
#   3785.4,
#   3786.4,
#   3787.4,
#   3788.4,
#   3789.4,
#   3790.4,
#   3791.4,
#   3792.4,
#   3793.4,
#   3794.4,
#   3795.4,
#   3796.4,
#   3797.4,
#   3798.4,
#   3799.4,
#   3800.4,
#   3801.4,
#   3802.4,
#   3803.4,
#   3804.4,
#   3805.4,
#   3806.4,
#   3807.4,
#   3808.4,
#   3809.4,
#   3810.4,
#   3811.4,
#   3812.4,
#   3813.4,
#   3814.4,
#   3815.4,
#   3816.4,
#   3817.4,
#   3818.4,
#   3819.4,
#   3820.4,
#   3821.4,
#   3822.4,
#   3823.4,
#   3824.4,
#   3825.4,
#   3826.4,
#   3827.4,
#   3828.4,
#   3829.4,
#   3830.4,
#   3831.4,
#   3832.4,
#   3833.4,
#   3834.4,
#   3835.4,
#   3836.4,
#   3837.4,
#   3838.4,
#   3839.4,
#   3840.4,
#   3841.4,
#   3842.4,
#   3843.4,
#   3844.4,
#   3845.4,
#   3846.4,
#   3847.4,
#   3848.4,
#   3849.4,
#   3850.4,
#   3851.4,
#   3852.4,
#   3853.4,
#   3854.4,
#   3855.4,
#   3856.4,
#   3857.4,
#   3858.4,
#   3859.4,
#   3860.4,
#   3861.4,
#   3862.4,
#   3863.4,
#   3864.4,
#   3865.4,
#   3866.4,
#   3867.4,
#   3868.4,
#   3869.4,
#   3870.4,
#   3871.4,
#   3872.4,
#   3873.4,
#   3874.4,
#   3875.4,
#   3876.4,
#   3877.4,
#   3878.4,
#   3879.4,
#   3880.4,
#   3881.4,
#   3882.4,
#   3883.4,
#   3884.4,
#   3885.4,
#   3886.4,
#   3887.4,
#   3888.4,
#   3889.4,
#   3890.4,
#   3891.4,
#   3892.4,
#   3893.4,
#   3894.4,
#   3895.4,
#   3896.4,
#   3897.4,
#   3898.4,
#   3899.4,
#   3900.4,
#   3901.4,
#   3902.4,
#   3903.4,
#   3904.4,
#   3905.4,
#   3906.4,
#   3907.4,
#   3908.4,
#   3909.4,
#   3910.4,
#   3911.4,
#   3912.4,
#   3913.4,
#   3914.4,
#   3915.4,
#   3916.4,
#   3917.4,
#   3918.4,
#   3919.4,
#   3920.4,
#   3921.4,
#   3922.4,
#   3923.4,
#   3924.4,
#   3925.4,
#   3926.4,
#   3927.4,
#   3928.4,
#   3929.4,
#   3930.4,
#   3931.4,
#   3932.4,
#   3933.4,
#   3934.4,
#   3935.4,
#   3936.4,
#   3937.4,
#   3938.4,
#   3939.4,
#   3940.4,
#   3941.4,
#   3942.4,
#   3943.4,
#   3944.4,
#   3945.4,
#   3946.4,
#   3947.4,
#   3948.4,
#   3949.4,
#   3950.4,
#   3951.4,
#   3952.4,
#   3953.4,
#   3954.4,
#   3955.4,
#   3956.4,
#   3957.4,
#   3958.4,
#   3959.4,
#   3960.4,
#   3961.4,
#   3962.4,
#   3963.4,
#   3964.4,
#   3965.4,
#   3966.4,
#   3967.4,
#   3968.4,
#   3969.4,
#   3970.4,
#   3971.4,
#   3972.4,
#   3973.4,
#   3974.4,
#   3975.4,
#   3976.4,
#   3977.4,
#   3978.4,
#   3979.4,
#   3980.4,
#   3981.4,
#   3982.4,
#   3983.4,
#   3984.4,
#   3985.4,
#   3986.4,
#   3987.4,
#   3988.4,
#   3989.4,
#   3990.4,
#   3991.4,
#   3992.4,
#   3993.4,
#   3994.4,
#   3995.4,
#   3996.4,
#   3997.4,
#   3998.4,
#   3999.4,
#   4000.4,
#   4001.4,
#   4002.4,
#   4003.4,
#   4004.4,
#   4005.4,
#   4006.4,
#   4007.4,
#   4008.4,
#   4009.4,
#   4010.4,
#   4011.4,
#   4012.4,
#   4013.4,
#   4014.4,
#   4015.4,
#   4016.4,
#   4017.4,
#   4018.4,
#   4019.4,
#   4020.4,
#   4021.4,
#   4022.4,
#   4023.4,
#   4024.4,
#   4025.4,
#   4026.4,
#   4027.4,
#   4028.4,
#   4029.4,
#   4030.4,
#   4031.4,
#   4032.4,
#   4033.4,
#   4034.4,
#   4035.4,
#   4036.4,
#   4037.4,
#   4038.4,
#   4039.4,
#   4040.4,
#   4041.4,
#   4042.4,
#   4043.4,
#   4044.4,
#   4045.4,
#   4046.4,
#   4047.4,
#   4048.4,
#   4049.4,
#   4050.4,
#   4051.4,
#   4052.4,
#   4053.4,
#   4054.4,
#   4055.4,
#   4056.4,
#   4057.4,
#   4058.4,
#   4059.4,
#   4060.4,
#   4061.4,
#   4062.4,
#   4063.4,
#   4064.4,
#   4065.4,
#   4066.4,
#   4067.4,
#   4068.4,
#   4069.4,
#   4070.4,
#   4071.4,
#   4072.4,
#   4073.4,
#   4074.4,
#   4075.4,
#   4076.4,
#   4077.4,
#   4078.4,
#   4079.4,
#   4080.4,
#   4081.4,
#   4082.4,
#   4083.4,
#   4084.4,
#   4085.4,
#   4086.4,
#   4087.4,
#   4088.4,
#   4089.4,
#   4090.4,
#   4091.4,
#   4092.4,
#   4093.4,
#   4094.4,
#   4095.4,
#   4096.4,
#   4097.4,
#   4098.4,
#   4099.4,
#   4100.4,
#   4101.4,
#   4102.4,
#   4103.4,
#   4104.4,
#   4105.4,
#   4106.4,
#   4107.4,
#   4108.4,
#   4109.4,
#   4110.4,
#   4111.4,
#   4112.4,
#   4113.4,
#   4114.4,
#   4115.4,
#   4116.4,
#   4117.4,
#   4118.4,
#   4119.4,
#   4120.4,
#   4121.4,
#   4122.4,
#   4123.4,
#   4124.4,
#   4125.4,
#   4126.4,
#   4127.4,
#   4128.4,
#   4129.4,
#   4130.4,
#   4131.4,
#   4132.4,
#   4133.4,
#   4134.4,
#   4135.4,
#   4136.4,
#   4137.4,
#   4138.4,
#   4139.4,
#   4140.4,
#   4141.4,
#   4142.4,
#   4143.4,
#   4144.4,
#   4145.4,
#   4146.4,
#   4147.4,
#   4148.4,
#   4149.4,
#   4150.4,
#   4151.4,
#   4152.4,
#   4153.4,
#   4154.4,
#   4155.4,
#   4156.4,
#   4157.4,
#   4158.4,
#   4159.4,
#   4160.4,
#   4161.4,
#   4162.4,
#   4163.4,
#   4164.4,
#   4165.4,
#   4166.4,
#   4167.4,
#   4168.4,
#   4169.4,
#   4170.4,
#   4171.4,
#   4172.4,
#   4173.4,
#   4174.4,
#   4175.4,
#   4176.4,
#   4177.4,
#   4178.4,
#   4179.4,
#   4180.4,
#   4181.4,
#   4182.4,
#   4183.4,
#   4184.4,
#   4185.4,
#   4186.4,
#   4187.4,
#   4188.4,
#   4189.4,
#   4190.4,
#   4191.4,
#   4192.4,
#   4193.4,
#   4194.4,
#   4195.4,
#   4196.4,
#   4197.4,
#   4198.4,
#   4199.4,
#   4200.4,
#   4201.4,
#   4202.4,
#   4203.4,
#   4204.4,
#   4205.4,
#   4206.4,
#   4207.4,
#   4208.4,
#   4209.4,
#   ...],
#  'assignment_id': None,
#  'fluxes': [-31.272,
#   26.412,
#   -15.744,
#   1.9954,
#   -6.1447,
#   17.832,
#   5.2183,
#   0.21775,
#   -6.9667,
#   4.2811,
#   -6.0224,
#   -9.3593,
#   -17.105,
#   -5.2356,
#   5.7495,
#   7.5477,
#   12.518,
#   17.948,
#   -1.4694,
#   -9.3596,
#   -7.9097,
#   -22.037,
#   4.4611,
#   -11.074,
#   -4.0146,
#   -23.181,
#   -19.601,
#   -1.1836,
#   -0.78184,
#   -24.278,
#   14.093,
#   -6.6918,
#   23.791,
#   4.678,
#   -0.16812,
#   9.6897,
#   4.2042,
#   6.9755,
#   -4.8835,
#   -3.8561,
#   -6.5464,
#   14.026,
#   4.4597,
#   13.436,
#   -19.147,
#   -7.0325,
#   6.9432,
#   -38.05,
#   4.5851,
#   5.9896,
#   16.813,
#   -7.9651,
#   -14.264,
#   32.227,
#   5.4569,
#   -0.87891,
#   -28.783,
#   10.008,
#   23.995,
#   -34.008,
#   -2.2496,
#   0.11508,
#   3.1349,
#   -5.697,
#   16.534,
#   -5.1978,
#   -12.839,
#   5.9947,
#   -7.0403,
#   -11.725,
#   -25.052,
#   26.996,
#   -11.276,
#   -19.95,
#   -30.599,
#   13.499,
#   4.1841,
#   3.8265,
#   34.561,
#   2.4864,
#   8.3311,
#   7.6642,
#   42.44,
#   -26.154,
#   -9.6321,
#   12.023,
#   18.366,
#   -5.863,
#   4.0883,
#   -31.207,
#   0.43212,
#   7.7292,
#   7.1288,
#   9.9151,
#   -4.3334,
#   9.0054,
#   6.1241,
#   -13.343,
#   6.5396,
#   -10.873,
#   -16.492,
#   14.435,
#   5.3384,
#   -2.7299,
#   -4.5163,
#   0.99841,
#   14.33,
#   -0.12359,
#   2.1285,
#   13.219,
#   -9.9548,
#   19.166,
#   1.3092,
#   -24.43,
#   7.3272,
#   -24.108,
#   -21.459,
#   -6.7376,
#   6.5511,
#   -11.524,
#   47.904,
#   16.632,
#   -9.9189,
#   8.9459,
#   -2.9127,
#   -13.524,
#   25.674,
#   -5.5843,
#   15.366,
#   -3.9788,
#   8.4657,
#   -5.118,
#   5.001,
#   -4.8629,
#   -16.854,
#   -7.2959,
#   -9.0155,
#   9.6989,
#   2.2488,
#   -1.1388,
#   2.8036,
#   1.3099,
#   15.514,
#   15.051,
#   1.0004,
#   -3.9352,
#   11.847,
#   -9.1448,
#   8.1759,
#   11.344,
#   7.0531,
#   -12.882,
#   16.191,
#   -7.6598,
#   -19.571,
#   -1.5957,
#   7.4258,
#   -13.425,
#   0.75325,
#   9.7437,
#   -13.267,
#   4.0858,
#   -5.11,
#   2.754,
#   4.6756,
#   22.28,
#   -5.4303,
#   32.906,
#   3.2714,
#   9.7974,
#   17.745,
#   -14.373,
#   -12.139,
#   1.4691,
#   36.811,
#   -6.197,
#   18.4,
#   16.036,
#   -10.72,
#   5.0361,
#   9.9348,
#   21.411,
#   -4.7991,
#   25.062,
#   14.788,
#   -7.7577,
#   23.099,
#   -23.42,
#   -23.074,
#   9.1806,
#   9.3919,
#   -3.2631,
#   26.589,
#   19.075,
#   12.256,
#   11.261,
#   7.3602,
#   24.268,
#   -4.2835,
#   2.437,
#   20.689,
#   -6.0474,
#   9.8809,
#   -10.465,
#   25.52,
#   14.218,
#   3.37,
#   29.009,
#   7.8992,
#   2.773,
#   -24.323,
#   2.4573,
#   13.669,
#   4.0081,
#   22.038,
#   23.044,
#   0.27785,
#   9.9514,
#   -8.3526,
#   -6.7334,
#   10.576,
#   -11.885,
#   -5.3304,
#   -9.502,
#   -7.915,
#   -3.5247,
#   16.762,
#   2.9303,
#   9.8005,
#   8.2704,
#   10.074,
#   14.904,
#   21.288,
#   5.4083,
#   -11.121,
#   37.111,
#   -15.326,
#   5.362,
#   2.6221,
#   -0.87178,
#   6.8721,
#   24.413,
#   -5.1502,
#   17.325,
#   -8.9486,
#   44.743,
#   26.082,
#   18.328,
#   12.003,
#   -1.7994,
#   -18.839,
#   11.978,
#   22.09,
#   -0.60818,
#   8.1592,
#   21.103,
#   28.272,
#   -8.8751,
#   9.1548,
#   5.9919,
#   28.898,
#   15.958,
#   7.172,
#   -8.256,
#   -14.761,
#   9.0733,
#   22.619,
#   -3.5728,
#   12.649,
#   17.499,
#   23.5,
#   27.544,
#   -8.1326,
#   5.9667,
#   2.0158,
#   -5.5135,
#   2.4519,
#   14.551,
#   3.5081,
#   -15.68,
#   -20.413,
#   13.372,
#   -3.2333,
#   6.8566,
#   21.389,
#   4.7001,
#   -14.508,
#   34.89,
#   2.1081,
#   -2.3729,
#   14.115,
#   5.9789,
#   -12.09,
#   -6.6878,
#   18.498,
#   49.778,
#   33.532,
#   -10.613,
#   2.8646,
#   -12.599,
#   -18.132,
#   5.9503,
#   -9.1608,
#   -0.27569,
#   -9.4432,
#   -9.3146,
#   27.381,
#   -14.852,
#   0.47046,
#   15.073,
#   27.23,
#   -37.4,
#   20.579,
#   12.617,
#   -19.979,
#   35.911,
#   9.837,
#   22.649,
#   -9.2069,
#   1.3215,
#   -2.6599,
#   25.079,
#   9.3084,
#   -17.189,
#   6.2123,
#   -6.8987,
#   -17.904,
#   -30.552,
#   1.6148,
#   17.247,
#   -0.69388,
#   -17.762,
#   19.481,
#   -34.954,
#   -34.702,
#   -0.023408,
#   14.413,
#   21.33,
#   36.363,
#   21.69,
#   10.501,
#   -8.9718,
#   12.532,
#   -5.0927,
#   33.676,
#   -6.0888,
#   8.132,
#   1.1549,
#   9.7709,
#   18.123,
#   -2.7598,
#   0.51784,
#   19.598,
#   18.99,
#   19.541,
#   1.941,
#   16.321,
#   9.9473,
#   45.401,
#   13.01,
#   -4.7258,
#   -4.6975,
#   0.15615,
#   0.32704,
#   24.309,
#   1.9815,
#   12.759,
#   7.91,
#   5.4457,
#   9.9948,
#   -6.3071,
#   -9.6877,
#   39.886,
#   23.855,
#   5.2716,
#   -9.0197,
#   -3.6881,
#   10.261,
#   -8.3835,
#   -4.3055,
#   3.7568,
#   24.669,
#   29.095,
#   9.7407,
#   4.9247,
#   13.291,
#   5.1711,
#   34.861,
#   7.4452,
#   17.573,
#   8.7258,
#   24.191,
#   -1.5786,
#   -3.4139,
#   5.6185,
#   22.316,
#   31.42,
#   4.5183,
#   15.38,
#   -0.80635,
#   15.685,
#   27.182,
#   -7.7376,
#   -29.684,
#   5.8309,
#   10.153,
#   24.65,
#   6.0612,
#   1.2574,
#   -4.1787,
#   -1.1618,
#   -16.803,
#   -7.7684,
#   8.1577,
#   -10.241,
#   12.956,
#   13.35,
#   -0.96641,
#   1.7765,
#   28.781,
#   -16.666,
#   17.12,
#   7.9328,
#   38.172,
#   18.024,
#   14.933,
#   38.479,
#   -8.1574,
#   -6.688,
#   -7.7719,
#   3.9158,
#   -7.2539,
#   19.649,
#   23.959,
#   -10.972,
#   31.78,
#   3.2463,
#   29.532,
#   37.695,
#   16.346,
#   -8.925,
#   2.9648,
#   -2.1985,
#   18.389,
#   19.663,
#   30.737,
#   25.278,
#   44.422,
#   37.028,
#   1.5684,
#   38.269,
#   31.393,
#   46.62,
#   30.773,
#   25.49,
#   -4.7559,
#   7.864,
#   -4.3831,
#   1.9583,
#   27.982,
#   0.44366,
#   -6.2992,
#   27.304,
#   46.884,
#   43.821,
#   -0.90757,
#   13.422,
#   1.8925,
#   20.206,
#   16.903,
#   7.7519,
#   11.726,
#   5.9007,
#   3.0674,
#   7.2677,
#   40.475,
#   46.463,
#   24.607,
#   40.562,
#   39.584,
#   20.285,
#   23.333,
#   7.7603,
#   27.845,
#   27.256,
#   45.283,
#   28.626,
#   0.42672,
#   27.951,
#   12.415,
#   53.392,
#   15.106,
#   39.542,
#   33.522,
#   39.841,
#   28.983,
#   18.522,
#   15.131,
#   22.435,
#   11.171,
#   18.907,
#   29.291,
#   29.554,
#   51.237,
#   14.103,
#   6.8006,
#   45.158,
#   16.294,
#   29.254,
#   11.262,
#   47.908,
#   22.023,
#   23.371,
#   38.323,
#   38.998,
#   23.612,
#   19.0,
#   23.953,
#   17.44,
#   10.999,
#   16.479,
#   29.4,
#   23.27,
#   36.185,
#   68.91,
#   9.9935,
#   20.228,
#   30.031,
#   28.57,
#   -6.7212,
#   20.884,
#   20.742,
#   33.514,
#   13.281,
#   22.015,
#   35.128,
#   32.477,
#   8.497,
#   24.579,
#   31.945,
#   27.835,
#   -5.4448,
#   9.23,
#   21.551,
#   29.055,
#   27.744,
#   27.63,
#   12.027,
#   35.396,
#   39.689,
#   31.782,
#   42.8,
#   50.551,
#   7.6758,
#   29.425,
#   34.514,
#   1.2634,
#   51.409,
#   15.041,
#   42.561,
#   33.012,
#   24.122,
#   62.019,
#   24.519,
#   7.6764,
#   21.052,
#   48.702,
#   9.9054,
#   27.407,
#   17.097,
#   17.146,
#   11.298,
#   7.2634,
#   31.657,
#   51.086,
#   21.933,
#   22.456,
#   3.8126,
#   40.668,
#   17.936,
#   27.355,
#   28.05,
#   5.8858,
#   55.281,
#   59.418,
#   22.667,
#   31.64,
#   52.619,
#   34.502,
#   39.556,
#   22.6,
#   46.978,
#   56.684,
#   68.06,
#   46.616,
#   39.392,
#   36.327,
#   -15.527,
#   23.931,
#   2.007,
#   54.11,
#   15.984,
#   50.904,
#   20.198,
#   36.579,
#   39.577,
#   58.769,
#   20.944,
#   13.173,
#   36.745,
#   31.186,
#   18.863,
#   32.847,
#   17.141,
#   28.136,
#   33.841,
#   51.599,
#   49.117,
#   53.541,
#   16.309,
#   45.294,
#   86.489,
#   69.586,
#   51.397,
#   43.004,
#   43.528,
#   29.253,
#   39.746,
#   12.081,
#   38.069,
#   34.48,
#   39.042,
#   24.889,
#   40.308,
#   28.685,
#   40.063,
#   54.377,
#   52.496,
#   29.718,
#   57.925,
#   45.013,
#   43.638,
#   54.352,
#   75.957,
#   69.345,
#   28.752,
#   58.87,
#   60.66,
#   35.268,
#   47.122,
#   10.793,
#   30.241,
#   37.065,
#   40.664,
#   37.8,
#   104.48,
#   58.944,
#   81.885,
#   88.513,
#   39.782,
#   29.134,
#   40.218,
#   18.998,
#   11.048,
#   24.372,
#   25.217,
#   31.611,
#   35.985,
#   45.216,
#   25.718,
#   31.566,
#   33.591,
#   46.194,
#   63.949,
#   7.909,
#   65.239,
#   15.37,
#   59.236,
#   17.079,
#   22.678,
#   44.216,
#   16.198,
#   64.545,
#   -4.1094,
#   20.525,
#   32.885,
#   29.777,
#   1.9513,
#   20.272,
#   53.212,
#   57.874,
#   43.4,
#   23.581,
#   14.944,
#   19.734,
#   19.593,
#   13.287,
#   34.312,
#   40.813,
#   43.72,
#   7.8311,
#   11.514,
#   -3.8474,
#   24.407,
#   -70.036,
#   14.022,
#   25.167,
#   3.0019,
#   23.568,
#   20.184,
#   59.653,
#   50.464,
#   47.794,
#   39.623,
#   41.542,
#   18.674,
#   6.6028,
#   45.863,
#   -0.91646,
#   -6.7379,
#   27.423,
#   3.1824,
#   17.914,
#   38.438,
#   33.602,
#   -1.3944,
#   7.4429,
#   23.439,
#   13.196,
#   41.574,
#   21.549,
#   -0.17361,
#   23.525,
#   19.798,
#   51.872,
#   72.582,
#   67.368,
#   74.533,
#   62.466,
#   33.248,
#   45.081,
#   36.106,
#   16.014,
#   49.105,
#   31.021,
#   47.551,
#   -0.0099362,
#   45.94,
#   47.447,
#   20.691,
#   52.074,
#   52.407,
#   15.435,
#   46.463,
#   17.515,
#   58.544,
#   55.706,
#   27.197,
#   31.219,
#   40.772,
#   40.463,
#   31.013,
#   32.71,
#   29.675,
#   63.556,
#   42.65,
#   33.051,
#   33.226,
#   38.463,
#   51.351,
#   34.12,
#   37.799,
#   55.853,
#   47.478,
#   47.692,
#   23.741,
#   38.932,
#   68.369,
#   66.953,
#   54.636,
#   43.903,
#   75.588,
#   86.524,
#   83.541,
#   75.44,
#   77.557,
#   58.743,
#   59.891,
#   53.844,
#   75.661,
#   75.043,
#   65.999,
#   46.195,
#   46.602,
#   63.953,
#   123.8,
#   73.673,
#   15.105,
#   69.451,
#   60.923,
#   91.776,
#   90.055,
#   50.264,
#   156.17,
#   91.51,
#   15.696,
#   83.504,
#   121.7,
#   100.01,
#   87.128,
#   94.342,
#   103.23,
#   82.32,
#   102.13,
#   58.664,
#   86.061,
#   103.5,
#   103.66,
#   105.69,
#   46.397,
#   104.78,
#   76.366,
#   65.863,
#   46.846,
#   108.93,
#   113.11,
#   92.811,
#   72.14,
#   103.4,
#   104.81,
#   101.27,
#   67.336,
#   61.665,
#   95.822,
#   79.396,
#   106.64,
#   127.66,
#   131.6,
#   138.18,
#   116.9,
#   60.249,
#   103.16,
#   93.038,
#   88.591,
#   114.35,
#   132.51,
#   125.82,
#   78.751,
#   96.791,
#   136.05,
#   108.16,
#   131.99,
#   125.46,
#   112.57,
#   116.37,
#   118.72,
#   110.23,
#   103.18,
#   131.08,
#   106.21,
#   107.71,
#   119.44,
#   149.65,
#   145.65,
#   132.77,
#   127.71,
#   122.42,
#   129.92,
#   93.261,
#   101.16,
#   140.31,
#   133.58,
#   151.1,
#   135.4,
#   124.01,
#   114.9,
#   127.38,
#   142.76,
#   119.3,
#   145.57,
#   123.62,
#   148.24,
#   155.01,
#   136.52,
#   163.26,
#   150.9,
#   110.39,
#   145.68,
#   121.46,
#   94.575,
#   136.34,
#   127.28,
#   160.92,
#   162.51,
#   108.71,
#   146.93,
#   115.67,
#   130.06,
#   124.8,
#   101.55,
#   96.734,
#   147.8,
#   125.65,
#   147.13,
#   114.94,
#   128.17,
#   80.17,
#   115.88,
#   131.88,
#   118.31,
#   157.38,
#   129.85,
#   115.17,
#   68.96,
#   159.79,
#   163.07,
#   116.57,
#   162.78,
#   127.6,
#   154.62,
#   152.3,
#   138.53,
#   103.79,
#   138.74,
#   113.92,
#   164.41,
#   121.39,
#   156.63,
#   174.74,
#   100.53,
#   121.74,
#   181.52,
#   160.5,
#   150.21,
#   131.2,
#   144.27,
#   163.51,
#   129.5,
#   142.04,
#   108.46,
#   112.78,
#   104.2,
#   126.34,
#   131.35,
#   134.76,
#   148.22,
#   139.45,
#   145.48,
#   136.47,
#   142.3,
#   105.69,
#   138.38,
#   140.58,
#   125.91,
#   130.6,
#   131.41,
#   165.86,
#   109.01,
#   131.07,
#   118.78,
#   115.41,
#   143.16,
#   134.8,
#   136.41,
#   150.73,
#   164.97,
#   118.81,
#   144.1,
#   155.82,
#   105.42,
#   93.186,
#   113.98,
#   103.93,
#   153.32,
#   152.87,
#   146.3,
#   112.57,
#   118.74,
#   133.77,
#   117.74,
#   125.79,
#   146.78,
#   144.1,
#   105.19,
#   105.09,
#   102.15,
#   88.665,
#   85.102,
#   107.39,
#   138.33,
#   122.06,
#   111.43,
#   136.0,
#   152.82,
#   148.79,
#   118.86,
#   128.36,
#   167.9,
#   158.82,
#   110.88,
#   ...],
#  'altdata': None,
#  'errors': None,
#  'original_file_string': '3210.4 -31.272\n3211.4 26.412\n3212.4 -15.744\n3213.4 1.9954\n3214.4 -6.1447\n3215.4 17.832\n3216.4 5.2183\n3217.4 0.21775\n3218.4 -6.9667\n3219.4 4.2811\n3220.4 -6.0224\n3221.4 -9.3593\n3222.4 -17.105\n3223.4 -5.2356\n3224.4 5.7495\n3225.4 7.5477\n3226.4 12.518\n3227.4 17.948\n3228.4 -1.4694\n3229.4 -9.3596\n3230.4 -7.9097\n3231.4 -22.037\n3232.4 4.4611\n3233.4 -11.074\n3234.4 -4.0146\n3235.4 -23.181\n3236.4 -19.601\n3237.4 -1.1836\n3238.4 -0.78184\n3239.4 -24.278\n3240.4 14.093\n3241.4 -6.6918\n3242.4 23.791\n3243.4 4.678\n3244.4 -0.16812\n3245.4 9.6897\n3246.4 4.2042\n3247.4 6.9755\n3248.4 -4.8835\n3249.4 -3.8561\n3250.4 -6.5464\n3251.4 14.026\n3252.4 4.4597\n3253.4 13.436\n3254.4 -19.147\n3255.4 -7.0325\n3256.4 6.9432\n3257.4 -38.05\n3258.4 4.5851\n3259.4 5.9896\n3260.4 16.813\n3261.4 -7.9651\n3262.4 -14.264\n3263.4 32.227\n3264.4 5.4569\n3265.4 -0.87891\n3266.4 -28.783\n3267.4 10.008\n3268.4 23.995\n3269.4 -34.008\n3270.4 -2.2496\n3271.4 0.11508\n3272.4 3.1349\n3273.4 -5.697\n3274.4 16.534\n3275.4 -5.1978\n3276.4 -12.839\n3277.4 5.9947\n3278.4 -7.0403\n3279.4 -11.725\n3280.4 -25.052\n3281.4 26.996\n3282.4 -11.276\n3283.4 -19.95\n3284.4 -30.599\n3285.4 13.499\n3286.4 4.1841\n3287.4 3.8265\n3288.4 34.561\n3289.4 2.4864\n3290.4 8.3311\n3291.4 7.6642\n3292.4 42.44\n3293.4 -26.154\n3294.4 -9.6321\n3295.4 12.023\n3296.4 18.366\n3297.4 -5.863\n3298.4 4.0883\n3299.4 -31.207\n3300.4 0.43212\n3301.4 7.7292\n3302.4 7.1288\n3303.4 9.9151\n3304.4 -4.3334\n3305.4 9.0054\n3306.4 6.1241\n3307.4 -13.343\n3308.4 6.5396\n3309.4 -10.873\n3310.4 -16.492\n3311.4 14.435\n3312.4 5.3384\n3313.4 -2.7299\n3314.4 -4.5163\n3315.4 0.99841\n3316.4 14.33\n3317.4 -0.12359\n3318.4 2.1285\n3319.4 13.219\n3320.4 -9.9548\n3321.4 19.166\n3322.4 1.3092\n3323.4 -24.43\n3324.4 7.3272\n3325.4 -24.108\n3326.4 -21.459\n3327.4 -6.7376\n3328.4 6.5511\n3329.4 -11.524\n3330.4 47.904\n3331.4 16.632\n3332.4 -9.9189\n3333.4 8.9459\n3334.4 -2.9127\n3335.4 -13.524\n3336.4 25.674\n3337.4 -5.5843\n3338.4 15.366\n3339.4 -3.9788\n3340.4 8.4657\n3341.4 -5.118\n3342.4 5.001\n3343.4 -4.8629\n3344.4 -16.854\n3345.4 -7.2959\n3346.4 -9.0155\n3347.4 9.6989\n3348.4 2.2488\n3349.4 -1.1388\n3350.4 2.8036\n3351.4 1.3099\n3352.4 15.514\n3353.4 15.051\n3354.4 1.0004\n3355.4 -3.9352\n3356.4 11.847\n3357.4 -9.1448\n3358.4 8.1759\n3359.4 11.344\n3360.4 7.0531\n3361.4 -12.882\n3362.4 16.191\n3363.4 -7.6598\n3364.4 -19.571\n3365.4 -1.5957\n3366.4 7.4258\n3367.4 -13.425\n3368.4 0.75325\n3369.4 9.7437\n3370.4 -13.267\n3371.4 4.0858\n3372.4 -5.11\n3373.4 2.754\n3374.4 4.6756\n3375.4 22.28\n3376.4 -5.4303\n3377.4 32.906\n3378.4 3.2714\n3379.4 9.7974\n3380.4 17.745\n3381.4 -14.373\n3382.4 -12.139\n3383.4 1.4691\n3384.4 36.811\n3385.4 -6.197\n3386.4 18.4\n3387.4 16.036\n3388.4 -10.72\n3389.4 5.0361\n3390.4 9.9348\n3391.4 21.411\n3392.4 -4.7991\n3393.4 25.062\n3394.4 14.788\n3395.4 -7.7577\n3396.4 23.099\n3397.4 -23.42\n3398.4 -23.074\n3399.4 9.1806\n3400.4 9.3919\n3401.4 -3.2631\n3402.4 26.589\n3403.4 19.075\n3404.4 12.256\n3405.4 11.261\n3406.4 7.3602\n3407.4 24.268\n3408.4 -4.2835\n3409.4 2.437\n3410.4 20.689\n3411.4 -6.0474\n3412.4 9.8809\n3413.4 -10.465\n3414.4 25.52\n3415.4 14.218\n3416.4 3.37\n3417.4 29.009\n3418.4 7.8992\n3419.4 2.773\n3420.4 -24.323\n3421.4 2.4573\n3422.4 13.669\n3423.4 4.0081\n3424.4 22.038\n3425.4 23.044\n3426.4 0.27785\n3427.4 9.9514\n3428.4 -8.3526\n3429.4 -6.7334\n3430.4 10.576\n3431.4 -11.885\n3432.4 -5.3304\n3433.4 -9.502\n3434.4 -7.915\n3435.4 -3.5247\n3436.4 16.762\n3437.4 2.9303\n3438.4 9.8005\n3439.4 8.2704\n3440.4 10.074\n3441.4 14.904\n3442.4 21.288\n3443.4 5.4083\n3444.4 -11.121\n3445.4 37.111\n3446.4 -15.326\n3447.4 5.362\n3448.4 2.6221\n3449.4 -0.87178\n3450.4 6.8721\n3451.4 24.413\n3452.4 -5.1502\n3453.4 17.325\n3454.4 -8.9486\n3455.4 44.743\n3456.4 26.082\n3457.4 18.328\n3458.4 12.003\n3459.4 -1.7994\n3460.4 -18.839\n3461.4 11.978\n3462.4 22.09\n3463.4 -0.60818\n3464.4 8.1592\n3465.4 21.103\n3466.4 28.272\n3467.4 -8.8751\n3468.4 9.15 ...
#  'obj_id': 'ZTF21aaqldsk',
#  'original_file_filename': 'merge_ZTF21aaqldsk.txt',
#  'observed_at': '2021-04-12T06:22:07',
#  'owner_id': 13,
#  'origin': None,
#  'id': 2333,
#  'created_at': '2021-04-21T03:12:17.910062',
#  'instrument_name': 'KAST',
#  'groups': [{'created_at': '2020-10-21T06:20:33.841974',
#    'single_user_group': True,
#    'nickname': None,
#    'id': 13,
#    'modified': '2020-10-21T06:20:33.841974',
#    'private': False,
#    'name': 'fremling'},
#   {'created_at': '2020-10-21T06:20:34.429576',
#    'single_user_group': False,
#    'nickname': 'rcf',
#    'id': 41,
#    'modified': '2020-10-21T06:20:34.429576',
#    'private': False,
#    'name': 'Redshift Completeness Factor'},
#   {'created_at': '2020-10-21T06:20:34.462803',
#    'single_user_group': False,
#    'nickname': 'clu',
#    'id': 43,
#    'modified': '2020-10-21T06:20:34.462803',
#    'private': False,
#    'name': 'Census of the Local Universe Caltech'},
#   {'created_at': '2020-11-25T02:01:38.504176',
#    'single_user_group': False,
#    'nickname': 'au-caltech',
#    'id': 214,
#    'modified': '2020-11-25T02:01:38.504176',
#    'private': False,
#    'name': 'Treasures Caltech'}],
#  'reducers': [],
#  'observers': [],
#  'owner': {'id': 13,
#   'created_at': '2020-10-21T06:20:33.841974',
#   'modified': '2021-04-08T19:26:08.990836',
#   'username': 'fremling',
#   'first_name': 'Ulf-Christoffer',
#   'last_name': 'Fremling',
#   'contact_email': 'fremling@caltech.edu',
#   'contact_phone': None,
#   'oauth_uid': 'fremling@caltech.edu'}}

# %%
get_all_spectra_id('ZTF21aagsxeo')
# Out:
# [1650]

# %%
def get_TNS_classification_ID(classification):    

    class_ids = {'Afterglow':23, 'AGN':29, 'CV':27, 'Galaxy':30, 'Gap':60, 'Gap I':61, 'Gap II':62, 'ILRT':25, 'Kilonova':70, 'LBV':24,'M dwarf':210, 'Nova':26, 'Novae':26, 'QSO':31, 'SLSN-I':18, 'Ic-SLSN':18, 'SLSN-II':19, 'SLSN-R':20, 'SN':1, 'I':2, 'Type I':2, 'I-faint':15, 'I-rapid':16, 'Ia':3, 'Ia-norm':3, 'Ia-91bg':103,'Ia-91T':104, 'Ia-CSM':106, 'Ia-pec':100, 'Ia-SC':102, 'Ia-02cx':105,
                'Ib':4, 'Ib-norm':4, 'Ib-Ca-rich':8, 'Ib-pec':107, 'Ib/c':6, 'SN Ibn':9, 'Ibn':9, 'Ic':5, 'Ic-norm':5, 'Ic-BL':7, 'Ic-pec':108, 'II':10, 'Type II':10, 'II-norm':10,
                'II-pec':110, 'IIb':14, 'IIL':12, 'IIn':13, 'IIn-pec':112, 'IIP':11, 'SN impostor':99, 'Std-spec':50, 'TDE':120,
                'Varstar':28, 'WR':200, 'WR-WC':202, 'WR-WN':201, 'WR-WO':203, 'Other':0}
    
    #keys = np.array(class_ids.keys())
    for keys in class_ids:
        if (keys == classification):
            classkey = class_ids[keys]
            return classkey

# %%
def get_TNS_instrument_ID(classification):

    inst_ids = {'DBSP':1, 'ALFOSC': 41, 'LRIS': 3, 'DIS': 70, 'SEDM': 149, 'SPRAT': 156, 'GMOS': 6, 'KAST': 10, 'LFC': 2, 'TSPEC': 109}

    #keys = np.array(class_ids.keys())
    for keys in inst_ids:
        if (keys == inst):
            instkey = inst_ids[keys]
            return instkey

# %%
class TNSClassificationReport:
    def __init__(self):
        self.name = ''
        self.fitsName = ''
        self.asciiName = ''
        self.classifierName = ''
        self.classificationID = ''
        self.redshift = ''
        self.classificationComments = ''
        self.obsDate = ''
        self.instrumentID = ''
        self.expTime = ''
        self.observers = ''
        self.reducers = ''
        self.specTypeID = ''
        self.spectrumComments = ''
        self.groupID = ''
        self.spec_proprietary_period_value = ''
        self.spec_proprietary_period_units = ''

    def classificationDict(self):
        classificationDict =  {
            'classification_report' : {
                '0' : {
                    'name' : self.name,
                    'classifier' : self.classifierName,
                    'objtypeid' : self.classificationID,
                    'redshift': self.redshift,
                    'groupid' : self.groupID,
                    'remarks' : self.classificationComments,
                    'spectra' : {
                        'spectra-group' : {
                            '0' : {
                                'obsdate' : self.obsDate,
                                'instrumentid' : self.instrumentID,
                                'exptime' : self.expTime,
                                'observer' : self.observers,
                                'reducer' : self.reducers,
                                'spectypeid' : self.specTypeID,
                                'ascii_file' : self.asciiName,
                                'fits_file' : self.fitsName,
                                'remarks' : self.spectrumComments,
                                'spec_proprietary_period' : {
                                    'spec_proprietary_period_value' : self.spec_proprietary_period_value,
                                    'spec_proprietary_period_units' : self.spec_proprietary_period_units
                                }
                            }
                        }
                    }
                }
            }
        }
        return classificationDict

    def classificationJson(self):
        return json.dumps(self.classificationDict())

# %%
def upload_to_TNS(filename, base_url = upload_url, api_key = API_KEY, filetype='ascii'):
    
    """
    uploads a file to TNS and returns the response json
    """
    url = base_url
    data = {'api_key' : api_key}

    if filetype is 'ascii':
        files = [('files[]', (filename, open(filename), 'text/plain'))]

    elif filetype is 'fits':
        files = [('files[0]', (filename, open(filename, 'rb'),
                               'application/fits'))]

    if filename:
        response = requests.post(url, data=data, files=files)
        try:
            return response.json()
        except:
            print(url, data, files, response.content, sep='\n')
            return False
    else:
        return {}

# %%
def tns_classify(classificationReport, base_url= report_url, api_key=API_KEY):
    """
    submits classification report to TNS and returns the response json
    """
    url = base_url
    data = {'api_key' : api_key, 'data' : classificationReport.classificationJson()}
    response = requests.post(url, data=data).json()
    if not response:
        return False

    res_code = response['id_code']
    report_id = response['data']['report_id']
    print("ID:", report_id)
    print(res_code, response['id_message'], "reporting finished")
    if res_code == 200:
        return report_id
    else:
        print("Result reporting didn't work")
        pprint(response)
        print("re-submit classification, but don't re-upload files")
        return False

# %%
def tns_feedback(report_id):
    data = {'api_key': API_KEY, 'report_id': report_id}
    
    response = requests.post(reply_url, data=data).json()
    
    feedback_code = response['id_code']
    print(feedback_code, response['id_message'], "feedback finished")
    if feedback_code == 200:
        return True
    elif feedback_code == 404:
        print("Waiting and retrying...")
        sleep(2)
        try:
            return tns_feedback(report_id)
        except KeyboardInterrupt:
            return False
    elif feedback_code == 400:
        print(response)
        return False
    else:
        # error receiving the feedback from TNS about the upload
        print("Something went wrong with the feedback, but the report may",
              "still have been fine?")
        return False

# %%
def get_number(group_id, date):
    ''' Info : Query number of sources saved in a group after a certain date
        Input : group id, date [yyyy-mm-dd]
        Returns : Number of sources saved after a given date to the specified group
    '''
    
    url = BASEURL+'api/sources?saveSummary=true&group_ids='+group_id+'&savedAfter='+date+'T00:00:00.000001'
    response = api('GET',url)
    return len(response['data']['sources'])



def get_sources(group_id, date):
    ''' Info : Query all sources saved in a group after a certain date
        Input : group id, date [yyyy-mm-dd]
        Returns : List of jsons of all sources in group(s)
        Comment : Takes a little time based on the date
    '''
    
    sources = []
    
    for i in range (get_number(group_id, date)):
    
        url = BASEURL+'api/sources?saveSummary=true&group_ids='+group_id+'&savedAfter='+date+'T00:00:00.000001'
        response = api('GET',url)
        ztfname = response['data']['sources'][i]['obj_id']
        sources.append(ztfname)
        
    return sources

def downloadfritzascii(outfile):
    
    date = '2020-11-06' #Specify the date from which you want to check the saved sources
    
    path = 'https://fritz.science/api/sources?group_ids=41&saveSummary=true&savedAfter='+date+'T00:00:00.000001'
 
    response = api('GET',path)
    
    srcs = []
    dates = []
    
    listdir = os.getcwd()
    f = open (listdir+'/'+outfile+'.ascii','w')
    f.write('col1'+'\t'+'col2'+'\n')
    
    for i in range (get_number('41', date)):
        
        source_name = response['data']['sources'][i]['obj_id']
        saved_date = response['data']['sources'][i]['saved_at']
        
        srcs.append(source_name)
        dates.append(saved_date.split('T')[0])
            
    
    #sorted_dates = sorted(dates, reverse = True)
    #Sources = [x for _,x in sorted(zip(dates,srcs), reverse=True)]
    
    output = sorted(zip(dates, srcs), reverse=True)
    
    for i in range (get_number('41', date)):
    
        f.write(output[i][1]+'\t'+output[i][0]+'\n')
        
    f.close()
        
    return

# %%
#downloadfritzascii('RCF_sources') #download the updated list of sources saved to RCF in descending order

#f = ascii.read("RCF_sources_copy.ascii") #ascii file containing the names of sources and their saved dates
#sources = f['col1']

sources = ['ZTF21aaxhzru', 'ZTF21aawzsew', 'ZTF21aavuprl', 'ZTF21aartgiv']
           
           
           
for source in sources:
    
    flag = 0
    ztfname = source
    
    for i in range (len(get_source_api(source)['comments'])):
        
        comment = get_source_api(source)['comments'][i]['text']
        
        if comment == 'Uploaded to TNS':
            flag = 1
        
    if flag == 0:
        
        info = get_TNS_information(ztfname)
        
        if info[2] == 'Not classified yet':         #Check if classified
            flag =1
            continue  


        a,b = (info[2]).split(',', 1)               #This is just to get the classification date
        c,d = b.split(':', 1)
        e,class_date = d.split(' ', 1)


        k,l = (info[2]).split(':', 1)               #This is just to get the classification
        m,n = l.split(',', 1)
        o,classify = m.split(' ', 1)

        print (classify, class_date)


        print (info, '\n')
        print ("Do you want to proceed with the report?")

        user_input = input("y/n: ")

        if user_input == 'y':

            spectrum_info = write_ascii_file(ztfname) #returns "spectrum_name"

            spectrum_name = spectrum_info[0]

            if spectrum_name == 'No Spectra Found':
                flag = 1
                continue

            if flag == 0:

                path = os.getcwd()

                specfile = (path+'/data/'+spectrum_name)

                files = specfile

                specid = spectrum_info[1]

                a = get_spectrum_api(specid)

                inst = (a['data']['instrument_name'])


                if inst == 'SEDM':

                    classifiers = 'A. Dahiwale, C. Fremling(Caltech) on behalf of the Zwicky Transient Facility (ZTF)'### Change accordingly
                    source_group = 48 ### Require source group id from drop down list, 0 is for None
                    spectypes = np.array(['object','host','sky','arcs','synthetic'])

                    #proprietary_period = int(input("Proprietary period in years:", x)
                    proprietary_period = '0'
                    proprietary_units = "years"
                    spec_comments =''
                    classification_comments = ''
                    spectype='object'
                    spectype_id = ['object', 'host', 'sky', 'arcs', 'synthetic'].index(spectype) + 1

                    header = (a['data']['altdata'])
                    obsdate = str((header['UTC']).split('T')[0])+' '+str((header['UTC']).split('T')[1])

                    classificationReport = TNSClassificationReport()
                    classificationReport.name = get_IAUname(ztfname)[0]['name'][3:]  
                    classificationReport.fitsName = ''
                    classificationReport.asciiName = spectrum_name
                    classificationReport.classifierName = classifiers
                    classificationReport.classificationID = get_TNS_classification_ID(classify)
                    classificationReport.redshift = get_redshift(ztfname)
                    classificationReport.classificationComments = classification_comments
                    classificationReport.obsDate = obsdate
                    classificationReport.instrumentID = get_TNS_instrument_ID(inst)
                    classificationReport.expTime = (header['EXPTIME'])
                    classificationReport.observers = 'SEDmRobot'
                    classificationReport.reducers = (header['REDUCER'])
                    classificationReport.specTypeID = spectype_id
                    classificationReport.spectrumComments = spec_comments
                    classificationReport.groupID = source_group
                    classificationReport.spec_proprietary_period_value = proprietary_period
                    classificationReport.spec_proprietary_period_units = proprietary_units
                    print(classificationReport.classificationDict())

                    #pprint(classificationReport.fill(), tab='  ')
                    proceed = input("\nProceed with classification and upload? ([y]/n) : ")
                    if proceed == 'y' and not proceed.strip() == '':

                        # ASCII FILE UPLOAD
                        print ("\n")
                        response = upload_to_TNS(files)
                        print (response)

                        if not response:
                            print("File upload didn't work")
                            print(response)
                            #return False

                        print(response['id_code'], response['id_message'],
                              "\nSuccessfully uploaded ascii spectrum")
                        #classificationReport.asciiName = response['data'][-1]

                        report_id = tns_classify(classificationReport)
                        post_comment(ztfname, 'Uploaded to TNS')
                        tns_feedback(report_id)


                if inst == 'SPRAT':

                    classifiers = 'D. A. Perley, K. Taggart (LJMU), A. Dahiwale, C. Fremling (Caltech) on behalf of the Zwicky Transient Facility (ZTF)'### Change accordingly
                    source_group = 48 ### Require source group id from drop down list, 0 is for None
                    spectypes = np.array(['object','host','sky','arcs','synthetic'])

                    #proprietary_period = int(input("Proprietary period in years:", x)
                    proprietary_period = '0'
                    proprietary_units = "years"
                    spec_comments =''
                    classification_comments = ''
                    spectype='object'
                    spectype_id = ['object', 'host', 'sky', 'arcs', 'synthetic'].index(spectype) + 1

                    header = (a['data']['altdata'])
                    obsdate = str(header['OBSDATE'].split('T')[0])+' '+str(header['OBSDATE'].split('T')[1])

                    classificationReport = TNSClassificationReport()
                    classificationReport.name = get_IAUname(ztfname)[0]['name'][3:] 
                    classificationReport.fitsName = ''
                    classificationReport.asciiName = spectrum_name
                    classificationReport.classifierName = classifiers
                    classificationReport.classificationID = get_TNS_classification_ID(classify)
                    classificationReport.redshift = get_redshift(ztfname)
                    classificationReport.classificationComments = classification_comments
                    classificationReport.obsDate = obsdate
                    classificationReport.instrumentID = get_TNS_instrument_ID(inst)
                    classificationReport.expTime = (header['EXPTIME'])
                    classificationReport.observers = 'LTRobot'
                    classificationReport.reducers = 'D. Perley'
                    classificationReport.specTypeID = spectype_id
                    classificationReport.spectrumComments = spec_comments
                    classificationReport.groupID = source_group
                    classificationReport.spec_proprietary_period_value = proprietary_period
                    classificationReport.spec_proprietary_period_units = proprietary_units
                    print(classificationReport.classificationDict())

                    #pprint(classificationReport.fill(), tab='  ')
                    proceed = input("\nProceed with classification and upload? ([y]/n) : ")
                    if proceed == 'y' and not proceed.strip() == '':

                        # ASCII FILE UPLOAD
                        print ("\n")
                        response = upload_to_TNS(files)
                        print (response)

                        if not response:
                            print("File upload didn't work")
                            print(response)
                            #return False

                        print(response['id_code'], response['id_message'],
                              "\nSuccessfully uploaded ascii spectrum")
                        #classificationReport.asciiName = response['data'][-1]

                        report_id = tns_classify(classificationReport)
                        post_comment(ztfname, 'Uploaded to TNS')
                        tns_feedback(report_id)



                if inst == 'ALFOSC':

                    classifiers = 'A. Dahiwale, C. Fremling(Caltech) on behalf of the Zwicky Transient Facility (ZTF)'### Change accordingly
                    source_group = 48 ### Require source group id from drop down list, 0 is for None
                    spectypes = np.array(['object','host','sky','arcs','synthetic'])

                    #proprietary_period = int(input("Proprietary period in years:", x)
                    proprietary_period = '0'
                    proprietary_units = "years"
                    spec_comments =''
                    classification_comments = ''
                    spectype='object'
                    spectype_id = ['object', 'host', 'sky', 'arcs', 'synthetic'].index(spectype) + 1

                    header = (a['data']['altdata'])
                    obsdate = str(a['data']['observed_at'].split('T')[0])+' '+str(a['data']['observed_at'].split('T')[1])

                    classificationReport = TNSClassificationReport()
                    classificationReport.name = get_IAUname(ztfname)[0]['name'][3:]  
                    classificationReport.fitsName = ''
                    classificationReport.asciiName = spectrum_name
                    classificationReport.classifierName = classifiers
                    classificationReport.classificationID = get_TNS_classification_ID(classify)
                    classificationReport.redshift = get_redshift(ztfname)
                    classificationReport.classificationComments = classification_comments
                    classificationReport.obsDate = obsdate
                    classificationReport.instrumentID = get_TNS_instrument_ID(inst)
                    classificationReport.expTime = (header['EXPTIME'])
                    classificationReport.observers = (str(a['data']['observers'][0]['first_name'])+' '+str(a['data']['observers'][0]['last_name']))
                    classificationReport.reducers = (str(a['data']['reducers'][0]['first_name'])+' '+str(a['data']['reducers'][0]['last_name']))
                    classificationReport.specTypeID = spectype_id
                    classificationReport.spectrumComments = spec_comments
                    classificationReport.groupID = source_group
                    classificationReport.spec_proprietary_period_value = proprietary_period
                    classificationReport.spec_proprietary_period_units = proprietary_units
                    print(classificationReport.classificationDict())

                    #pprint(classificationReport.fill(), tab='  ')
                    proceed = input("\nProceed with classification and upload? ([y]/n) : ")
                    if proceed == 'y' and not proceed.strip() == '':

                        # ASCII FILE UPLOAD
                        print ("\n")
                        response = upload_to_TNS(files)
                        print (response)

                        if not response:
                            print("File upload didn't work")
                            print(response)
                            #return False

                        print(response['id_code'], response['id_message'],
                              "\nSuccessfully uploaded ascii spectrum")
                        #classificationReport.asciiName = response['data'][-1]

                        report_id = tns_classify(classificationReport)
                        post_comment(ztfname, 'Uploaded to TNS')
                        tns_feedback(report_id)



                if inst == 'DBSP':

                    classifiers = 'A. Dahiwale, C. Fremling(Caltech) on behalf of the Zwicky Transient Facility (ZTF)'### Change accordingly
                    source_group = 48 ### Require source group id from drop down list, 0 is for None
                    spectypes = np.array(['object','host','sky','arcs','synthetic'])

                    #proprietary_period = int(input("Proprietary period in years:", x)
                    proprietary_period = '0'
                    proprietary_units = "years"
                    spec_comments =''
                    classification_comments = ''
                    spectype='object'
                    spectype_id = ['object', 'host', 'sky', 'arcs', 'synthetic'].index(spectype) + 1

                    OBSDATE = str(a['data']['observed_at'].split('T')[0])+' '+str(a['data']['observed_at'].split('T')[1])

                    classificationReport = TNSClassificationReport()
                    classificationReport.name = get_IAUname(ztfname)[0]['name'][3:]  
                    classificationReport.fitsName = ''
                    classificationReport.asciiName = spectrum_name
                    classificationReport.classifierName = classifiers
                    classificationReport.classificationID = get_TNS_classification_ID(classify)
                    classificationReport.redshift = get_redshift(ztfname)
                    classificationReport.classificationComments = classification_comments
                    classificationReport.obsDate = OBSDATE
                    classificationReport.instrumentID = get_TNS_instrument_ID(inst)
                    classificationReport.expTime = '450'
                    classificationReport.observers = (str(a['data']['observers'][0]['first_name'])+' '+str(a['data']['observers'][0]['last_name']))
                    classificationReport.reducers = (str(a['data']['reducers'][0]['first_name'])+' '+str(a['data']['reducers'][0]['last_name']))
                    classificationReport.specTypeID = spectype_id
                    classificationReport.spectrumComments = spec_comments
                    classificationReport.groupID = source_group
                    classificationReport.spec_proprietary_period_value = proprietary_period
                    classificationReport.spec_proprietary_period_units = proprietary_units
                    print(classificationReport.classificationDict())

                    #pprint(classificationReport.fill(), tab='  ')
                    proceed = input("\nProceed with classification and upload? ([y]/n) : ")
                    if proceed == 'y' and not proceed.strip() == '':

                        # ASCII FILE UPLOAD
                        print ("\n")
                        response = upload_to_TNS(files)
                        print (response)

                        if not response:
                            print("File upload didn't work")
                            print(response)
                            #return False

                        print(response['id_code'], response['id_message'],
                              "\nSuccessfully uploaded ascii spectrum")
                        #classificationReport.asciiName = response['data'][-1]

                        report_id = tns_classify(classificationReport)
                        post_comment(ztfname, 'Uploaded to TNS')
                        tns_feedback(report_id)  


                if inst == 'LRIS':

                    classifiers = 'A. Dahiwale, C. Fremling(Caltech) on behalf of the Zwicky Transient Facility (ZTF)'### Change accordingly
                    source_group = 48 ### Require source group id from drop down list, 0 is for None
                    spectypes = np.array(['object','host','sky','arcs','synthetic'])

                    header = (a['data']['altdata'])

                    #proprietary_period = int(input("Proprietary period in years:", x)
                    proprietary_period = '0'
                    proprietary_units = "years"
                    spec_comments =''
                    classification_comments = ''
                    spectype='object'
                    spectype_id = ['object', 'host', 'sky', 'arcs', 'synthetic'].index(spectype) + 1

                    OBSDATE = str(a['data']['observed_at'].split('T')[0])+' '+str(a['data']['observed_at'].split('T')[1])

                    classificationReport = TNSClassificationReport()
                    classificationReport.name = get_IAUname(ztfname)[0]['name'][3:]  
                    classificationReport.fitsName = ''
                    classificationReport.asciiName = spectrum_name
                    classificationReport.classifierName = classifiers
                    classificationReport.classificationID = get_TNS_classification_ID(classify)
                    classificationReport.redshift = get_redshift(ztfname)
                    classificationReport.classificationComments = classification_comments
                    classificationReport.obsDate = OBSDATE
                    classificationReport.instrumentID = get_TNS_instrument_ID(inst)
                    #classificationReport.expTime = '300'
                    classificationReport.observers = (str(a['data']['observers'][0]['first_name'])+' '+str(a['data']['observers'][0]['last_name']))
                    classificationReport.reducers = (str(a['data']['reducers'][0]['first_name'])+' '+str(a['data']['reducers'][0]['last_name']))
                    classificationReport.specTypeID = spectype_id
                    classificationReport.spectrumComments = spec_comments
                    classificationReport.groupID = source_group
                    classificationReport.spec_proprietary_period_value = proprietary_period
                    classificationReport.spec_proprietary_period_units = proprietary_units
                    print(classificationReport.classificationDict())

                    #pprint(classificationReport.fill(), tab='  ')
                    proceed = input("\nProceed with classification and upload? ([y]/n) : ")
                    if proceed == 'y' and not proceed.strip() == '':

                        # ASCII FILE UPLOAD
                        print ("\n")
                        response = upload_to_TNS(files)
                        print (response)

                        if not response:
                            print("File upload didn't work")
                            print(response)
                            #return False

                        print(response['id_code'], response['id_message'],
                              "\nSuccessfully uploaded ascii spectrum")
                        #classificationReport.asciiName = response['data'][-1]

                        report_id = tns_classify(classificationReport)
                        post_comment(ztfname, 'Uploaded to TNS')
                        tns_feedback(report_id)  


                if inst == 'DIS':

                    classifiers = 'Melissa L. Graham (UW), A. Dahiwale, C. Fremling(Caltech) on behalf of the Zwicky Transient Facility (ZTF)'### Change accordingly
                    source_group = 48 ### Require source group id from drop down list, 0 is for None
                    spectypes = np.array(['object','host','sky','arcs','synthetic'])
                    #proprietary_period = int(input("Proprietary period in years:", x)
                    proprietary_period = '0'
                    proprietary_units = "years"
                    spec_comments =''
                    classification_comments = ''
                    spectype='object'
                    spectype_id = ['object', 'host', 'sky', 'arcs', 'synthetic'].index(spectype) + 1

                    #obsdate = APO(specid)[0]  
                    #exptime = APO(specid)[1]
                    #observers = APO(specid)[2]
                    #reducers = APO(specid)[3]

                    obsdate = str(a['data']['observed_at'].split('T')[0])+' '+str(a['data']['observed_at'].split('T')[1])

                    classificationReport = TNSClassificationReport()
                    classificationReport.name = get_IAUname(ztfname)[0]['name'][3:]  
                    classificationReport.fitsName = ''
                    classificationReport.asciiName = spectrum_name
                    classificationReport.classifierName = classifiers
                    classificationReport.classificationID = get_TNS_classification_ID(classify)
                    classificationReport.redshift = get_redshift(ztfname)
                    classificationReport.classificationComments = classification_comments
                    classificationReport.obsDate = obsdate
                    classificationReport.instrumentID = get_TNS_instrument_ID(inst)
                    #classificationReport.expTime = exptime
                    #classificationReport.observers = observers
                    #classificationReport.reducers = reducers
                    classificationReport.observers = (str(a['data']['observers'][0]['first_name'])+' '+str(a['data']['observers'][0]['last_name']))
                    classificationReport.reducers = (str(a['data']['reducers'][0]['first_name'])+' '+str(a['data']['reducers'][0]['last_name']))
                    classificationReport.specTypeID = spectype_id
                    classificationReport.spectrumComments = spec_comments
                    classificationReport.groupID = source_group
                    classificationReport.spec_proprietary_period_value = proprietary_period
                    classificationReport.spec_proprietary_period_units = proprietary_units
                    print(classificationReport.classificationDict())

                    #pprint(classificationReport.fill(), tab='  ')
                    proceed = input("\nProceed with classification and upload? ([y]/n) : ")
                    if proceed == 'y' and not proceed.strip() == '':

                        #ASCII FILE UPLOAD
                        print ("\n")
                        response = upload_to_TNS(files)
                        print (response)

                        if not response:
                            print("File upload didn't work")
                            print(response)
                            #return False

                        print(response['id_code'], response['id_message'],
                              "\nSuccessfully uploaded ascii spectrum")
                        #classificationReport.asciiName = response['data'][-1]

                        report_id = tns_classify(classificationReport)
                        tns_feedback(report_id)
                        post_comment(ztfname, 'Uploaded to TNS')
                        
                        
                if inst == 'KAST':

                    #classifiers = 'Thomas G. Brink, Kishore C. Patra, Thomas de Jaeger, WeiKang Zheng, Benjamin E. Stahl, Alexei V. Filippenko (UC Berkeley), A. Dahiwale, C. Fremling (Caltech) on behalf of the Zwicky Transient Facility (ZTF)'### Change accordingly
                    #classifiers = 'A. Dahiwale, C. Fremling(Caltech) on behalf of the Zwicky Transient Facility (ZTF)'### Change accordingly
                    source_group = 48 ### Require source group id from drop down list, 0 is for None
                    spectypes = np.array(['object','host','sky','arcs','synthetic'])
                    #proprietary_period = int(input("Proprietary period in years:", x)
                    proprietary_period = '0'
                    proprietary_units = "years"
                    spec_comments =''
                    classification_comments = ''
                    spectype='object'
                    spectype_id = ['object', 'host', 'sky', 'arcs', 'synthetic'].index(spectype) + 1


                    obsdate = str(a['data']['observed_at'].split('T')[0])+' '+str(a['data']['observed_at'].split('T')[1])

                    classificationReport = TNSClassificationReport()
                    classificationReport.name = get_IAUname(ztfname)[0]['name'][3:]  
                    classificationReport.fitsName = ''
                    classificationReport.asciiName = spectrum_name
                    classificationReport.classifierName = classifiers
                    classificationReport.classificationID = get_TNS_classification_ID(classify)
                    classificationReport.redshift = get_redshift(ztfname)
                    classificationReport.classificationComments = classification_comments
                    classificationReport.obsDate = obsdate
                    classificationReport.instrumentID = get_TNS_instrument_ID(inst)
                    #classificationReport.expTime = exptime
                    classificationReport.observers = 'Mike Rich'
                    classificationReport.reducers = 'Mike Rich'
                    #classificationReport.observers = (str(a['data']['observers'][0]['first_name'])+' '+str(a['data']['observers'][0]['last_name']))
                    #classificationReport.reducers = (str(a['data']['reducers'][0]['first_name'])+' '+str(a['data']['reducers'][0]['last_name']))
                    classificationReport.specTypeID = spectype_id
                    classificationReport.spectrumComments = spec_comments
                    classificationReport.groupID = source_group
                    classificationReport.spec_proprietary_period_value = proprietary_period
                    classificationReport.spec_proprietary_period_units = proprietary_units
                    print(classificationReport.classificationDict())

                    #pprint(classificationReport.fill(), tab='  ')
                    proceed = input("\nProceed with classification and upload? ([y]/n) : ")
                    if proceed == 'y' and not proceed.strip() == '':

                        #ASCII FILE UPLOAD
                        print ("\n")
                        response = upload_to_TNS(files)
                        print (response)

                        if not response:
                            print("File upload didn't work")
                            print(response)
                            #return False

                        print(response['id_code'], response['id_message'],
                              "\nSuccessfully uploaded ascii spectrum")
                        #classificationReport.asciiName = response['data'][-1]

                        report_id = tns_classify(classificationReport)
                        tns_feedback(report_id)
                        post_comment(ztfname, 'Uploaded to TNS')
                        
                        #print('deleting files now')
                        #call(['rm', all_info['asciifile']])
# Out:
# Ic-BL 2021-04-30
# ('ZTF21aartgiv', 'AT 2021hyz', 'Classification: Ic-BL, Classification date: 2021-04-30', 'redshift:0.0461')
#
# Do you want to proceed with the report?
# y/n: y
# Please choose from the following spectra:
#
# 1 ) spectrum name:  None spectrum date: 2020-04-16
# 2 ) spectrum name:  spec_auto_contsep_lstep1__crr_b_ifu20210405_08_44_42_ZTF21aartgiv.txt spectrum date: 2021-04-05
# 3 ) spectrum name:  spec_auto_robot_lstep1__crr_b_ifu20210405_08_44_42_ZTF21aartgiv.txt spectrum date: 2021-04-05
# 4 ) spectrum name:  spec_auto_robot_lstep1__crr_b_ifu20210407_08_41_16_ZTF21aartgiv.txt spectrum date: 2021-04-07
# 5 ) spectrum name:  spec_auto_robot_lstep1__crr_b_ifu20210415_04_17_49_ZTF21aartgiv.txt spectrum date: 2021-04-15
# 6 ) spectrum name:  spec_auto_robot_lstep1__crr_b_ifu20210430_03_59_03_ZTF21aartgiv.txt spectrum date: 2021-04-30
# Choose spectrum to upload: 6
# {'classification_report': {'0': {'name': '2021hyz', 'classifier': 'A. Dahiwale, C. Fremling(Caltech) on behalf of the Zwicky Transient Facility (ZTF)', 'objtypeid': 7, 'redshift': 0.0461, 'groupid': 48, 'remarks': '', 'spectra': {'spectra-group': {'0': {'obsdate': '2021-04-30 03:59:03.657565', 'instrumentid': 149, 'exptime': 2700.0, 'observer': 'SEDmRobot', 'reducer': 'auto', 'spectypeid': 1, 'ascii_file': 'ZTF21aartgiv_2021-04-30_SEDM.ascii', 'fits_file': '', 'remarks': '', 'spec_proprietary_period': {'spec_proprietary_period_value': '0', 'spec_proprietary_period_units': 'years'}}}}}}}
#
# Proceed with classification and upload? ([y]/n) : y
#
#
# {'id_code': 200, 'id_message': 'OK', 'data': ['ZTF21aartgiv_2021-04-30_SEDM.ascii']}
# 200 OK
# Successfully uploaded ascii spectrum
# ID: 71972
# 200 OK reporting finished
# 200 OK feedback finished

# %%
def get_new_classification(ztfname):
                        
    ''' Info : Query the classification and classification date for any source
        Input : ZTFname
        Returns : Classification and Classification date
        Comment : You need to choose the classification if there are multiple classifications
    '''
    try:
        
        url = BASEURL+'api/sources/'+ztfname+'/classifications'
        response = api('GET',url)
        output = response['data']

        if (len(output)< 1):
            classification = "Not Classified"
            classification_date = "None"

        if (len(output) >= 1):

            classification = response['data'][(len(output)-1)]['classification']  
            classification_date = response['data'][(len(output)-1)]['created_at']
            
    except KeyError as e:
        classification = "Error"
        classification_date = "Error"
        
    return classification, classification_date

def get_new_IAUname(ztfname):
    
    ''' Info : Query the TNS name for any source
        Input : ZTFname
        Returns : ATname
    '''
    try:
        
        url = BASEURL+'api/alerts_aux/'+ztfname
        response = api('GET',url)
        IAU = response['data']['cross_matches']['TNS']
 
        
        if not IAU:
            IAU = "Not reported to TNS"

        else:   
            IAU = IAU[0]['name']

    except KeyError as e:
        IAU = "Error"
        
    return IAU


def get_number(group_id, date):
    ''' Info : Query number of sources saved in a group after a certain date
        Input : group id, date [yyyy-mm-dd]
        Returns : Number of sources saved after a given date to the specified group
    '''
    
    url = BASEURL+'api/sources?saveSummary=true&group_ids='+group_id+'&savedAfter='+date+'T00:00:00.000001'
    response = api('GET',url)
    return len(response['data']['sources'])



def get_sources(group_id, date):
    ''' Info : Query all sources saved in a group after a certain date
        Input : group id, date [yyyy-mm-dd]
        Returns : List of jsons of all sources in group(s)
        Comment : Takes a little time based on the date
    '''
    
    sources = []
    
    for i in range (get_number(group_id, date)):
    
        url = BASEURL+'api/sources?saveSummary=true&group_ids='+group_id+'&savedAfter='+date+'T00:00:00.000001'
        response = api('GET',url)
        ztfname = response['data']['sources'][i]['obj_id']
        sources.append(ztfname)
        
    return sources

def get_comment(ztfname):
    
    flag = 0
    
    for i in range (len(get_source_api(ztfname)['comments'])):
    
        TNS_comment = get_source_api(ztfname)['comments'][i]['text']

        if TNS_comment == 'Uploaded to TNS':
            comment = 'Yes'
            flag = 1
            
            
    if flag == 0:
        comment = 'No'
            
    return comment

# %%
def sourceclassification(outfile):
    
    dat = '2020-11-06' #Specify the date from which you want to check the saved sources
    #dat = '2021-01-10'
    path = 'https://fritz.science/api/sources?group_ids=41&saveSummary=true&savedAfter='+dat+'T00:00:00.000001'
 
    response = api('GET',path)
    
    srcs = []
    dates = []
    classify = []
    class_date = []
    TNS = []
    
    #annotation = []
    
    listdir = os.getcwd()
    f = open (listdir+'/'+outfile+'.ascii','w')
    f.write('Source Name'+'\t'+'TNS Name'+'\t'+'Saved Date'+'\t'+'Classification'+'\t'+'Classification Date'+'\n')
    
    for i in range (get_number('41', dat)):
            
        source_name = response['data']['sources'][i]['obj_id']
        saved_date = response['data']['sources'][i]['saved_at']
        classification = get_new_classification(source_name)[0]
        date = get_new_classification(source_name)[1]
        IAU = get_new_IAUname(source_name)
        
        #fritz_comment = get_comment(source_name)
            
        print (i, source_name)

        srcs.append(source_name)
        TNS.append(IAU)
        dates.append(saved_date.split('T')[0])
        classify.append(classification)
        class_date.append(date.split('T')[0])
        
        #annotation.append(fritz_comment)

        
    output = sorted(zip(class_date, srcs, TNS, dates, classify), reverse=True)
    #output = sorted(zip(class_date, srcs, dates, classify), reverse=True)

    for i in range (get_number('41', dat)):

        f.write(output[i][1]+'\t'+output[i][2]+'\t'+output[i][3]+'\t'+output[i][4]+'\t'+output[i][0]+'\n')
        #f.write(output[i][1]+'\t'+output[i][2]+'\t'+output[i][3]+'\t'+output[i][0]+'\n')

    f.close()
        
    return

# %%
sourceclassification('classification_0430')
# Out:
# 0 ZTF18abtoued
# 1 ZTF20acmzfsz
# 2 ZTF20acoxmsr
# 3 ZTF20acoanlv
# 4 ZTF20acivqxo
# 5 ZTF20acmgrda
# 6 ZTF20acpbboa
# 7 ZTF18aahjbii
# 8 ZTF20acpevli
# 9 ZTF20acpgnsn
# 10 ZTF20acpgnej
# 11 ZTF18adhzhfw
# 12 ZTF20acozxxt
# 13 ZTF19aanbpus
# 14 ZTF18abrfccm
# 15 ZTF20acpdrab
# 16 ZTF19aczeomw
# 17 ZTF20acggkic
# 18 ZTF19acvieqw
# 19 ZTF20aclkdlu
# 20 ZTF20aboquuv
# 21 ZTF20acgcice
# 22 ZTF20abupbub
# 23 ZTF20abvyare
# 24 ZTF20abzcfqn
# 25 ZTF20acjynpx
# 26 ZTF20abzpxxu
# 27 ZTF20acegtsw
# 28 ZTF20acinuir
# 29 ZTF20abyjoxb
# 30 ZTF20abwifwx
# 31 ZTF20aclmssm
# 32 ZTF20acnvprg
# 33 ZTF20acouofb
# 34 ZTF20abzeynv
# 35 ZTF20achdusl
# 36 ZTF20acgyvgs
# 37 ZTF20acpjlon
# 38 ZTF20acopmey
# 39 ZTF20acjryhf
# 40 ZTF20acfmxbj
# 41 ZTF20acounqo
# 42 ZTF20acmcqwc
# 43 ZTF20acpcuwx
# 44 ZTF20aciuakq
# 45 ZTF20acazpve
# 46 ZTF20acfaonm
# 47 ZTF20acoykif
# 48 ZTF20acpbnzr
# 49 ZTF20acpgvef
# 50 ZTF20acordqz
# 51 ZTF20acoyyly
# 52 ZTF20acgzjmh
# 53 ZTF20acphbem
# 54 ZTF20acpjeiu
# 55 ZTF20acorjop
# 56 ZTF20acpiwrj
# 57 ZTF20acoxudw
# 58 ZTF20acpkled
# 59 ZTF20acphjfv
# 60 ZTF20acoawtj
# 61 ZTF20acoyvdg
# 62 ZTF20acovrzx
# 63 ZTF20acpkuvc
# 64 ZTF20acowpur
# 65 ZTF20acpqbfu
# 66 ZTF20acpppyu
# 67 ZTF20acpjodk
# 68 ZTF20acoredl
# 69 ZTF20acoxtxr
# 70 ZTF20acbccug
# 71 ZTF20acpkprl
# 72 ZTF20acpeldz
# 73 ZTF20acpgzif
# 74 ZTF20acpmgdz
# 75 ZTF20acphdbu
# 76 ZTF20acmgsfo
# 77 ZTF20acphvjk
# 78 ZTF20acoukep
# 79 ZTF20acpgokr
# 80 ZTF20acowuix
# 81 ZTF20acowata
# 82 ZTF20acpkqhq
# 83 ZTF20acpeyoo
# 84 ZTF20acpctbg
# 85 ZTF20acpujxl
# 86 ZTF20achuuaj
# 87 ZTF20abmthvt
# 88 ZTF20acjyepw
# 89 ZTF20acowsyj
# 90 ZTF20acpocys
# 91 ZTF20acqlcge
# 92 ZTF19abyjmei
# 93 ZTF20acptdpf
# 94 ZTF20aclwwhz
# 95 ZTF20acpgpen
# 96 ZTF20acptvww
# 97 ZTF20abxyayj
# 98 ZTF20acphcdv
# 99 ZTF20acqismu
# 100 ZTF20acpjapi
# 101 ZTF20acpvbbh
# 102 ZTF20acpkpla
# 103 ZTF20acpwjus
# 104 ZTF20acpyaap
# 105 ZTF19acwiqrc
# 106 ZTF20acpqagp
# 107 ZTF20acpkefi
# 108 ZTF20acquetr
# 109 ZTF20acpevlh
# 110 ZTF20acpbrxw
# 111 ZTF20acpuwbf
# 112 ZTF20acplqek
# 113 ZTF20acoyrlm
# 114 ZTF20acprmuv
# 115 ZTF20acpknjk
# 116 ZTF20acqfssi
# 117 ZTF20acqelhh
# 118 ZTF20acqilvj
# 119 ZTF20acprazr
# 120 ZTF20acpkjsn
# 121 ZTF20acqksdi
# 122 ZTF20acpjqxp
# 123 ZTF20acpprmy
# 124 ZTF20acpksoc
# 125 ZTF20acpkses
# 126 ZTF20acqjbrk
# 127 ZTF20acpjcoe
# 128 ZTF20acpiywu
# 129 ZTF20acoplqe
# 130 ZTF20acpjbgc
# 131 ZTF20acpjino
# 132 ZTF20acphccy
# 133 ZTF20acqntkr
# 134 ZTF20acqzjqz
# 135 ZTF20acpkzxq
# 136 ZTF20acplhku
# 137 ZTF20acqexmr
# 138 ZTF20acqnfzn
# 139 ZTF20acpxvez
# 140 ZTF20acmbhgy
# 141 ZTF20acijssu
# 142 ZTF20acllntr
# 143 ZTF20ackpjmb
# 144 ZTF20acpwlvw
# 145 ZTF19aamftgs
# 146 ZTF19abfrydu
# 147 ZTF20aatunbk
# 148 ZTF20aaukwib
# 149 ZTF19abgdcyx
# 150 ZTF19acmxvsa
# 151 ZTF20aarfmax
# 152 ZTF20aaspiic
# 153 ZTF19aarsact
# 154 ZTF20aauktau
# 155 ZTF19aciiuta
# 156 ZTF19aamoixn
# 157 ZTF19abgpydp
# 158 ZTF19aalbzik
# 159 ZTF19aamlihv
# 160 ZTF18acnbgrj
# 161 ZTF20aauomty
# 162 ZTF20aauonyt
# 163 ZTF20aauadsw
# 164 ZTF20acpxuvg
# 165 ZTF20abupuzr
# 166 ZTF19abqgxla
# 167 ZTF20abuvuel
# 168 ZTF19acnpnzw
# 169 ZTF20aauomdt
# 170 ZTF19acvfxgc
# 171 ZTF20aauoogx
# 172 ZTF19aamlkrd
# 173 ZTF19aalbzvm
# 174 ZTF20aauovyg
# 175 ZTF19abhowwd
# 176 ZTF20acgcoly
# 177 ZTF20aauqtle
# 178 ZTF20aauqkyy
# 179 ZTF20aaubkfu
# 180 ZTF19abhusrq
# 181 ZTF20aanmwtv
# 182 ZTF19acjijfr
# 183 ZTF19ackjnrh
# 184 ZTF20abvuqpb
# 185 ZTF19acmwioa
# 186 ZTF20aautuqz
# 187 ZTF20aavdwpb
# 188 ZTF20aavtfsw
# 189 ZTF20aavrqtf
# 190 ZTF20abstmwq
# 191 ZTF19acrwmcm
# 192 ZTF19aanevlu
# 193 ZTF18aaorexe
# 194 ZTF20abqyqcu
# 195 ZTF19acekeny
# 196 ZTF18aadvsxy
# 197 ZTF20aawfpvy
# 198 ZTF20aaxlznl
# 199 ZTF19aanrbqk
# 200 ZTF20aayhrea
# 201 ZTF20aayvycp
# 202 ZTF19acyndsh
# 203 ZTF19abjcghj
# 204 ZTF20abakgww
# 205 ZTF20aasjzci
# 206 ZTF20aaiacec
# 207 ZTF19aarupqs
# 208 ZTF20abdqqkj
# 209 ZTF18aczeral
# 210 ZTF18abmmfiy
# 211 ZTF20abyvbcu
# 212 ZTF20abjtcwp
# 213 ZTF20acgjria
# 214 ZTF20acgcasw
# 215 ZTF20abkwuxw
# 216 ZTF20aciwbbr
# 217 ZTF20aamdywf
# 218 ZTF19abvimhc
# 219 ZTF18acpspzy
# 220 ZTF20aaodhzr
# 221 ZTF20aarkdtk
# 222 ZTF19abrfroa
# 223 ZTF19aafmjfw
# 224 ZTF20abpqhjh
# 225 ZTF19aathapt
# 226 ZTF20abmdlng
# 227 ZTF18adbhlet
# 228 ZTF20abpliud
# 229 ZTF19acubsip
# 230 ZTF20abrbzjw
# 231 ZTF20aatpjja
# 232 ZTF20aasawks
# 233 ZTF19aaaplhu
# 234 ZTF20aaukvat
# 235 ZTF19aaxrqft
# 236 ZTF18aaypxlu
# 237 ZTF19aailuve
# 238 ZTF19acoqkxe
# 239 ZTF19acnfbaf
# 240 ZTF19aamftoa
# 241 ZTF19acpqyxp
# 242 ZTF20aaunzub
# 243 ZTF19acozbwk
# 244 ZTF20aauwvmp
# 245 ZTF20aavhvdq
# 246 ZTF20aawjdge
# 247 ZTF20aayicdu
# 248 ZTF20aaxgbtu
# 249 ZTF19aandwkj
# 250 ZTF19acrvodx
# 251 ZTF20abxwqea
# 252 ZTF19acordvu
# 253 ZTF20acigjwx
# 254 ZTF19acrtwcp
# 255 ZTF19actainy
# 256 ZTF19achtjls
# 257 ZTF20aausgkr
# 258 ZTF20aavzmox
# 259 ZTF20aavebyd
# 260 ZTF20aawfogn
# 261 ZTF19aanjfnk
# 262 ZTF19abjbjik
# 263 ZTF18abortym
# 264 ZTF20aavfurd
# 265 ZTF18abrbaow
# 266 ZTF20aaxmfow
# 267 ZTF20aazangn
# 268 ZTF19aapbnvn
# 269 ZTF19aaozxqk
# 270 ZTF19adcchsv
# 271 ZTF20abatpqr
# 272 ZTF20abbfhxd
# 273 ZTF18acsxyai
# 274 ZTF20aabqqpj
# 275 ZTF20abgbvzy
# 276 ZTF20aaeyzfp
# 277 ZTF18acxhldp
# 278 ZTF20abgauki
# 279 ZTF20abzgddp
# 280 ZTF18aatjhup
# 281 ZTF19aaruopq
# 282 ZTF19aarqkfv
# 283 ZTF20aahleif
# 284 ZTF20aahirup
# 285 ZTF20aafxahn
# 286 ZTF20abjalqf
# 287 ZTF18acuegof
# 288 ZTF20abjgcwc
# 289 ZTF20abndwkw
# 290 ZTF20accwihn
# 291 ZTF20abzcmeh
# 292 ZTF19aatoboa
# 293 ZTF20abjcvbo
# 294 ZTF20aakwcfh
# 295 ZTF19aarsose
# 296 ZTF20aaspwvx
# 297 ZTF20abjddfe
# 298 ZTF20abkcrqr
# 299 ZTF19adcfrwa
# 300 ZTF18acpkjyg
# 301 ZTF19abulmfe
# 302 ZTF20acgcqle
# 303 ZTF20abjwntl
# 304 ZTF19aaxroib
# 305 ZTF19acswdgx
# 306 ZTF20abldrje
# 307 ZTF20ablqayh
# 308 ZTF19abucuya
# 309 ZTF19aamftdx
# 310 ZTF20aaldpjs
# 311 ZTF20aamdkgk
# 312 ZTF19adbkvnr
# 313 ZTF20aamiqml
# 314 ZTF20acizlhn
# 315 ZTF20aakzaul
# 316 ZTF19abrozgp
# 317 ZTF19aauxfaw
# 318 ZTF19aaulpwc
# 319 ZTF19aavldqp
# 320 ZTF19abpizpb
# 321 ZTF19aavbomb
# 322 ZTF19aalcajs
# 323 ZTF20aaupott
# 324 ZTF19acllajw
# 325 ZTF18aarmlzn
# 326 ZTF19acrwixd
# 327 ZTF19aanetcr
# 328 ZTF20abvadds
# 329 ZTF19acoknzg
# 330 ZTF20aavnmia
# 331 ZTF19acxxsmw
# 332 ZTF20aaurvkv
# 333 ZTF20aaxckgg
# 334 ZTF19acyfion
# 335 ZTF19abmyalo
# 336 ZTF18acsyfsl
# 337 ZTF20abefbjx
# 338 ZTF19acxqawb
# 339 ZTF19abqxiok
# 340 ZTF20aahuwwe
# 341 ZTF20aahbrfu
# 342 ZTF20abivhxo
# 343 ZTF18aarbixk
# 344 ZTF20abjimko
# 345 ZTF18abefxte
# 346 ZTF20acgjixx
# 347 ZTF18abceitr
# 348 ZTF20acglhmi
# 349 ZTF20aahisam
# 350 ZTF20aalxtwm
# 351 ZTF18acsvogv
# 352 ZTF20abmkypp
# 353 ZTF20abovqes
# 354 ZTF18acsxoed
# 355 ZTF18adaysyr
# 356 ZTF20aapyqax
# 357 ZTF19aavifuy
# 358 ZTF19aavvzwq
# 359 ZTF18adbdjij
# 360 ZTF19acstkvb
# 361 ZTF20aasiwxy
# 362 ZTF19aaabtbz
# 363 ZTF20aatpvvp
# 364 ZTF20aatprua
# 365 ZTF20aattrzv
# 366 ZTF19aabymik
# 367 ZTF19aawllzb
# 368 ZTF20aarcdss
# 369 ZTF20aatvjqk
# 370 ZTF20aaukrus
# 371 ZTF19aadpidh
# 372 ZTF19aaconmv
# 373 ZTF19aadnvyf
# 374 ZTF19aachzlb
# 375 ZTF18acyhrdi
# 376 ZTF19abymvpt
# 377 ZTF19acaiers
# 378 ZTF19acbugyi
# 379 ZTF19acxnebw
# 380 ZTF19abbbuyn
# 381 ZTF19acdtjpp
# 382 ZTF20aaukwuf
# 383 ZTF20aauolwn
# 384 ZTF20aauuwmg
# 385 ZTF19acruoro
# 386 ZTF20aauwwuu
# 387 ZTF18acqyktp
# 388 ZTF20abyxewf
# 389 ZTF20aavoabc
# 390 ZTF20aautfqu
# 391 ZTF19acneyhb
# 392 ZTF20aavxtbz
# 393 ZTF19acxytzf
# 394 ZTF19abhpatq
# 395 ZTF19aaqwxkr
# 396 ZTF20aaepcdr
# 397 ZTF20aafckvw
# 398 ZTF20aadzvtx
# 399 ZTF18aczawcw
# 400 ZTF20aahsrna
# 401 ZTF19aartupg
# 402 ZTF19abqtfbj
# 403 ZTF19aaspang
# 404 ZTF18aczeqzj
# 405 ZTF19aarlhwo
# 406 ZTF18aczumpe
# 407 ZTF18aasxahh
# 408 ZTF20abhtzig
# 409 ZTF20aahkkql
# 410 ZTF20abjmsmt
# 411 ZTF20acfnnxc
# 412 ZTF19acudlxq
# 413 ZTF20ablpwxe
# 414 ZTF20achoqmk
# 415 ZTF20abjmpqs
# 416 ZTF20acmwxry
# 417 ZTF19aaujlou
# 418 ZTF18adainmx
# 419 ZTF19acscelt
# 420 ZTF20aarvuvj
# 421 ZTF20aasmawh
# 422 ZTF19aavnotz
# 423 ZTF20aasibbh
# 424 ZTF19aaaibty
# 425 ZTF19aabhdko
# 426 ZTF20abrbeqj
# 427 ZTF20aaukvqw
# 428 ZTF19aayeotg
# 429 ZTF19abzzuin
# 430 ZTF19aacxwfb
# 431 ZTF19abzzfnp
# 432 ZTF19acbtddm
# 433 ZTF19aawgqcc
# 434 ZTF19aaegspa
# 435 ZTF19acblrbx
# 436 ZTF18ablthsd
# 437 ZTF19acbkkkx
# 438 ZTF19acbpzjg
# 439 ZTF19acasxva
# 440 ZTF19aamppea
# 441 ZTF20aauriwm
# 442 ZTF19acrcmzw
# 443 ZTF19acmbpck
# 444 ZTF18aablerf
# 445 ZTF19acrssbx
# 446 ZTF17aaavjfv
# 447 ZTF19aanmhlu
# 448 ZTF19acnhadk
# 449 ZTF19acwkjgg
# 450 ZTF20abykcen
# 451 ZTF19aanhdwt
# 452 ZTF18acqgvrt
# 453 ZTF19acxndat
# 454 ZTF18acrwgfp
# 455 ZTF19aaqcpcw
# 456 ZTF18acvvslx
# 457 ZTF20abgntuh
# 458 ZTF20abeuwlk
# 459 ZTF20aaifylu
# 460 ZTF20aaeiols
# 461 ZTF19acsjyxy
# 462 ZTF20abixnhk
# 463 ZTF18acgqliz
# 464 ZTF19aasssmj
# 465 ZTF20abjuezd
# 466 ZTF20abjufir
# 467 ZTF20acbgacu
# 468 ZTF20aamybej
# 469 ZTF20aaptcqc
# 470 ZTF20aansmkx
# 471 ZTF20aankgwv
# 472 ZTF19aarpxgb
# 473 ZTF20aamulau
# 474 ZTF20abpvgcy
# 475 ZTF20aasebpp
# 476 ZTF20abqgtqf
# 477 ZTF20aaofwwq
# 478 ZTF18adbdhwh
# 479 ZTF19aavhvwd
# 480 ZTF19aavleuf
# 481 ZTF19aabyhwy
# 482 ZTF19aaapfde
# 483 ZTF19aaaokub
# 484 ZTF20aattord
# 485 ZTF20abqsrvn
# 486 ZTF19aawlgrc
# 487 ZTF20aatvpsa
# 488 ZTF19aavwarp
# 489 ZTF19aadavfl
# 490 ZTF19aadmapf
# 491 ZTF19aadofaz
# 492 ZTF19aaeqhjn
# 493 ZTF19aaesfyl
# 494 ZTF19abzrcje
# 495 ZTF19aaefazu
# 496 ZTF19aailpsf
# 497 ZTF19aaipokk
# 498 ZTF19acbyklm
# 499 ZTF19aazvqod
# 500 ZTF19aayrhmd
# 501 ZTF19abzuaoj
# 502 ZTF19acaxfkb
# 503 ZTF19accvbkv
# 504 ZTF20aarbmuu
# 505 ZTF19accskys
# 506 ZTF19acbwjjz
# 507 ZTF19acbwgqj
# 508 ZTF20abvtvuq
# 509 ZTF19aamoyzf
# 510 ZTF19acojuex
# 511 ZTF19acneyja
# 512 ZTF20aatvpnx
# 513 ZTF20acoqrpm
# 514 ZTF19acrwiye
# 515 ZTF19aaneseo
# 516 ZTF19acschjc
# 517 ZTF20aavudxc
# 518 ZTF20aavnztx
# 519 ZTF19acbplek
# 520 ZTF17aaaocnx
# 521 ZTF18acurkzx
# 522 ZTF19abqirpa
# 523 ZTF18acyrmdh
# 524 ZTF19aarjspm
# 525 ZTF19aaqwwde
# 526 ZTF19aarisna
# 527 ZTF20abzpxjv
# 528 ZTF20abjxefy
# 529 ZTF20aceowmd
# 530 ZTF20acfnqsh
# 531 ZTF19abucixu
# 532 ZTF19aadaqmn
# 533 ZTF20acgkiwo
# 534 ZTF20abkdxzy
# 535 ZTF20aalkbuu
# 536 ZTF20aajvnji
# 537 ZTF20aamdzkk
# 538 ZTF20acgyggs
# 539 ZTF20abmgzuf
# 540 ZTF19acvfryu
# 541 ZTF19abvitks
# 542 ZTF18adbmhzp
# 543 ZTF18adbmbgf
# 544 ZTF19aaaulkx
# 545 ZTF20aatuqfy
# 546 ZTF19aawvisn
# 547 ZTF18adbijzc
# 548 ZTF20aaubnyg
# 549 ZTF20aatqbmw
# 550 ZTF20abkiebn
# 551 ZTF20aaulgac
# 552 ZTF20aaulcil
# 553 ZTF20aaunvkd
# 554 ZTF20aadvpnz
# 555 ZTF19aafmymc
# 556 ZTF19acttopm
# 557 ZTF18adiaqui
# 558 ZTF19aaileyk
# 559 ZTF19acbkanq
# 560 ZTF19acddkbj
# 561 ZTF20abuocri
# 562 ZTF20aatvady
# 563 ZTF19aciefgg
# 564 ZTF19acqnmjo
# 565 ZTF19acnjftp
# 566 ZTF19aamkugw
# 567 ZTF20abrjyie
# 568 ZTF20aavqbbd
# 569 ZTF20absjhye
# 570 ZTF20abxnsoe
# 571 ZTF20aaurfvz
# 572 ZTF20aawkwvo
# 573 ZTF20aavhtsi
# 574 ZTF20aaxxmaj
# 575 ZTF20aaxccrt
# 576 ZTF20aawfxyv
# 577 ZTF19actnybi
# 578 ZTF19adakeem
# 579 ZTF18acspdha
# 580 ZTF20abaccvn
# 581 ZTF18acwgdeh
# 582 ZTF20aaaybry
# 583 ZTF19abqhgqi
# 584 ZTF20abeinak
# 585 ZTF19aartwud
# 586 ZTF19abrawuz
# 587 ZTF20acaxbqi
# 588 ZTF20aajcbhr
# 589 ZTF20abjksgj
# 590 ZTF18abzvtco
# 591 ZTF19abtuifj
# 592 ZTF19acqyfcz
# 593 ZTF20acjixfi
# 594 ZTF20aamudnp
# 595 ZTF19abucxdi
# 596 ZTF20abnklxp
# 597 ZTF20aaqujzw
# 598 ZTF20abqalfa
# 599 ZTF19aaatzvg
# 600 ZTF19aabynxp
# 601 ZTF19aavmsxz
# 602 ZTF19aabhmcx
# 603 ZTF20aatpsgc
# 604 ZTF19acudmhc
# 605 ZTF19aaczyek
# 606 ZTF19aadgily
# 607 ZTF18acueupj
# 608 ZTF19aadyize
# 609 ZTF19aawviut
# 610 ZTF19aardvhf
# 611 ZTF19aayejww
# 612 ZTF19abzzuik
# 613 ZTF19acrxflk
# 614 ZTF18abnopie
# 615 ZTF19aagdrrr
# 616 ZTF19aafndoy
# 617 ZTF19abaevrw
# 618 ZTF19acbvkbi
# 619 ZTF19acudien
# 620 ZTF19accdacw
# 621 ZTF19aamresp
# 622 ZTF19aampiqc
# 623 ZTF20aautqyd
# 624 ZTF20acpmxdg
# 625 ZTF19acttpsv
# 626 ZTF20abxyfah
# 627 ZTF19acvtvok
# 628 ZTF20abywpje
# 629 ZTF20aawkqgl
# 630 ZTF20aawkskq
# 631 ZTF20aaxukgn
# 632 ZTF19acvhmzn
# 633 ZTF20aaypknr
# 634 ZTF18ablpcfv
# 635 ZTF18acllewz
# 636 ZTF18actwyhl
# 637 ZTF20abeevyo
# 638 ZTF20abyzdsb
# 639 ZTF20abznlzw
# 640 ZTF20aaivlzx
# 641 ZTF20aahsoxr
# 642 ZTF20abgsjrt
# 643 ZTF20abizigt
# 644 ZTF20aajvwfh
# 645 ZTF19aaspwmv
# 646 ZTF19aatjrua
# 647 ZTF20abkibte
# 648 ZTF20abjzapi
# 649 ZTF20aaiuyrm
# 650 ZTF19abutqrg
# 651 ZTF20aacdans
# 652 ZTF20aaqlsho
# 653 ZTF20abmbcza
# 654 ZTF20abpbmxi
# 655 ZTF18adakwzc
# 656 ZTF20abpgnos
# 657 ZTF19aaaffso
# 658 ZTF18abqkfvr
# 659 ZTF19aabkvoe
# 660 ZTF18aadbtae
# 661 ZTF19acslkjy
# 662 ZTF19aavnxtq
# 663 ZTF19abzvkjw
# 664 ZTF19aahusgo
# 665 ZTF18aadqmyy
# 666 ZTF19abalrzb
# 667 ZTF19acclxty
# 668 ZTF19actairt
# 669 ZTF20aappggv
# 670 ZTF20acpylns
# 671 ZTF19aculgki
# 672 ZTF19acrolpe
# 673 ZTF19aanenop
# 674 ZTF19aancrfs
# 675 ZTF19aanhluk
# 676 ZTF19acrxytf
# 677 ZTF19acrxzha
# 678 ZTF19acrqppc
# 679 ZTF20aawknzg
# 680 ZTF20aawdaem
# 681 ZTF19aanuuqb
# 682 ZTF20acgyjwl
# 683 ZTF20aavtcaj
# 684 ZTF20aaxcgwn
# 685 ZTF20aazfxvw
# 686 ZTF18acsyxhj
# 687 ZTF20abavxkq
# 688 ZTF19aboclfq
# 689 ZTF20abajzrl
# 690 ZTF20abehuki
# 691 ZTF18aczcsmg
# 692 ZTF20aagprzh
# 693 ZTF20aafcljq
# 694 ZTF18abfekzy
# 695 ZTF20aahirec
# 696 ZTF20abivilh
# 697 ZTF20abyvbvs
# 698 ZTF19aaprhvf
# 699 ZTF20abzuhfn
# 700 ZTF20acbupdz
# 701 ZTF20abjgzjd
# 702 ZTF20abzbtgm
# 703 ZTF19aarqkkx
# 704 ZTF19aauctno
# 705 ZTF20abjwhkc
# 706 ZTF20abbpqiu
# 707 ZTF20abjwnqf
# 708 ZTF20abkfkze
# 709 ZTF20aaqumal
# 710 ZTF18abnvwgk
# 711 ZTF20aankhpt
# 712 ZTF20aamioom
# 713 ZTF19abvjnsm
# 714 ZTF20aaomfhr
# 715 ZTF19acsgdey
# 716 ZTF18adaimlf
# 717 ZTF20abqjcsx
# 718 ZTF19aaaiztl
# 719 ZTF20aatruwg
# 720 ZTF20aatpsxv
# 721 ZTF20aatvpnt
# 722 ZTF19aaxdzrs
# 723 ZTF20aatvqqw
# 724 ZTF20abrifkg
# 725 ZTF19aavlnik
# 726 ZTF19aadfqfw
# 727 ZTF19aacokgn
# 728 ZTF19aaapjrf
# 729 ZTF19aaednlp
# 730 ZTF19aavmiij
# 731 ZTF19aaxizyq
# 732 ZTF20abjyovb
# 733 ZTF19aahsrvz
# 734 ZTF19aayebej
# 735 ZTF19aaywnbf
# 736 ZTF19abbvfyz
# 737 ZTF19acozdpl
# 738 ZTF19acnlunn
# 739 ZTF20abkhinr
# 740 ZTF19acpmpvh
# 741 ZTF19acghxoi
# 742 ZTF20aavdqfw
# 743 ZTF18abusrtw
# 744 ZTF19aanickz
# 745 ZTF20aavmurk
# 746 ZTF19acrwwlt
# 747 ZTF20aavwppy
# 748 ZTF18aaajljy
# 749 ZTF19acynqtm
# 750 ZTF19aapdieo
# 751 ZTF19acykaqg
# 752 ZTF19acyndsy
# 753 ZTF20aazxtha
# 754 ZTF18acuypmo
# 755 ZTF19aczkkaj
# 756 ZTF20aahhzxr
# 757 ZTF19abqsfpw
# 758 ZTF18acwyvhw
# 759 ZTF20aaifzbr
# 760 ZTF20aakjctr
# 761 ZTF20abjmqsd
# 762 ZTF20aagzfsz
# 763 ZTF19aauusyv
# 764 ZTF20acfyxmx
# 765 ZTF20acbaajc
# 766 ZTF20acgcpuu
# 767 ZTF20achnjnz
# 768 ZTF20aafaejx
# 769 ZTF20abndxzn
# 770 ZTF19aaunjft
# 771 ZTF20abmsqea
# 772 ZTF18abvbpkf
# 773 ZTF20abpvipp
# 774 ZTF20aasivsc
# 775 ZTF20aasbvco
# 776 ZTF19aabyyhr
# 777 ZTF19aavwqil
# 778 ZTF19aavwqvn
# 779 ZTF19aadnvyd
# 780 ZTF19aadpped
# 781 ZTF19acucmja
# 782 ZTF19abzlcjk
# 783 ZTF20aanvsru
# 784 ZTF19acxoujr
# 785 ZTF19aajxddj
# 786 ZTF19acdigzw
# 787 ZTF20aatuqva
# 788 ZTF18aagguqz
# 789 ZTF20aatzcxk
# 790 ZTF18aamrkmd
# 791 ZTF20aavebgw
# 792 ZTF19aamwkeb
# 793 ZTF19aangcrd
# 794 ZTF20abwvqjk
# 795 ZTF20aaqglss
# 796 ZTF20abeezcd
# 797 ZTF19acwxgrz
# 798 ZTF19acoymzz
# 799 ZTF19abhbswp
# 800 ZTF19aanneuv
# 801 ZTF19aaoxzrm
# 802 ZTF19acxzcdu
# 803 ZTF18acqijrr
# 804 ZTF19acsbwsa
# 805 ZTF20abezywi
# 806 ZTF19aaqhcgm
# 807 ZTF20aafcetl
# 808 ZTF18acxzrgc
# 809 ZTF20aahsvoh
# 810 ZTF20abzkyve
# 811 ZTF20abhziqt
# 812 ZTF19aaprwmw
# 813 ZTF20abiserv
# 814 ZTF20acfdmmk
# 815 ZTF20acdmckz
# 816 ZTF20abjysfc
# 817 ZTF20acjpwdk
# 818 ZTF19acwkwhu
# 819 ZTF19abtuhqa
# 820 ZTF20aaruesp
# 821 ZTF19abxdnmh
# 822 ZTF20abmoguq
# 823 ZTF19abvimho
# 824 ZTF20abowrff
# 825 ZTF20abpfbih
# 826 ZTF20aaqnfzg
# 827 ZTF19aavkuzh
# 828 ZTF19aaupklw
# 829 ZTF19aavrzzr
# 830 ZTF19aaaicak
# 831 ZTF19aavocqa
# 832 ZTF19aawlluc
# 833 ZTF19aabyqsw
# 834 ZTF19actbcdk
# 835 ZTF20aatrvpl
# 836 ZTF20aatwacm
# 837 ZTF19abypmqz
# 838 ZTF20aatpqca
# 839 ZTF19aabyvgk
# 840 ZTF20aatpqir
# 841 ZTF19aadpgac
# 842 ZTF19aadgdyk
# 843 ZTF19abzqbgp
# 844 ZTF19abymuxu
# 845 ZTF19aahsono
# 846 ZTF19acajpme
# 847 ZTF19acaxdvp
# 848 ZTF19aaztcqh
# 849 ZTF19actbqdd
# 850 ZTF19acajmzq
# 851 ZTF19aailqpe
# 852 ZTF20acgnhuj
# 853 ZTF19abbnjiz
# 854 ZTF19acnwelq
# 855 ZTF20acpvxmk
# 856 ZTF19acrwmdp
# 857 ZTF19acrdcgp
# 858 ZTF19acsakuv
# 859 ZTF20aaxcbvr
# 860 ZTF19aantbof
# 861 ZTF18acrcaee
# 862 ZTF20aaytqhd
# 863 ZTF19aapcqle
# 864 ZTF20aaryhnd
# 865 ZTF18acswnlt
# 866 ZTF19abnetqv
# 867 ZTF19aaqgqfg
# 868 ZTF19aaqgpiu
# 869 ZTF20aazsglm
# 870 ZTF19abppvor
# 871 ZTF19adbnaky
# 872 ZTF20abefdcc
# 873 ZTF20abeewpi
# 874 ZTF20abfqghm
# 875 ZTF20aaelxjv
# 876 ZTF20aafmgyr
# 877 ZTF18acsxhmk
# 878 ZTF18acvdbdo
# 879 ZTF19abrhyun
# 880 ZTF18acytxlp
# 881 ZTF19aariljm
# 882 ZTF18aczergr
# 883 ZTF20aaieyvg
# 884 ZTF20acczsxk
# 885 ZTF20aalbgef
# 886 ZTF19acspcch
# 887 ZTF20abkhhoe
# 888 ZTF20acggviy
# 889 ZTF20achaxsk
# 890 ZTF20acjizgn
# 891 ZTF20acilhew
# 892 ZTF19abrokwi
# 893 ZTF18abdbgza
# 894 ZTF20ackrvsm
# 895 ZTF20aciupyq
# 896 ZTF20aamensp
# 897 ZTF19abuhlpn
# 898 ZTF20aaqihuw
# 899 ZTF20aanadvz
# 900 ZTF20abnklbi
# 901 ZTF20aapdeap
# 902 ZTF20aasknkx
# 903 ZTF18aaaqgyc
# 904 ZTF19aavhwbp
# 905 ZTF19acvriwv
# 906 ZTF19aawbgdh
# 907 ZTF19aaadxmz
# 908 ZTF19aaagizo
# 909 ZTF19aawtruu
# 910 ZTF19actakac
# 911 ZTF19abxqycj
# 912 ZTF20aatpfnq
# 913 ZTF19aabyvbf
# 914 ZTF19aavpqhr
# 915 ZTF20aaumllb
# 916 ZTF19aadpdqm
# 917 ZTF19aadodym
# 918 ZTF19aadnwgk
# 919 ZTF19aavwdwy
# 920 ZTF19abzknnj
# 921 ZTF18aawxgqp
# 922 ZTF18aalpcph
# 923 ZTF19abzlyqt
# 924 ZTF19acxmbyu
# 925 ZTF19aafmkfm
# 926 ZTF19aahsukw
# 927 ZTF19aahuewo
# 928 ZTF19aawmhbu
# 929 ZTF18aaxnmge
# 930 ZTF19aalybta
# 931 ZTF20aauonox
# 932 ZTF19acoyidq
# 933 ZTF19aanekbm
# 934 ZTF19acpkdlr
# 935 ZTF20abvyiwh
# 936 ZTF20abxypwi
# 937 ZTF20abyevll
# 938 ZTF18aamasph
# 939 ZTF20aauwtnz
# 940 ZTF20abyfgkz
# 941 ZTF20abyjanf
# 942 ZTF19aanqqzb
# 943 ZTF20aaxckbj
# 944 ZTF20aaxclbz
# 945 ZTF19aanvhyc
# 946 ZTF19acyfatb
# 947 ZTF20aaxzwnu
# 948 ZTF19aandwfe
# 949 ZTF20aayplyv
# 950 ZTF18acsvkxu
# 951 ZTF19aarihpp
# 952 ZTF19acynipo
# 953 ZTF19adbmduz
# 954 ZTF20abejrqk
# 955 ZTF18abvowtp
# 956 ZTF20abgbdhi
# 957 ZTF18acwwchq
# 958 ZTF19abqgyqr
# 959 ZTF18adaifgd
# 960 ZTF20acefoiy
# 961 ZTF19aarmujg
# 962 ZTF20acdreek
# 963 ZTF20abkhjbu
# 964 ZTF19abtriyg
# 965 ZTF20abligvh
# 966 ZTF20aaodnaa
# 967 ZTF19acdjfbg
# 968 ZTF18aarcouj
# 969 ZTF18adblnwv
# 970 ZTF19abljehr
# 971 ZTF20abqbkzm
# 972 ZTF19abglrxo
# 973 ZTF19aauvblr
# 974 ZTF19aavgyjd
# 975 ZTF19aavrbra
# 976 ZTF18adbcjkb
# 977 ZTF18adccxqw
# 978 ZTF18adbihrq
# 979 ZTF18adbiftk
# 980 ZTF20aammzjf
# 981 ZTF20abqkeje
# 982 ZTF20ablmxtl
# 983 ZTF19aawfxwj
# 984 ZTF20aatuvvc
# 985 ZTF19aavriia
# 986 ZTF20aaunwum
# 987 ZTF20aaulari
# 988 ZTF19abyndix
# 989 ZTF20abbzolz
# 990 ZTF19aavlnqp
# 991 ZTF19aaxzglq
# 992 ZTF19aaflkzn
# 993 ZTF19aaeprwm
# 994 ZTF19acsmzfr
# 995 ZTF19abzvkbz
# 996 ZTF19acqoxzt
# 997 ZTF19aafnfis
# 998 ZTF18aaenucd
# 999 ZTF18adbhsjc
# 1000 ZTF19acahpfn
# 1001 ZTF19acxozlr
# 1002 ZTF19aazprtn
# 1003 ZTF19aaznxcw
# 1004 ZTF19acbmyqe
# 1005 ZTF19acsxzya
# 1006 ZTF19abaevmv
# 1007 ZTF19acdtkbv
# 1008 ZTF19acajmlj
# 1009 ZTF19aamvfgy
# 1010 ZTF20aauwyta
# 1011 ZTF20aauwysn
# 1012 ZTF20aauwgnw
# 1013 ZTF18acqeuat
# 1014 ZTF20aauolxq
# 1015 ZTF19aamqory
# 1016 ZTF19aamgpuc
# 1017 ZTF19aanhdwf
# 1018 ZTF19aamtjzm
# 1019 ZTF19aakjfzu
# 1020 ZTF20aausfxo
# 1021 ZTF18aceyycq
# 1022 ZTF19abgctni
# 1023 ZTF20aautwvg
# 1024 ZTF19abgbcgv
# 1025 ZTF19aancxsc
# 1026 ZTF19abotlte
# 1027 ZTF20aaycyka
# 1028 ZTF20aaydyzl
# 1029 ZTF19acxzdjb
# 1030 ZTF19aaoakjo
# 1031 ZTF19abneygz
# 1032 ZTF20aaaysed
# 1033 ZTF20aaccieq
# 1034 ZTF20abewzpe
# 1035 ZTF19aapjuqf
# 1036 ZTF20abdzjpn
# 1037 ZTF18acvduiz
# 1038 ZTF20aafchgb
# 1039 ZTF18acjfixk
# 1040 ZTF20abzfotj
# 1041 ZTF20abytgnq
# 1042 ZTF19aarizoc
# 1043 ZTF20abypgvs
# 1044 ZTF19aarifvy
# 1045 ZTF19aarnhko
# 1046 ZTF20abjgqic
# 1047 ZTF20aaglqmj
# 1048 ZTF20aajcekl
# 1049 ZTF20abhcmuj
# 1050 ZTF20abisgvs
# 1051 ZTF19abtvlza
# 1052 ZTF20abkdsog
# 1053 ZTF18acujedb
# 1054 ZTF20aagzuaw
# 1055 ZTF20aahicfo
# 1056 ZTF20aclnfvp
# 1057 ZTF20aamjncn
# 1058 ZTF19aatmudg
# 1059 ZTF19aassokj
# 1060 ZTF19abxwfgr
# 1061 ZTF19aavledx
# 1062 ZTF20aaqmumz
# 1063 ZTF18adbcknf
# 1064 ZTF18adbadid
# 1065 ZTF20aafjmdg
# 1066 ZTF20acgyfxp
# 1067 ZTF20aatwanv
# 1068 ZTF19aacxgtc
# 1069 ZTF19aavsqjw
# 1070 ZTF18abqvpaz
# 1071 ZTF19aadnxkc
# 1072 ZTF19aadyplk
# 1073 ZTF19acajpbp
# 1074 ZTF20aapcdln
# 1075 ZTF19aafmoql
# 1076 ZTF19aazrlqy
# 1077 ZTF19aaeovwr
# 1078 ZTF19abagian
# 1079 ZTF19abaibif
# 1080 ZTF19abcejwg
# 1081 ZTF17aabwkio
# 1082 ZTF18aaszfhi
# 1083 ZTF19acobfoo
# 1084 ZTF20aavnots
# 1085 ZTF19aanhgpu
# 1086 ZTF19acrxzgm
# 1087 ZTF19acxmmar
# 1088 ZTF19abgbbpx
# 1089 ZTF20aaurtvs
# 1090 ZTF20achpgul
# 1091 ZTF20aavnljl
# 1092 ZTF20abbypaa
# 1093 ZTF18abhboqu
# 1094 ZTF19abjbjdv
# 1095 ZTF20aaxxhhi
# 1096 ZTF19acyjzco
# 1097 ZTF20aayvlky
# 1098 ZTF20aazhxjf
# 1099 ZTF19acigwcg
# 1100 ZTF18acsoymy
# 1101 ZTF19adcgaer
# 1102 ZTF18acsxpqp
# 1103 ZTF20abbccsa
# 1104 ZTF20abcwuou
# 1105 ZTF19aarisyu
# 1106 ZTF19aarqslv
# 1107 ZTF20abuhcje
# 1108 ZTF20acajwft
# 1109 ZTF20abhcohh
# 1110 ZTF20abjgnsw
# 1111 ZTF20abjtwij
# 1112 ZTF20aalkasj
# 1113 ZTF20aamcpzi
# 1114 ZTF20aambmws
# 1115 ZTF20aambofu
# 1116 ZTF20abnchny
# 1117 ZTF20abluhjf
# 1118 ZTF19aavahrx
# 1119 ZTF20abbsopk
# 1120 ZTF18adbclta
# 1121 ZTF18adaymez
# 1122 ZTF19abuoexn
# 1123 ZTF20aanajbr
# 1124 ZTF19aavxoyu
# 1125 ZTF18adbcjin
# 1126 ZTF18adbmbva
# 1127 ZTF19aaabtvg
# 1128 ZTF20aattnyx
# 1129 ZTF19aabypir
# 1130 ZTF19aavqoww
# 1131 ZTF19aachpob
# 1132 ZTF20aceekkd
# 1133 ZTF19aavweqz
# 1134 ZTF20aaskblh
# 1135 ZTF20abmaktx
# 1136 ZTF19aaflsrw
# 1137 ZTF19abyxpgt
# 1138 ZTF19aafncke
# 1139 ZTF19aadgmuq
# 1140 ZTF19abzlrbs
# 1141 ZTF19aainndi
# 1142 ZTF19aafmwfh
# 1143 ZTF19aajyohf
# 1144 ZTF19aazwnsq
# 1145 ZTF19abaevtw
# 1146 ZTF19acvrisy
# 1147 ZTF19abaivcy
# 1148 ZTF19acarefd
# 1149 ZTF19acbmotn
# 1150 ZTF20abpcrtx
# 1151 ZTF18adaysnz
# 1152 ZTF19acvgdyx
# 1153 ZTF19aavwczu
# 1154 ZTF18adbmbuh
# 1155 ZTF19aaadegs
# 1156 ZTF20aasdhqn
# 1157 ZTF20aatvxow
# 1158 ZTF20aatzfpo
# 1159 ZTF20aauktvp
# 1160 ZTF19aacwzuy
# 1161 ZTF19aaycpfe
# 1162 ZTF19abymuls
# 1163 ZTF19acudhkn
# 1164 ZTF19abadotn
# 1165 ZTF19acbisfe
# 1166 ZTF20aarbtdi
# 1167 ZTF20aaoqqyf
# 1168 ZTF19acbprgt
# 1169 ZTF19acbpwda
# 1170 ZTF19accmcjj
# 1171 ZTF18adbcjlv
# 1172 ZTF19aaajcbb
# 1173 ZTF19aaahuvq
# 1174 ZTF20aatusjj
# 1175 ZTF20aaukuzn
# 1176 ZTF20aaukuzk
# 1177 ZTF19aaxeaey
# 1178 ZTF19aayhvar
# 1179 ZTF19aacipif
# 1180 ZTF19aadpddh
# 1181 ZTF19abzvzzr
# 1182 ZTF19acjidwq
# 1183 ZTF19aaedudt
# 1184 ZTF19abzvjgv
# 1185 ZTF19acbmwnv
# 1186 ZTF19acbpkxp
# 1187 ZTF19aahsmns
# 1188 ZTF19acbwnmp
# 1189 ZTF20abraygp
# 1190 ZTF19acbpjqd
# 1191 ZTF19abaofar
# 1192 ZTF19abcmhpj
# 1193 ZTF19aaprbry
# 1194 ZTF19acdtmwh
# 1195 ZTF19abcomui
# 1196 ZTF19accvilj
# 1197 ZTF19aatyrpj
# 1198 ZTF19acendsf
# 1199 ZTF19acekjvb
# 1200 ZTF19aceckaj
# 1201 ZTF19aceclmb
# 1202 ZTF19acbvenh
# 1203 ZTF19acecjzu
# 1204 ZTF19acdcgqm
# 1205 ZTF19acbpdro
# 1206 ZTF19acetvex
# 1207 ZTF19aceckai
# 1208 ZTF19aavkbch
# 1209 ZTF18aabuoud
# 1210 ZTF19aceytnn
# 1211 ZTF19abcejfq
# 1212 ZTF19acewmzw
# 1213 ZTF19acdgeow
# 1214 ZTF19acduepd
# 1215 ZTF19abcmjed
# 1216 ZTF19acetwod
# 1217 ZTF19abbythd
# 1218 ZTF19abdspdf
# 1219 ZTF18aczeraq
# 1220 ZTF19abdcgfd
# 1221 ZTF19aakiydh
# 1222 ZTF19aaejtrn
# 1223 ZTF19aailutj
# 1224 ZTF19abcyrlv
# 1225 ZTF19abdcexm
# 1226 ZTF19abddsvk
# 1227 ZTF19aayiidz
# 1228 ZTF19abcpdlq
# 1229 ZTF19abbywip
# 1230 ZTF19aceckgz
# 1231 ZTF19acdakjs
# 1232 ZTF19acezjqu
# 1233 ZTF19acfdvaj
# 1234 ZTF19aayurjv
# 1235 ZTF18aawwzrq
# 1236 ZTF19aakjdcq
# 1237 ZTF19aailuqa
# 1238 ZTF19aakjeqc
# 1239 ZTF19aakiyjd
# 1240 ZTF19aakjfws
# 1241 ZTF18aawdynj
# 1242 ZTF19abfarpa
# 1243 ZTF19acgkqnt
# 1244 ZTF19acepeea
# 1245 ZTF19acewggu
# 1246 ZTF19abflpfn
# 1247 ZTF19abdolkk
# 1248 ZTF18absmdtd
# 1249 ZTF19abdltnq
# 1250 ZTF19abdkghl
# 1251 ZTF19abqgxqb
# 1252 ZTF19aaklkrd
# 1253 ZTF19aajxoak
# 1254 ZTF19aaintrn
# 1255 ZTF19aainxtt
# 1256 ZTF19aaklihv
# 1257 ZTF19aakkuki
# 1258 ZTF19acgjnjx
# 1259 ZTF19achasgk
# 1260 ZTF20abbblrb
# 1261 ZTF19acgtkqe
# 1262 ZTF19acigmhp
# 1263 ZTF19abplzzk
# 1264 ZTF19aakvysq
# 1265 ZTF18abrwuou
# 1266 ZTF18abufgdj
# 1267 ZTF19acgjphi
# 1268 ZTF19abfpwia
# 1269 ZTF18abalzzd
# 1270 ZTF19aakkufz
# 1271 ZTF19aakoste
# 1272 ZTF19aakozlr
# 1273 ZTF20aarxwcz
# 1274 ZTF19acwinbf
# 1275 ZTF19ackjmae
# 1276 ZTF18abixgny
# 1277 ZTF18abkmowi
# 1278 ZTF19acgmznn
# 1279 ZTF19acgjyte
# 1280 ZTF19aamtdws
# 1281 ZTF19acgjjfy
# 1282 ZTF19acgkjnr
# 1283 ZTF19aahsbmq
# 1284 ZTF19aailrlv
# 1285 ZTF20abcxmst
# 1286 ZTF19acgjpjh
# 1287 ZTF19achtzyx
# 1288 ZTF19abfjjwc
# 1289 ZTF19aakpdqk
# 1290 ZTF19acbixgk
# 1291 ZTF19acmwfsx
# 1292 ZTF19aakynun
# 1293 ZTF19aafndkx
# 1294 ZTF18abykqma
# 1295 ZTF19acgjtxu
# 1296 ZTF19aalcbda
# 1297 ZTF19aamkfxg
# 1298 ZTF19acifsaj
# 1299 ZTF19achaqju
# 1300 ZTF19achtkza
# 1301 ZTF19acukmmn
# 1302 ZTF19aalviiv
# 1303 ZTF18abttgnr
# 1304 ZTF18aawzxky
# 1305 ZTF19acjndsa
# 1306 ZTF19acjmmdu
# 1307 ZTF19aaklsto
# 1308 ZTF18aaexyql
# 1309 ZTF19acwsajh
# 1310 ZTF19acocoaq
# 1311 ZTF18aclkdrz
# 1312 ZTF19achunqn
# 1313 ZTF18abdgdhz
# 1314 ZTF19acjduan
# 1315 ZTF20aarxdxk
# 1316 ZTF18acbvczr
# 1317 ZTF18abffuqh
# 1318 ZTF18abgkkri
# 1319 ZTF18abymobs
# 1320 ZTF18acegewi
# 1321 ZTF19achaibh
# 1322 ZTF19acjndrx
# 1323 ZTF18abcvpor
# 1324 ZTF18abdkiaq
# 1325 ZTF19acnfzpc
# 1326 ZTF18acciaxb
# 1327 ZTF19acjndrw
# 1328 ZTF19aainmwq
# 1329 ZTF18abguhwj
# 1330 ZTF18acbzooq
# 1331 ZTF19acfsvry
# 1332 ZTF19acivqsk
# 1333 ZTF18abclhtl
# 1334 ZTF19aakptsa
# 1335 ZTF19aahsdsf
# 1336 ZTF19actucih
# 1337 ZTF20aartfmb
# 1338 ZTF18abvefxs
# 1339 ZTF18abvrmto
# 1340 ZTF20aaoduix
# 1341 ZTF19aciflrf
# 1342 ZTF19achvsey
# 1343 ZTF19aclewjz
# 1344 ZTF19aakkwpb
# 1345 ZTF19aakptvj
# 1346 ZTF18aboinda
# 1347 ZTF18abortku
# 1348 ZTF19acigmia
# 1349 ZTF19aakizhb
# 1350 ZTF18aasvias
# 1351 ZTF19aalvata
# 1352 ZTF20aarflny
# 1353 ZTF19acgwgvh
# 1354 ZTF20aanafyp
# 1355 ZTF19acujyzv
# 1356 ZTF19aaeqxxl
# 1357 ZTF18abrynno
# 1358 ZTF19aclnrkg
# 1359 ZTF18aajfspz
# 1360 ZTF18abnyzcb
# 1361 ZTF18absdbpd
# 1362 ZTF20acpjfln
# 1363 ZTF20acqwaiy
# 1364 ZTF20acqyfie
# 1365 ZTF20acqldir
# 1366 ZTF20acrbpqd
# 1367 ZTF20acppsay
# 1368 ZTF20acqvwzb
# 1369 ZTF20acnhosq
# 1370 ZTF20acpwxbg
# 1371 ZTF20acqnthg
# 1372 ZTF20acrcesk
# 1373 ZTF20acrrzzj
# 1374 ZTF20acpmcmu
# 1375 ZTF20acreckb
# 1376 ZTF20acrudzk
# 1377 ZTF20acpqcjc
# 1378 ZTF20abrnwfc
# 1379 ZTF20acqoiyt
# 1380 ZTF18abzsimu
# 1381 ZTF20acqqmtf
# 1382 ZTF20acppchi
# 1383 ZTF20acpmcbw
# 1384 ZTF20acplqrq
# 1385 ZTF20acqnher
# 1386 ZTF20acowpad
# 1387 ZTF20acrvlem
# 1388 ZTF20acrtzgt
# 1389 ZTF20acqoxod
# 1390 ZTF20acqjmzk
# 1391 ZTF20acqqiao
# 1392 ZTF20actkulc
# 1393 ZTF20acrdemq
# 1394 ZTF20acphjgz
# 1395 ZTF20acrerzb
# 1396 ZTF20acqvqhv
# 1397 ZTF20abepyro
# 1398 ZTF20acounxo
# 1399 ZTF20acppruo
# 1400 ZTF20acrwxgr
# 1401 ZTF20acpypow
# 1402 ZTF20acrheie
# 1403 ZTF20acqqdkl
# 1404 ZTF20actddoh
# 1405 ZTF20acrcesc
# 1406 ZTF19achtcmr
# 1407 ZTF20acppzah
# 1408 ZTF20acphdcg
# 1409 ZTF20acshkqo
# 1410 ZTF20acgrzjm
# 1411 ZTF20acqlfwb
# 1412 ZTF20acqpxdc
# 1413 ZTF19abhelmm
# 1414 ZTF20acpziet
# 1415 ZTF20acrjjse
# 1416 ZTF18abadmpz
# 1417 ZTF20acpwmui
# 1418 ZTF20abztizu
# 1419 ZTF20acsfean
# 1420 ZTF20abijrzv
# 1421 ZTF20achlkrs
# 1422 ZTF20acqzpta
# 1423 ZTF20acpzaoa
# 1424 ZTF20acstglw
# 1425 ZTF20acrcfiq
# 1426 ZTF20acsopse
# 1427 ZTF20acszwan
# 1428 ZTF20actljfs
# 1429 ZTF20acpumut
# 1430 ZTF20acthbdd
# 1431 ZTF20actogyl
# 1432 ZTF20acqnhci
# 1433 ZTF20acqwcoi
# 1434 ZTF18acsjzcl
# 1435 ZTF20acrufey
# 1436 ZTF19aacpfqv
# 1437 ZTF20acqpzbo
# 1438 ZTF20acrdadi
# 1439 ZTF20actocyw
# 1440 ZTF20acrxrfv
# 1441 ZTF20acrsubb
# 1442 ZTF20acofydj
# 1443 ZTF20acpolgu
# 1444 ZTF20actnuls
# 1445 ZTF20actdhix
# 1446 ZTF20acpilio
# 1447 ZTF20acsesce
# 1448 ZTF20acrzwvx
# 1449 ZTF20actiymd
# 1450 ZTF20actrovz
# 1451 ZTF20acpbdvm
# 1452 ZTF20acqgklx
# 1453 ZTF20actpavu
# 1454 ZTF20actpatx
# 1455 ZTF20acsenmb
# 1456 ZTF20actawpa
# 1457 ZTF20actskcf
# 1458 ZTF20actkmks
# 1459 ZTF20acpjswl
# 1460 ZTF20acrqeje
# 1461 ZTF20acpkktq
# 1462 ZTF20actpbck
# 1463 ZTF20actoswy
# 1464 ZTF20acrzuko
# 1465 ZTF20actvffz
# 1466 ZTF20acqztpi
# 1467 ZTF20acuaqlf
# 1468 ZTF20acuhren
# 1469 ZTF18acahbqb
# 1470 ZTF20acucbek
# 1471 ZTF20actezmo
# 1472 ZTF20acqnfkh
# 1473 ZTF20actekrw
# 1474 ZTF20acufmrl
# 1475 ZTF20acseuvr
# 1476 ZTF20actzmzp
# 1477 ZTF20acrmolb
# 1478 ZTF20acqikeh
# 1479 ZTF20acsfdnn
# 1480 ZTF20actfoxr
# 1481 ZTF20acqvwzm
# 1482 ZTF20ackijaj
# 1483 ZTF20acqwbbb
# 1484 ZTF20acryhzw
# 1485 ZTF20acrhrcy
# 1486 ZTF20actnzzk
# 1487 ZTF20actquyv
# 1488 ZTF20acrjied
# 1489 ZTF20acufmte
# 1490 ZTF20actjbaf
# 1491 ZTF20actodrq
# 1492 ZTF20actpuan
# 1493 ZTF19aclhpiz
# 1494 ZTF20actoank
# 1495 ZTF20acuovfk
# 1496 ZTF20acupdsm
# 1497 ZTF20acphvzi
# 1498 ZTF20actnzxm
# 1499 ZTF20acqiryd
# 1500 ZTF18aboszbk
# 1501 ZTF20actkupc
# 1502 ZTF20acufmah
# 1503 ZTF20abfadbm
# 1504 ZTF20acsfdlj
# 1505 ZTF20acqpkxj
# 1506 ZTF20acqvgav
# 1507 ZTF20acuajow
# 1508 ZTF20acpklpq
# 1509 ZTF20actqtfk
# 1510 ZTF20acqrahz
# 1511 ZTF20actvlbq
# 1512 ZTF20aalxxyz
# 1513 ZTF20acuasvx
# 1514 ZTF20actrwym
# 1515 ZTF20actdeqw
# 1516 ZTF20acodsyb
# 1517 ZTF20actlign
# 1518 ZTF20acsfciw
# 1519 ZTF20actvfgr
# 1520 ZTF20acrinvz
# 1521 ZTF20actkuxm
# 1522 ZTF20actvpyc
# 1523 ZTF20acrsbye
# 1524 ZTF18acfhmhp
# 1525 ZTF20acuiuvw
# 1526 ZTF20acukwll
# 1527 ZTF20acuiuke
# 1528 ZTF20actquzl
# 1529 ZTF20acuhgar
# 1530 ZTF20actvgsy
# 1531 ZTF20acuozua
# 1532 ZTF20actoakx
# 1533 ZTF20acuvatg
# 1534 ZTF20acurrzb
# 1535 ZTF20acusjxt
# 1536 ZTF20acuspji
# 1537 ZTF20acutkgr
# 1538 ZTF20actowxb
# 1539 ZTF20acuoxrx
# 1540 ZTF20actpqgc
# 1541 ZTF20acuosiq
# 1542 ZTF20acrlvea
# 1543 ZTF20acuiktl
# 1544 ZTF20acusylb
# 1545 ZTF20acuzydz
# 1546 ZTF20acugxbm
# 1547 ZTF20acitojm
# 1548 ZTF20acvebcu
# 1549 ZTF20acuzfpk
# 1550 ZTF20acvbneg
# 1551 ZTF20acumxrh
# 1552 ZTF20aciojzg
# 1553 ZTF20acurtpj
# 1554 ZTF20acwgxhk
# 1555 ZTF20acvziuf
# 1556 ZTF20acusqsp
# 1557 ZTF20acuoatt
# 1558 ZTF20actoerz
# 1559 ZTF20acpguww
# 1560 ZTF20acrivxx
# 1561 ZTF20acvjlev
# 1562 ZTF20aculruc
# 1563 ZTF20acuhlns
# 1564 ZTF20acrcevd
# 1565 ZTF20acuzjqk
# 1566 ZTF20acutyac
# 1567 ZTF20acujaft
# 1568 ZTF20acvblkk
# 1569 ZTF20acumekm
# 1570 ZTF20acwobku
# 1571 ZTF20acwmpsj
# 1572 ZTF20acrcewc
# 1573 ZTF20acsdykp
# 1574 ZTF20acwfcaq
# 1575 ZTF20acvamwo
# 1576 ZTF20acuoacn
# 1577 ZTF20acudkao
# 1578 ZTF20acvpghu
# 1579 ZTF20acuosjp
# 1580 ZTF20acunxkg
# 1581 ZTF20acwcfvx
# 1582 ZTF20acwijiy
# 1583 ZTF20acvjagm
# 1584 ZTF18acealtv
# 1585 ZTF20actrjdy
# 1586 ZTF20acufbnv
# 1587 ZTF20actrakc
# 1588 ZTF20acsfcph
# 1589 ZTF20acggqfs
# 1590 ZTF20acvamqy
# 1591 ZTF20acusmhd
# 1592 ZTF20actgrnu
# 1593 ZTF20actlsch
# 1594 ZTF20actquxk
# 1595 ZTF20acvsxob
# 1596 ZTF20acvkjrm
# 1597 ZTF20acvlzjg
# 1598 ZTF20acveyyv
# 1599 ZTF20acvkwkt
# 1600 ZTF20acuosvy
# 1601 ZTF20actnran
# 1602 ZTF20acusgtg
# 1603 ZTF20aaulgdx
# 1604 ZTF20aciwcuz
# 1605 ZTF20acvbrbv
# 1606 ZTF20acueziy
# 1607 ZTF20acvbcrd
# 1608 ZTF20acngnrs
# 1609 ZTF20acwmcys
# 1610 ZTF20acwiojc
# 1611 ZTF20acqwnmo
# 1612 ZTF20acszhad
# 1613 ZTF20acvezau
# 1614 ZTF20acvfcef
# 1615 ZTF20acuduje
# 1616 ZTF20acuoclk
# 1617 ZTF20acuzlib
# 1618 ZTF20acveadu
# 1619 ZTF20acuowxj
# 1620 ZTF20acumcrz
# 1621 ZTF20acumrio
# 1622 ZTF20acusneh
# 1623 ZTF20acviwcr
# 1624 ZTF20acufkdp
# 1625 ZTF20acrmefv
# 1626 ZTF20acungqk
# 1627 ZTF18abqzouu
# 1628 ZTF20acuobve
# 1629 ZTF20actoabw
# 1630 ZTF20acrvrel
# 1631 ZTF20acggqsg
# 1632 ZTF20acwfcvr
# 1633 ZTF20acuimtq
# 1634 ZTF20actfeym
# 1635 ZTF20acvliry
# 1636 ZTF20aculkie
# 1637 ZTF20acuobqz
# 1638 ZTF20actlvpy
# 1639 ZTF20acbjgoa
# 1640 ZTF19abamfog
# 1641 ZTF20acwfftd
# 1642 ZTF20acvexen
# 1643 ZTF20acvczmt
# 1644 ZTF20acufbmq
# 1645 ZTF20actqnhg
# 1646 ZTF20acsebtw
# 1647 ZTF20acweyro
# 1648 ZTF20aculrhg
# 1649 ZTF20acwphph
# 1650 ZTF20acwtsbv
# 1651 ZTF20acwpixx
# 1652 ZTF20acwdnbw
# 1653 ZTF20acwfcfs
# 1654 ZTF20acwsaud
# 1655 ZTF20acwyihb
# 1656 ZTF20acwpibi
# 1657 ZTF20acwphqb
# 1658 ZTF20acwkwqn
# 1659 ZTF20acwfgiy
# 1660 ZTF20acwobak
# 1661 ZTF20acvyhlw
# 1662 ZTF20acvmzfv
# 1663 ZTF20acwoamm
# 1664 ZTF20acplkub
# 1665 ZTF20actrbvz
# 1666 ZTF20acvezck
# 1667 ZTF20acvdqtg
# 1668 ZTF20acvejem
# 1669 ZTF20acvchhw
# 1670 ZTF20acviwgj
# 1671 ZTF20acvevsn
# 1672 ZTF20acvagdq
# 1673 ZTF20acveumw
# 1674 ZTF20acwphbg
# 1675 ZTF20acuwwcx
# 1676 ZTF20acwoauy
# 1677 ZTF20acuzoei
# 1678 ZTF20acuueei
# 1679 ZTF20acvbaax
# 1680 ZTF20actveqm
# 1681 ZTF20acudclc
# 1682 ZTF20acwfanr
# 1683 ZTF20actkjaa
# 1684 ZTF19abwsfsl
# 1685 ZTF20acvglwq
# 1686 ZTF20acwqmul
# 1687 ZTF18acpbiqk
# 1688 ZTF20acvkqxy
# 1689 ZTF20acwcqnv
# 1690 ZTF20acvexpc
# 1691 ZTF20acwqqjs
# 1692 ZTF20acpvkhu
# 1693 ZTF20acxkfrm
# 1694 ZTF20acwytmh
# 1695 ZTF20acwkvgj
# 1696 ZTF20acwqlpq
# 1697 ZTF20acwnrty
# 1698 ZTF20acxtfqs
# 1699 ZTF20acxdawc
# 1700 ZTF20acxtetx
# 1701 ZTF20acwphyx
# 1702 ZTF20acxtgxr
# 1703 ZTF20acwlsro
# 1704 ZTF20acxtewc
# 1705 ZTF20acwscli
# 1706 ZTF20acxkxxr
# 1707 ZTF20acwytsu
# 1708 ZTF20aceokvr
# 1709 ZTF20acxyury
# 1710 ZTF20acwyicy
# 1711 ZTF20acxbbaj
# 1712 ZTF20acvfccx
# 1713 ZTF20acyhxqw
# 1714 ZTF20acusecr
# 1715 ZTF18aavmrqy
# 1716 ZTF20acwqjaw
# 1717 ZTF20acxtfrf
# 1718 ZTF20acwytht
# 1719 ZTF20acpjngk
# 1720 ZTF20acwytxn
# 1721 ZTF20acxklpf
# 1722 ZTF20acwgnxk
# 1723 ZTF20acukxat
# 1724 ZTF20acxffhe
# 1725 ZTF18ablvioz
# 1726 ZTF20acxnxbh
# 1727 ZTF20acxsxac
# 1728 ZTF20acxfccu
# 1729 ZTF20acxvdnd
# 1730 ZTF18acvhqfj
# 1731 ZTF20acwpfvq
# 1732 ZTF20acxlaih
# 1733 ZTF20acxzkkf
# 1734 ZTF20acwpbgv
# 1735 ZTF18aaaorhy
# 1736 ZTF20acwyoqx
# 1737 ZTF20acxnafa
# 1738 ZTF20acqhysq
# 1739 ZTF20acxvcoe
# 1740 ZTF20acwpibn
# 1741 ZTF20acwqqax
# 1742 ZTF20acwofhd
# 1743 ZTF20acwqkuz
# 1744 ZTF20acwncbd
# 1745 ZTF20acwxbyr
# 1746 ZTF20acvcxkz
# 1747 ZTF20acxcxkz
# 1748 ZTF20acuqyea
# 1749 ZTF20acvivzp
# 1750 ZTF20acxpurh
# 1751 ZTF20acxmxth
# 1752 ZTF20acuxfhx
# 1753 ZTF20acwqndp
# 1754 ZTF20acwpaov
# 1755 ZTF20acvezdt
# 1756 ZTF20acwyijj
# 1757 ZTF20actvrbc
# 1758 ZTF20acwxhka
# 1759 ZTF20acwyoxc
# 1760 ZTF20acxkfoh
# 1761 ZTF20acxnjzy
# 1762 ZTF20acwhpmj
# 1763 ZTF20acxuyqs
# 1764 ZTF20acwozwz
# 1765 ZTF20acwomqh
# 1766 ZTF20acxfcmr
# 1767 ZTF20acuxjtr
# 1768 ZTF20acpgolz
# 1769 ZTF20acxtgek
# 1770 ZTF20acympvl
# 1771 ZTF20acxbbru
# 1772 ZTF20acyrody
# 1773 ZTF20acwkbes
# 1774 ZTF20acyqzeu
# 1775 ZTF20acxncha
# 1776 ZTF20acywnjy
# 1777 ZTF20acxzqyp
# 1778 ZTF20acwphzx
# 1779 ZTF20acwmfpw
# 1780 ZTF20acypdlh
# 1781 ZTF20acxbnjd
# 1782 ZTF20acynjjo
# 1783 ZTF20acyybvq
# 1784 ZTF20acynlkj
# 1785 ZTF20acyrodz
# 1786 ZTF20acxpvhu
# 1787 ZTF20acxbadv
# 1788 ZTF20acxnjat
# 1789 ZTF20acymtcs
# 1790 ZTF20acxzsxb
# 1791 ZTF20acwnqcy
# 1792 ZTF20actoaia
# 1793 ZTF18aafeiiy
# 1794 ZTF18aakkvea
# 1795 ZTF20abeokzg
# 1796 ZTF20acynudw
# 1797 ZTF20abnorit
# 1798 ZTF18acvgvdz
# 1799 ZTF20acxznai
# 1800 ZTF20acxklrm
# 1801 ZTF20acnviht
# 1802 ZTF20acynaba
# 1803 ZTF20acwujgz
# 1804 ZTF20acynllu
# 1805 ZTF20aczfwjj
# 1806 ZTF20acyzsol
# 1807 ZTF20achpcvt
# 1808 ZTF20acwoftf
# 1809 ZTF20acwuiuo
# 1810 ZTF20acvdfmw
# 1811 ZTF20acytgxf
# 1812 ZTF20acytfkf
# 1813 ZTF18aahfbqp
# 1814 ZTF20acyvzbr
# 1815 ZTF20acxzhyu
# 1816 ZTF20acywbes
# 1817 ZTF20aczkvvy
# 1818 ZTF20acxvvnf
# 1819 ZTF18acejejm
# 1820 ZTF18aaisqmw
# 1821 ZTF20acyrhbo
# 1822 ZTF20acxuflv
# 1823 ZTF20acyjrsl
# 1824 ZTF20adabyww
# 1825 ZTF20acxycfh
# 1826 ZTF20acyvbhj
# 1827 ZTF20acyxrez
# 1828 ZTF20adadrhw
# 1829 ZTF20acxqnhn
# 1830 ZTF20acwjhpo
# 1831 ZTF20acxooam
# 1832 ZTF20acziblz
# 1833 ZTF20adadlqv
# 1834 ZTF20aczacag
# 1835 ZTF20acyntiu
# 1836 ZTF21aaabzap
# 1837 ZTF20aczgvcg
# 1838 ZTF20aczfytu
# 1839 ZTF21aaarlbp
# 1840 ZTF21aaaajfe
# 1841 ZTF21aaabvzf
# 1842 ZTF20acwrwpy
# 1843 ZTF21aaabvit
# 1844 ZTF20aczgoml
# 1845 ZTF21aaabxbd
# 1846 ZTF21aaabwfu
# 1847 ZTF21aaabvjk
# 1848 ZTF20aczhajq
# 1849 ZTF20aclnqle
# 1850 ZTF20acywefl
# 1851 ZTF20acyxwop
# 1852 ZTF21aaabucc
# 1853 ZTF21aaaovwg
# 1854 ZTF20aczgjdx
# 1855 ZTF20acztnts
# 1856 ZTF21aaabwgy
# 1857 ZTF20acgyjbh
# 1858 ZTF21aaabzdr
# 1859 ZTF20abpwtmi
# 1860 ZTF18aaqxbvf
# 1861 ZTF20aasjzhg
# 1862 ZTF20adadgpw
# 1863 ZTF20aczefsg
# 1864 ZTF21aaabubo
# 1865 ZTF21aaabzfo
# 1866 ZTF21aaabwzx
# 1867 ZTF21aaabwfl
# 1868 ZTF20aczguyy
# 1869 ZTF21aaampui
# 1870 ZTF20adadffg
# 1871 ZTF20aczwdhk
# 1872 ZTF21aaabxln
# 1873 ZTF21aaabzsj
# 1874 ZTF20adadshh
# 1875 ZTF20aczhaeu
# 1876 ZTF20adaghdo
# 1877 ZTF19aabyxhe
# 1878 ZTF20adadlqm
# 1879 ZTF21aaadiap
# 1880 ZTF21aaabaey
# 1881 ZTF20aczsjzc
# 1882 ZTF20acnvznn
# 1883 ZTF21aaaosoq
# 1884 ZTF21aaaadvr
# 1885 ZTF21aaagypx
# 1886 ZTF21aaahtln
# 1887 ZTF20adadmsg
# 1888 ZTF20adadsgm
# 1889 ZTF20adaduxg
# 1890 ZTF21aaaigfg
# 1891 ZTF20acrrssy
# 1892 ZTF21aaaouyd
# 1893 ZTF21aaaubig
# 1894 ZTF21aaabtyq
# 1895 ZTF21aaaovuq
# 1896 ZTF20acyybwo
# 1897 ZTF18aarrwmi
# 1898 ZTF20acyroek
# 1899 ZTF21aaabvkj
# 1900 ZTF20acyxzzf
# 1901 ZTF21aaaollj
# 1902 ZTF18aczergg
# 1903 ZTF20acyrodl
# 1904 ZTF21aaabucr
# 1905 ZTF20aczgvfe
# 1906 ZTF21aaaovbc
# 1907 ZTF21aaapesv
# 1908 ZTF21aaagzee
# 1909 ZTF21aaaadmo
# 1910 ZTF20adagnfh
# 1911 ZTF20acydasr
# 1912 ZTF20acasmjl
# 1913 ZTF19aaqzfuk
# 1914 ZTF21aabhtvy
# 1915 ZTF21aaaewsb
# 1916 ZTF20adadhnz
# 1917 ZTF20adaftef
# 1918 ZTF21aaaecrv
# 1919 ZTF21aaazbpi
# 1920 ZTF21aaafrnh
# 1921 ZTF21aaaoslt
# 1922 ZTF21aaabuoj
# 1923 ZTF19aadtgaj
# 1924 ZTF20acyxvbz
# 1925 ZTF20acwjnux
# 1926 ZTF20adafawd
# 1927 ZTF20adadrdh
# 1928 ZTF20adaenal
# 1929 ZTF21aaafzwx
# 1930 ZTF21aaaekui
# 1931 ZTF21aaaqzta
# 1932 ZTF20acwztut
# 1933 ZTF21aaadhjn
# 1934 ZTF20acxqxyw
# 1935 ZTF21aaaytyv
# 1936 ZTF21aaabviz
# 1937 ZTF21aaaytny
# 1938 ZTF21aaabzje
# 1939 ZTF21aaaosmn
# 1940 ZTF18abjyjfe
# 1941 ZTF21aaahliy
# 1942 ZTF20acyvzef
# 1943 ZTF21aaamxea
# 1944 ZTF20acymtod
# 1945 ZTF21aaaqtwd
# 1946 ZTF20acvfraq
# 1947 ZTF21aaaadmi
# 1948 ZTF20aczhtem
# 1949 ZTF20acywbdi
# 1950 ZTF21aaafgmv
# 1951 ZTF19aahsido
# 1952 ZTF20accxwro
# 1953 ZTF21aaavghg
# 1954 ZTF21aaabvrz
# 1955 ZTF21aaahyjj
# 1956 ZTF20acyydnc
# 1957 ZTF20adafguh
# 1958 ZTF21aaaawur
# 1959 ZTF21aaazieb
# 1960 ZTF21aaazjia
# 1961 ZTF21aaaldio
# 1962 ZTF21aaahuox
# 1963 ZTF21aabcyvd
# 1964 ZTF21aaaywdg
# 1965 ZTF21aaaiakl
# 1966 ZTF21aabyzjl
# 1967 ZTF21aabfson
# 1968 ZTF21aaahhso
# 1969 ZTF21aabjesm
# 1970 ZTF21aabjfbc
# 1971 ZTF21aaaelsm
# 1972 ZTF21aaahzpr
# 1973 ZTF21aaapfal
# 1974 ZTF21aabgtar
# 1975 ZTF19aanvdna
# 1976 ZTF21aaaovua
# 1977 ZTF21aabgois
# 1978 ZTF21aaaoviv
# 1979 ZTF19aaaojzi
# 1980 ZTF21aabygea
# 1981 ZTF21aaabzbr
# 1982 ZTF21aaavhbu
# 1983 ZTF21aaaotku
# 1984 ZTF21aaapswk
# 1985 ZTF20acyyavb
# 1986 ZTF20acxtdcm
# 1987 ZTF20aawbxmt
# 1988 ZTF21aabawlm
# 1989 ZTF21aabfwwl
# 1990 ZTF21aabhxxj
# 1991 ZTF21aaaalaf
# 1992 ZTF20acuofwe
# 1993 ZTF20adadgnw
# 1994 ZTF21aaaxtyk
# 1995 ZTF21aaanbla
# 1996 ZTF21aactywz
# 1997 ZTF21aadkhte
# 1998 ZTF21aabpszb
# 1999 ZTF21aaazhai
# 2000 ZTF21aaaiafo
# 2001 ZTF21aackkcp
# 2002 ZTF21aaabwem
# 2003 ZTF21aabyeil
# 2004 ZTF21aacvhsc
# 2005 ZTF21aabgdda
# 2006 ZTF21aabpnlm
# 2007 ZTF21aabavaz
# 2008 ZTF21aabyifm
# 2009 ZTF20aczgmai
# 2010 ZTF21aaaekuh
# 2011 ZTF21aadalct
# 2012 ZTF21aaarmhs
# 2013 ZTF21aaczpca
# 2014 ZTF21aabyrhy
# 2015 ZTF21aacwpnr
# 2016 ZTF21aaadamr
# 2017 ZTF21aaanzzg
# 2018 ZTF21aabhqng
# 2019 ZTF21aaaduti
# 2020 ZTF21aaaodzf
# 2021 ZTF21aacxung
# 2022 ZTF21aabyqps
# 2023 ZTF21aadrlji
# 2024 ZTF21aadoizf
# 2025 ZTF21aacndur
# 2026 ZTF21aaaaddl
# 2027 ZTF21aackkyn
# 2028 ZTF21aacdntt
# 2029 ZTF21aacnfez
# 2030 ZTF21aaarmti
# 2031 ZTF21aacngjg
# 2032 ZTF21aabqtsd
# 2033 ZTF20acqltqd
# 2034 ZTF21aabvdjw
# 2035 ZTF20acrseou
# 2036 ZTF18abwitkf
# 2037 ZTF21aaebrbd
# 2038 ZTF21aadsoer
# 2039 ZTF21aaclxjj
# 2040 ZTF21aaeoqxf
# 2041 ZTF21aadezmh
# 2042 ZTF21aadrxkv
# 2043 ZTF21aacujkj
# 2044 ZTF21aaeczqr
# 2045 ZTF21aafdnje
# 2046 ZTF20abajndg
# 2047 ZTF21aafepon
# 2048 ZTF21aadawow
# 2049 ZTF21aaetrdb
# 2050 ZTF21aadtkki
# 2051 ZTF21aacugzd
# 2052 ZTF21aaejeyu
# 2053 ZTF21aabvqlo
# 2054 ZTF21aaedpyk
# 2055 ZTF21aacpasn
# 2056 ZTF21aaespww
# 2057 ZTF21aadruyx
# 2058 ZTF21aafdxca
# 2059 ZTF19aaylipu
# 2060 ZTF18abxptoa
# 2061 ZTF21aacudxe
# 2062 ZTF21aabxztv
# 2063 ZTF21aacufqf
# 2064 ZTF21aabyiel
# 2065 ZTF19aaadmqv
# 2066 ZTF21aabvbkq
# 2067 ZTF21aadzuil
# 2068 ZTF21aafkwtk
# 2069 ZTF19absxwow
# 2070 ZTF21aadudgy
# 2071 ZTF21aaateuz
# 2072 ZTF21aacsuwx
# 2073 ZTF21aaagmlj
# 2074 ZTF21aaabrpu
# 2075 ZTF21aadrmpu
# 2076 ZTF21aaepqnb
# 2077 ZTF21aaewexx
# 2078 ZTF19aclkofz
# 2079 ZTF21aadktwq
# 2080 ZTF21aaarmon
# 2081 ZTF21aadrmok
# 2082 ZTF21aadrtcs
# 2083 ZTF18aajjhkq
# 2084 ZTF21aaayeby
# 2085 ZTF21aaetznl
# 2086 ZTF21aaasxel
# 2087 ZTF21aaekkbv
# 2088 ZTF19acbveqm
# 2089 ZTF21aacvrzy
# 2090 ZTF21aaecjfc
# 2091 ZTF18acgusct
# 2092 ZTF21aafncuz
# 2093 ZTF21aabxjqr
# 2094 ZTF21aaeeuqz
# 2095 ZTF21aadkgpm
# 2096 ZTF21aaawwgi
# 2097 ZTF21aacvupj
# 2098 ZTF21aaeuxxd
# 2099 ZTF21aadebss
# 2100 ZTF21aacufip
# 2101 ZTF21aacujrw
# 2102 ZTF21aadatfg
# 2103 ZTF18aahwquy
# 2104 ZTF21aacwleg
# 2105 ZTF21aadlkte
# 2106 ZTF21aaabvoj
# 2107 ZTF21aacscvb
# 2108 ZTF19aceviuo
# 2109 ZTF19aaafqfi
# 2110 ZTF21aadkuko
# 2111 ZTF21aafdxdg
# 2112 ZTF21aaekmoy
# 2113 ZTF19acnskyy
# 2114 ZTF21aafkktu
# 2115 ZTF21aaehinn
# 2116 ZTF21aagkfhm
# 2117 ZTF21aagkfgh
# 2118 ZTF21aadrtqz
# 2119 ZTF21aaeolbz
# 2120 ZTF21aaglxow
# 2121 ZTF21aagmqic
# 2122 ZTF21aahsgan
# 2123 ZTF21aagsypp
# 2124 ZTF21aagqdvr
# 2125 ZTF21aaglamm
# 2126 ZTF21aagyvtq
# 2127 ZTF21aagofpx
# 2128 ZTF21aagkswj
# 2129 ZTF21aagkhwf
# 2130 ZTF21aaezixn
# 2131 ZTF21aagojfe
# 2132 ZTF21aagoeny
# 2133 ZTF21aafnaaf
# 2134 ZTF21aafgljq
# 2135 ZTF21aahdqrg
# 2136 ZTF21aagshha
# 2137 ZTF21aagkzhd
# 2138 ZTF21aagkzwn
# 2139 ZTF21aagtcwd
# 2140 ZTF21aafnabs
# 2141 ZTF21aagycrc
# 2142 ZTF21aagqbvp
# 2143 ZTF21aafmltt
# 2144 ZTF21aagsjfx
# 2145 ZTF21aaglccp
# 2146 ZTF20acrjdjk
# 2147 ZTF21aagtcgb
# 2148 ZTF21aafjjee
# 2149 ZTF21aafsmnv
# 2150 ZTF21aafnacn
# 2151 ZTF21aaetnfe
# 2152 ZTF21aafhftg
# 2153 ZTF21aagkzmc
# 2154 ZTF21aagkzye
# 2155 ZTF21aagmryd
# 2156 ZTF18aafzers
# 2157 ZTF18abrbywo
# 2158 ZTF21aagktan
# 2159 ZTF21aagyewh
# 2160 ZTF21aaglret
# 2161 ZTF21aagmttf
# 2162 ZTF21aagdrdj
# 2163 ZTF21aagpthy
# 2164 ZTF21aaflcbk
# 2165 ZTF21aagpymw
# 2166 ZTF21aagtqna
# 2167 ZTF21aagsysd
# 2168 ZTF21aagteny
# 2169 ZTF21aagmrly
# 2170 ZTF20aamibse
# 2171 ZTF21aaiaqhh
# 2172 ZTF21aagqcnl
# 2173 ZTF21aafkgvj
# 2174 ZTF21aagnzjy
# 2175 ZTF21aahevxo
# 2176 ZTF21aagrjag
# 2177 ZTF21aagbeah
# 2178 ZTF21aagvmqr
# 2179 ZTF21aagkvqa
# 2180 ZTF21aagtvjq
# 2181 ZTF21aagyrvh
# 2182 ZTF21aafkpnp
# 2183 ZTF21aagtqpn
# 2184 ZTF21aagtqgz
# 2185 ZTF21aafdvxz
# 2186 ZTF21aagbpvf
# 2187 ZTF21aaglcat
# 2188 ZTF21aahgspm
# 2189 ZTF21aagocky
# 2190 ZTF19aabyoce
# 2191 ZTF21aaffxdt
# 2192 ZTF21aagocor
# 2193 ZTF21aaglayo
# 2194 ZTF21aaflcai
# 2195 ZTF21aagyscx
# 2196 ZTF21aagycmk
# 2197 ZTF21aagmoqw
# 2198 ZTF21aagtquu
# 2199 ZTF21aagkhca
# 2200 ZTF21aafnunh
# 2201 ZTF21aagnwkk
# 2202 ZTF21aaglrfh
# 2203 ZTF21aagsfzc
# 2204 ZTF21aagydov
# 2205 ZTF21aaheulr
# 2206 ZTF21aagsihi
# 2207 ZTF21aagtceu
# 2208 ZTF18aannern
# 2209 ZTF21aagqcfs
# 2210 ZTF21aagnvvk
# 2211 ZTF19aaywash
# 2212 ZTF21aaflzqy
# 2213 ZTF21aagppzg
# 2214 ZTF21aagkvka
# 2215 ZTF21aagydmn
# 2216 ZTF21aagxott
# 2217 ZTF18aatrllk
# 2218 ZTF21aahfizt
# 2219 ZTF21aafkugm
# 2220 ZTF21aagsceu
# 2221 ZTF21aahdpvi
# 2222 ZTF21aagpbkj
# 2223 ZTF21aagrbpi
# 2224 ZTF21aahdpqu
# 2225 ZTF21aagxmfv
# 2226 ZTF21aaglylh
# 2227 ZTF21aaigqir
# 2228 ZTF21aaglgcb
# 2229 ZTF19acfsjcu
# 2230 ZTF21aagtpyw
# 2231 ZTF21aagtqgq
# 2232 ZTF21aagygzv
# 2233 ZTF21aagtoic
# 2234 ZTF21aagkwjc
# 2235 ZTF21aagyxhz
# 2236 ZTF21aahfbkh
# 2237 ZTF21aagsgit
# 2238 ZTF21aagnqnz
# 2239 ZTF21aajgdeu
# 2240 ZTF21aagogqe
# 2241 ZTF21aagzzce
# 2242 ZTF21aagmzio
# 2243 ZTF21aagtuzm
# 2244 ZTF21aahnkut
# 2245 ZTF21aaglrzc
# 2246 ZTF21aagrzqz
# 2247 ZTF21aagkysp
# 2248 ZTF21aagyhax
# 2249 ZTF21aagtexi
# 2250 ZTF21aaiaeri
# 2251 ZTF21aagtcvb
# 2252 ZTF21aagtqug
# 2253 ZTF21aagoliy
# 2254 ZTF21aaipypa
# 2255 ZTF21aaiimpw
# 2256 ZTF21aahccrk
# 2257 ZTF21aahfjlo
# 2258 ZTF21aahargb
# 2259 ZTF21aahtmlu
# 2260 ZTF21aagtcsj
# 2261 ZTF19abjdoed
# 2262 ZTF21aahvuvi
# 2263 ZTF21aaivnap
# 2264 ZTF21aahsqsu
# 2265 ZTF21aaelbdm
# 2266 ZTF18aabiwhf
# 2267 ZTF21aagkxnb
# 2268 ZTF21aakilyd
# 2269 ZTF21aaiimkv
# 2270 ZTF21aagoeyx
# 2271 ZTF21aajdbhw
# 2272 ZTF21aaevrjl
# 2273 ZTF21aagolqa
# 2274 ZTF21aagofnn
# 2275 ZTF21aaeoxfd
# 2276 ZTF21aairadl
# 2277 ZTF21aahkvem
# 2278 ZTF21aajzhgk
# 2279 ZTF21aahptim
# 2280 ZTF21aahfjbs
# 2281 ZTF18aatgdph
# 2282 ZTF21aahrqjq
# 2283 ZTF21aagxmcs
# 2284 ZTF21aajaljq
# 2285 ZTF19aakppnj
# 2286 ZTF21aagtpro
# 2287 ZTF21aajmkrd
# 2288 ZTF21aagtoyj
# 2289 ZTF21aahptas
# 2290 ZTF21aaijnza
# 2291 ZTF21aagvmtk
# 2292 ZTF21aaihala
# 2293 ZTF21aaixlfe
# 2294 ZTF20abakrcq
# 2295 ZTF21aaigdly
# 2296 ZTF21aajvukh
# 2297 ZTF21aahgvie
# 2298 ZTF21aahsqng
# 2299 ZTF21aakljvi
# 2300 ZTF21aahcmkt
# 2301 ZTF18aawznqy
# 2302 ZTF21aajtszm
# 2303 ZTF21aaeundb
# 2304 ZTF21aaifyvi
# 2305 ZTF21aaizyqc
# 2306 ZTF21aagrhot
# 2307 ZTF21aalinof
# 2308 ZTF21aaksblr
# 2309 ZTF21aaivbei
# 2310 ZTF21aajfpwk
# 2311 ZTF21aakupth
# 2312 ZTF21aajtsba
# 2313 ZTF21aakzmaq
# 2314 ZTF21aakyqkb
# 2315 ZTF21aakymbv
# 2316 ZTF21aakybgi
# 2317 ZTF21aalgszc
# 2318 ZTF21aajvtsq
# 2319 ZTF21aalekwo
# 2320 ZTF18aadlaxo
# 2321 ZTF21aalgtgc
# 2322 ZTF21aalcsng
# 2323 ZTF21aaiqbqz
# 2324 ZTF21aalimtr
# 2325 ZTF21aakvrgb
# 2326 ZTF21aaexknb
# 2327 ZTF21aalezap
# 2328 ZTF21aahkcsq
# 2329 ZTF21aalgqup
# 2330 ZTF20aahcrjn
# 2331 ZTF21aajevjg
# 2332 ZTF21aallfyn
# 2333 ZTF21aaixibu
# 2334 ZTF21aaldmmf
# 2335 ZTF21aalenaa
# 2336 ZTF21aalxpnl
# 2337 ZTF21aagtekf
# 2338 ZTF19aanjdmy
# 2339 ZTF21aakildf
# 2340 ZTF21aakvroo
# 2341 ZTF21aakjhcb
# 2342 ZTF21aaldqxj
# 2343 ZTF21aaiwlyy
# 2344 ZTF21aajyufk
# 2345 ZTF21aamaufb
# 2346 ZTF19acekltt
# 2347 ZTF21aakijia
# 2348 ZTF21aagtqkw
# 2349 ZTF21aajuerd
# 2350 ZTF21aalydkl
# 2351 ZTF21aamokak
# 2352 ZTF21aalodzw
# 2353 ZTF21aajnefd
# 2354 ZTF21aaikpnj
# 2355 ZTF21aalkltz
# 2356 ZTF21aaluoym
# 2357 ZTF21aakbgpf
# 2358 ZTF21aaliivu
# 2359 ZTF21aalimun
# 2360 ZTF21aamauao
# 2361 ZTF21aaloddc
# 2362 ZTF21aakvhtz
# 2363 ZTF21aahnqnn
# 2364 ZTF21aaisube
# 2365 ZTF21aalnhby
# 2366 ZTF21aahqahr
# 2367 ZTF21aagmhzg
# 2368 ZTF21aalmtom
# 2369 ZTF21aalnyny
# 2370 ZTF21aajgdpo
# 2371 ZTF21aalgqsv
# 2372 ZTF21aalimya
# 2373 ZTF21aamgrxm
# 2374 ZTF21aaiucta
# 2375 ZTF21aahhars
# 2376 ZTF21aaekeqv
# 2377 ZTF21aahaksd
# 2378 ZTF21aamgcrv
# 2379 ZTF21aahlbxc
# 2380 ZTF21aahfjrr
# 2381 ZTF21aakygxl
# 2382 ZTF21aakdvst
# 2383 ZTF21aalepvi
# 2384 ZTF21aalmsrg
# 2385 ZTF21aadloxe
# 2386 ZTF21aahzspd
# 2387 ZTF21aagskhr
# 2388 ZTF21aamesud
# 2389 ZTF21aalofsw
# 2390 ZTF21aamhtui
# 2391 ZTF21aamttit
# 2392 ZTF21aaluqkp
# 2393 ZTF21aalcrjh
# 2394 ZTF21aaaagdb
# 2395 ZTF21aamsiqk
# 2396 ZTF21aalyvyw
# 2397 ZTF21aaldwvp
# 2398 ZTF21aamuniy
# 2399 ZTF20aclmdyn
# 2400 ZTF21aalokks
# 2401 ZTF21aamfcji
# 2402 ZTF21aaloalc
# 2403 ZTF18abdqwzs
# 2404 ZTF19aaapnrt
# 2405 ZTF21aamobbh
# 2406 ZTF21aagxvul
# 2407 ZTF18aakbuks
# 2408 ZTF21aakylsb
# 2409 ZTF21aanfuuk
# 2410 ZTF21aanfppb
# 2411 ZTF21aamhuym
# 2412 ZTF21aalxzly
# 2413 ZTF21aaleanv
# 2414 ZTF21aamucom
# 2415 ZTF21aalhrtk
# 2416 ZTF21aaljjvt
# 2417 ZTF21aajglah
# 2418 ZTF21aalpwpr
# 2419 ZTF21aanfuin
# 2420 ZTF21aambvzd
# 2421 ZTF21aamnngb
# 2422 ZTF21aamavyq
# 2423 ZTF21aamwyql
# 2424 ZTF18aadaexi
# 2425 ZTF21aamzuxi
# 2426 ZTF21aahczlb
# 2427 ZTF21aaknzxo
# 2428 ZTF21aaasirb
# 2429 ZTF21aamgrtx
# 2430 ZTF21aalknoo
# 2431 ZTF21aanfqch
# 2432 ZTF21aamayom
# 2433 ZTF21aannoix
# 2434 ZTF21aanncjl
# 2435 ZTF21aanehlz
# 2436 ZTF21aamwpdf
# 2437 ZTF21aamnnjb
# 2438 ZTF21aagyvrm
# 2439 ZTF21aanmthi
# 2440 ZTF21aanojbq
# 2441 ZTF21aamtsly
# 2442 ZTF21aakjbdm
# 2443 ZTF21aalxurs
# 2444 ZTF18aaviokz
# 2445 ZTF21aamcpte
# 2446 ZTF18aajawol
# 2447 ZTF21aamnnqm
# 2448 ZTF21aajbgex
# 2449 ZTF21aamgvsy
# 2450 ZTF21aaldqvq
# 2451 ZTF21aamiukc
# 2452 ZTF21aamkxbl
# 2453 ZTF21aalkknw
# 2454 ZTF21aanthfa
# 2455 ZTF21aankmzt
# 2456 ZTF21aalkjbl
# 2457 ZTF21aamjgfp
# 2458 ZTF21aamwzfi
# 2459 ZTF21aamxdns
# 2460 ZTF21aalfvel
# 2461 ZTF21aamqgid
# 2462 ZTF21aahjlqc
# 2463 ZTF21aanrhag
# 2464 ZTF21aanplys
# 2465 ZTF21aanortq
# 2466 ZTF21aanwfjk
# 2467 ZTF21aakjkec
# 2468 ZTF21aanrvcq
# 2469 ZTF19abnoeso
# 2470 ZTF21aantsla
# 2471 ZTF18acufhuz
# 2472 ZTF21aamwqim
# 2473 ZTF21aanhvpo
# 2474 ZTF21aanxdmk
# 2475 ZTF21aanyyde
# 2476 ZTF21aaobcrz
# 2477 ZTF21aamxduf
# 2478 ZTF21aalhgqi
# 2479 ZTF21aanxhjv
# 2480 ZTF21aamarfm
# 2481 ZTF21aamgsmb
# 2482 ZTF21aahfjcp
# 2483 ZTF18aazjked
# 2484 ZTF21aantupk
# 2485 ZTF21aaocgku
# 2486 ZTF21aanzcuj
# 2487 ZTF21aanswls
# 2488 ZTF21aantfmm
# 2489 ZTF20acpyldh
# 2490 ZTF21aaltwgl
# 2491 ZTF21aanefkx
# 2492 ZTF21aanuyro
# 2493 ZTF21aaocfbh
# 2494 ZTF21aantftk
# 2495 ZTF21aaogglh
# 2496 ZTF21aanvncv
# 2497 ZTF21aaocgci
# 2498 ZTF21aaocwmx
# 2499 ZTF21aaoiaar
# 2500 ZTF21aaodljj
# 2501 ZTF21aaoexgy
# 2502 ZTF21aanyfxr
# 2503 ZTF21aanyfqu
# 2504 ZTF21aanwbhk
# 2505 ZTF21aantxma
# 2506 ZTF21aaoekcj
# 2507 ZTF21aaoblhd
# 2508 ZTF21aaaokyp
# 2509 ZTF21aaoqcnh
# 2510 ZTF21aagyxdi
# 2511 ZTF21aaoghxo
# 2512 ZTF21aaogifb
# 2513 ZTF21aahfpwt
# 2514 ZTF21aamwvhr
# 2515 ZTF21aaobrbn
# 2516 ZTF21aanxiax
# 2517 ZTF21aapdumx
# 2518 ZTF21aapliyn
# 2519 ZTF21aaphlty
# 2520 ZTF21aapkfjx
# 2521 ZTF21aaomuka
# 2522 ZTF21aaopqqk
# 2523 ZTF21aanwmxn
# 2524 ZTF21aaocibg
# 2525 ZTF21aaowaxx
# 2526 ZTF21aapjmda
# 2527 ZTF21aaocrlm
# 2528 ZTF21aalhtgv
# 2529 ZTF18acjxyak
# 2530 ZTF21aapejbx
# 2531 ZTF21aaazkfd
# 2532 ZTF21aaoqbbw
# 2533 ZTF21aapfpod
# 2534 ZTF21aapecxb
# 2535 ZTF21aapjqdl
# 2536 ZTF21aapuvzb
# 2537 ZTF21aantfmz
# 2538 ZTF21aaphvyi
# 2539 ZTF21aaokuyo
# 2540 ZTF21aapdulz
# 2541 ZTF21aapjphz
# 2542 ZTF21aapdvus
# 2543 ZTF21aapqzxr
# 2544 ZTF21aaohrgf
# 2545 ZTF21aaplfah
# 2546 ZTF21aapfime
# 2547 ZTF21aapfdis
# 2548 ZTF21aaokzbt
# 2549 ZTF21aaprevg
# 2550 ZTF21aaopqyt
# 2551 ZTF21aaitlhy
# 2552 ZTF21aapdmnr
# 2553 ZTF21aapdxxs
# 2554 ZTF21aaoexjt
# 2555 ZTF21aapjmgf
# 2556 ZTF21aaoppzc
# 2557 ZTF21aapnikc
# 2558 ZTF20acyroke
# 2559 ZTF21aaovdlh
# 2560 ZTF21aaplooj
# 2561 ZTF21aapxpsp
# 2562 ZTF21aaplnef
# 2563 ZTF21aappehx
# 2564 ZTF21aaossxf
# 2565 ZTF21aaphzsw
# 2566 ZTF21aapkisz
# 2567 ZTF21aapnzbu
# 2568 ZTF21aaqgmjt
# 2569 ZTF21aapegtd
# 2570 ZTF21aapogvm
# 2571 ZTF20aarvpbq
# 2572 ZTF21aaplnxw
# 2573 ZTF21aaosgqa
# 2574 ZTF21aaopwrh
# 2575 ZTF21aaoghxv
# 2576 ZTF21aappcvm
# 2577 ZTF21aapfqdo
# 2578 ZTF21aaoekdf
# 2579 ZTF21aaokvio
# 2580 ZTF21aaprgdh
# 2581 ZTF21aaoqayg
# 2582 ZTF21aapfdqw
# 2583 ZTF21aapduck
# 2584 ZTF21aaprcuv
# 2585 ZTF21aapkkgx
# 2586 ZTF18aawjhmu
# 2587 ZTF21aapjksm
# 2588 ZTF21aaprddk
# 2589 ZTF21aapyiku
# 2590 ZTF21aaqafcf
# 2591 ZTF21aaqecpl
# 2592 ZTF21aaovhxe
# 2593 ZTF21aapkcmr
# 2594 ZTF21aapkhsc
# 2595 ZTF21aapouwv
# 2596 ZTF21aapomdb
# 2597 ZTF21aapnymf
# 2598 ZTF21aapdphm
# 2599 ZTF18aavdwmh
# 2600 ZTF21aapxogj
# 2601 ZTF21aaphjyn
# 2602 ZTF21aapvsxv
# 2603 ZTF21aapkvrd
# 2604 ZTF21aaqhhfu
# 2605 ZTF21aaprfqv
# 2606 ZTF21aapjcqb
# 2607 ZTF21aapdlnd
# 2608 ZTF21aappktx
# 2609 ZTF21aapnlfx
# 2610 ZTF19aachtie
# 2611 ZTF19aalfjvu
# 2612 ZTF21aappkns
# 2613 ZTF21aaqndlk
# 2614 ZTF21aaqhwgh
# 2615 ZTF21aapscpi
# 2616 ZTF21aaqonig
# 2617 ZTF21aaphjns
# 2618 ZTF21aapowty
# 2619 ZTF21aapfmut
# 2620 ZTF21aaokley
# 2621 ZTF21aapriwm
# 2622 ZTF21aaphjef
# 2623 ZTF18aassbst
# 2624 ZTF21aaotidq
# 2625 ZTF21aaqjmps
# 2626 ZTF21aapizqg
# 2627 ZTF21aaqfrxz
# 2628 ZTF21aaoqvzv
# 2629 ZTF21aaocrtt
# 2630 ZTF21aapzzgf
# 2631 ZTF21aapkaio
# 2632 ZTF21aaprfkc
# 2633 ZTF21aaptnwj
# 2634 ZTF21aapffqd
# 2635 ZTF21aapkzox
# 2636 ZTF21aaqhqke
# 2637 ZTF21aaqftuq
# 2638 ZTF21aapiwls
# 2639 ZTF21aapzgtu
# 2640 ZTF21aapvxnf
# 2641 ZTF21aapkiaw
# 2642 ZTF21aaqpyfm
# 2643 ZTF21aaqrbdq
# 2644 ZTF21aapnydy
# 2645 ZTF21aappdev
# 2646 ZTF21aapfowm
# 2647 ZTF21aaqraul
# 2648 ZTF21aaqftpz
# 2649 ZTF21aaqpykm
# 2650 ZTF20aartqux
# 2651 ZTF21aapxtqg
# 2652 ZTF21aaptouk
# 2653 ZTF21aaqqwln
# 2654 ZTF21aaqmgnp
# 2655 ZTF21aaqjmnn
# 2656 ZTF21aaquyqa
# 2657 ZTF21aapfpov
# 2658 ZTF21aaqvsvw
# 2659 ZTF21aapehpx
# 2660 ZTF21aaqizwm
# 2661 ZTF21aaqgedd
# 2662 ZTF21aaqjhff
# 2663 ZTF21aaoqefp
# 2664 ZTF21aapkzug
# 2665 ZTF21aaqkqwq
# 2666 ZTF21aaqgrrf
# 2667 ZTF21aaqwndb
# 2668 ZTF21aaqvsvc
# 2669 ZTF21aaqyckv
# 2670 ZTF21aaphpor
# 2671 ZTF21aaqybuv
# 2672 ZTF21aaquhqr
# 2673 ZTF21aaqwkbv
# 2674 ZTF21aaqwjlz
# 2675 ZTF21aapdvea
# 2676 ZTF21aaqsprr
# 2677 ZTF21aaqwlgv
# 2678 ZTF21aaqldxc
# 2679 ZTF21aaqwbgq
# 2680 ZTF21aaqyeso
# 2681 ZTF21aaquppw
# 2682 ZTF21aaqyetj
# 2683 ZTF21aaqvhgk
# 2684 ZTF21aaqwfqe
# 2685 ZTF21aaqujke
# 2686 ZTF21aaqqlfw
# 2687 ZTF21aaquymq
# 2688 ZTF21aaquyjp
# 2689 ZTF21aaraqpr
# 2690 ZTF21aaqldsk
# 2691 ZTF21aaqldsj
# 2692 ZTF21aaqdxzv
# 2693 ZTF21aaqyuun
# 2694 ZTF21aaquiwu
# 2695 ZTF21aarasvn
# 2696 ZTF21aarazam
# 2697 ZTF21aaptocc
# 2698 ZTF21aapjlyx
# 2699 ZTF21aapjmpq
# 2700 ZTF21aaqtbaj
# 2701 ZTF21aapvoqy
# 2702 ZTF21aaqmqyp
# 2703 ZTF21aaqytjr
# 2704 ZTF21aaqzkhx
# 2705 ZTF18aatezaj
# 2706 ZTF21aaqzmdg
# 2707 ZTF21aaqvuyf
# 2708 ZTF21aaqugxm
# 2709 ZTF21aarcldd
# 2710 ZTF18acsremz
# 2711 ZTF21aarasky
# 2712 ZTF21aarbjun
# 2713 ZTF21aarkoym
# 2714 ZTF21aarejnt
# 2715 ZTF21aaqzrat
# 2716 ZTF21aardybv
# 2717 ZTF21aappdnv
# 2718 ZTF21aaqztcg
# 2719 ZTF21aaqhuhd
# 2720 ZTF21aarakan
# 2721 ZTF21aaqprjz
# 2722 ZTF21aasfseg
# 2723 ZTF21aasdhhn
# 2724 ZTF21aarhikz
# 2725 ZTF21aarqkes
# 2726 ZTF21aaridax
# 2727 ZTF21aarhnwn
# 2728 ZTF21aaradzm
# 2729 ZTF21aarenhl
# 2730 ZTF21aaragyr
# 2731 ZTF21aasbntf
# 2732 ZTF21aarjczf
# 2733 ZTF21aarmkuj
# 2734 ZTF21aasbxng
# 2735 ZTF21aaqxiaj
# 2736 ZTF21aarhzdh
# 2737 ZTF21aaqyqux
# 2738 ZTF21aarrrsx
# 2739 ZTF21aarucpz
# 2740 ZTF21aaqzqaa
# 2741 ZTF21aaqupdt
# 2742 ZTF21aassaom
# 2743 ZTF21aarcobt
# 2744 ZTF20abvdtgl
# 2745 ZTF18aaszvfn
# 2746 ZTF20abtcijp
# 2747 ZTF21aascwrr
# 2748 ZTF21aasdhhy
# 2749 ZTF21aastazz
# 2750 ZTF21aarstlf
# 2751 ZTF21aartgiv
# 2752 ZTF21aarigsr
# 2753 ZTF21aarohyu
# 2754 ZTF21aarycru
# 2755 ZTF21aasctwo
# 2756 ZTF21aarrwdu
# 2757 ZTF21aarrplo
# 2758 ZTF21aargjdw
# 2759 ZTF21aasgffc
# 2760 ZTF21aarnjyd
# 2761 ZTF21aaswtok
# 2762 ZTF21aasxgne
# 2763 ZTF21aasbjgq
# 2764 ZTF21aarwlht
# 2765 ZTF21aastzsn
# 2766 ZTF21aarmuxl
# 2767 ZTF21aatghue
# 2768 ZTF21aasyayn
# 2769 ZTF20acselme
# 2770 ZTF21aatscez
# 2771 ZTF21aasafkl
# 2772 ZTF21aarybxo
# 2773 ZTF21aaqyqwk
# 2774 ZTF21aasuazz
# 2775 ZTF21aasufxv
# 2776 ZTF21aassamj
# 2777 ZTF21aaskwgm
# 2778 ZTF21aarxsfm
# 2779 ZTF21aarojxa
# 2780 ZTF21aaucuqu
# 2781 ZTF21aasaxdk
# 2782 ZTF21aauaksp
# 2783 ZTF21aatjavc
# 2784 ZTF21aasyydo
# 2785 ZTF18aansqom
# 2786 ZTF21aatmfnz
# 2787 ZTF21aatwkkt
# 2788 ZTF21aauapli
# 2789 ZTF21aaswvyc
# 2790 ZTF21aarycyl
# 2791 ZTF21aarskup
# 2792 ZTF21aarmjai
# 2793 ZTF21aatlbsi
# 2794 ZTF20aaobxzx
# 2795 ZTF19aawevgq
# 2796 ZTF21aasgcve
# 2797 ZTF21aaufvpg
# 2798 ZTF18aatjfoe
# 2799 ZTF21aasaxfg
# 2800 ZTF21aatyplr
# 2801 ZTF21aaunadg
# 2802 ZTF21aardsgh
# 2803 ZTF21aatnpnl
# 2804 ZTF21aartehc
# 2805 ZTF21aareexg
# 2806 ZTF21aatdzmt
# 2807 ZTF21aarzgql
# 2808 ZTF21aathrnx
# 2809 ZTF21aaubuml
# 2810 ZTF21aasbqqw
# 2811 ZTF21aaugbus
# 2812 ZTF21aaupkow
# 2813 ZTF21aatvcdl
# 2814 ZTF21aasyzkt
# 2815 ZTF21aavoqpl
# 2816 ZTF21aatvqcl
# 2817 ZTF21aatitlf
# 2818 ZTF21aatpsky
# 2819 ZTF21aaublej
# 2820 ZTF21aaufwyh
# 2821 ZTF21aaufthj
# 2822 ZTF21aaucuyq
# 2823 ZTF21aatisro
# 2824 ZTF21aavidfz
# 2825 ZTF21aatsafx
# 2826 ZTF21aaqmoof
# 2827 ZTF21aatlesr
# 2828 ZTF21aavacsc
# 2829 ZTF21aavuprt
# 2830 ZTF21aavheiv
# 2831 ZTF21aatwlhj
# 2832 ZTF21aatjypi
# 2833 ZTF21aatnxwt
# 2834 ZTF21aatklhw
# 2835 ZTF21aauvmck
# 2836 ZTF21aatkdcw
# 2837 ZTF21aapdpup
# 2838 ZTF21aateglh
# 2839 ZTF21aaskyvp
# 2840 ZTF21aauamtx
# 2841 ZTF21aavqwhh
# 2842 ZTF21aatwkkg
# 2843 ZTF21aasbkrl
# 2844 ZTF21aavqphe
# 2845 ZTF21aawgvpe
# 2846 ZTF21aavodtn
# 2847 ZTF21aatiolj
# 2848 ZTF21aavadbu
# 2849 ZTF21aaukcog
# 2850 ZTF21aavhsdw
# 2851 ZTF21aavhnpk
# 2852 ZTF21aavodst
# 2853 ZTF21aavxruq
# 2854 ZTF21aauuybx
# 2855 ZTF21aavozbk
# 2856 ZTF21aavhlry
# 2857 ZTF21aavasiz
# 2858 ZTF21aawgvpj
# 2859 ZTF21aavutkm
# 2860 ZTF21aauzzny
# 2861 ZTF21aaszrim
# 2862 ZTF18aavvnzu
# 2863 ZTF21aavotzn
# 2864 ZTF21aawckpe
# 2865 ZTF21aaupsoq
# 2866 ZTF21aawmdxw
# 2867 ZTF21aawmtug
# 2868 ZTF21aawlvmx
# 2869 ZTF21aawlmzl
# 2870 ZTF21aavxcdr
# 2871 ZTF21aawihwx
# 2872 ZTF21aavbrwr
# 2873 ZTF21aawxqia
# 2874 ZTF21aawogdl
# 2875 ZTF21aawzkdr
# 2876 ZTF21aawyyha
# 2877 ZTF21aavuprl
# 2878 ZTF21aaualej
# 2879 ZTF18aahsuyl
# 2880 ZTF21aaxjjwf
# 2881 ZTF21aawqczk
# 2882 ZTF21aavhmav
# 2883 ZTF21aaxljzc
# 2884 ZTF21aaxjiii
# 2885 ZTF21aawtewf
# 2886 ZTF21aaxhzru
# 2887 ZTF21aawzsew
# 2888 ZTF21aawqpuf
# 2889 ZTF21aawgzda
# 2890 ZTF21aaxgwtb
# 2891 ZTF21aaxjvyl
# 2892 ZTF21aaxgzln
# 2893 ZTF21aavoete

# %%
f = ascii.read("RCF_source.ascii") #ascii file containing the names of sources and their saved dates
sources = f['col1']

#sources = ['ZTF21aagygzv', 'ZTF21aacufip']
    
for source in sources:
    
    flag = 0
    ztfname = source
    
    for i in range (len(get_source_api(ztfname)['comments'])):
        
        comment = get_source_api(ztfname)['comments'][i]['text']
        
        if comment == 'Uploaded to TNS':
            flag = 1
        
    if flag == 0:
        
        print (source)
        
        post_comment(ztfname, 'Uploaded to TNS')
# Out:
# ZTF20acwytxn
# ZTF20acqqdkl
# ZTF21aacscvb
# ZTF21aacpasn
# ZTF21aaaaddl
# ZTF20acgyjbh
# ZTF21aabxztv
# ZTF18aajjhkq
# ZTF21aadoizf
# ZTF21aacvhsc
# ZTF21aaateuz
# ZTF21aaaosmn
# ZTF21aaahyjj
# ZTF21aaaewsb
# ZTF21aadalct
# ZTF21aaczpca
# ZTF21aabyqps
# ZTF21aabcyvd
# ZTF21aaabzje
# ZTF21aaabrpu
# ZTF20acytfkf
# ZTF20aasjzhg
# ZTF21aaazieb
# ZTF21aaasxel
# ZTF21aaaoviv
# ZTF21aaabwem
# ZTF20acxpvhu
# ZTF21aacxung
# ZTF21aabfson
# ZTF21aaabwfl
# ZTF21aabhxxj
# ZTF21aaafgmv
# ZTF21aaadiap
# ZTF21aaabwzx
# ZTF21aaaalaf
# ZTF20adaghdo
# ZTF21aaaldio
# ZTF20acymtcs
# ZTF21aaaotku
# ZTF21aaahuox
# ZTF21aaabxln
# ZTF21aaabvkj
# ZTF21aaabubo
# ZTF21aaaawur
# ZTF20adaftef
# ZTF20acwytht
# ZTF21aaagzee
# ZTF21aaabaey
# ZTF21aaaadmo
# ZTF20acztnts
# ZTF20acvezdt
# ZTF21aaabvit
# ZTF20adadlqm
# ZTF20aczacag
# ZTF20acyrodl
# ZTF21aaabvjk
# ZTF20adadsgm
# ZTF20adadlqv
# ZTF20aczgoml
# ZTF20acywefl
# ZTF20acxzkkf
# ZTF20acxtewc
# ZTF20acxsxac
# ZTF20acxqnhn
# ZTF20acwytmh
# ZTF20acwphqb
# ZTF20acwgnxk
# ZTF20acwfftd
# ZTF20acweyro
# ZTF20acvjlev
# ZTF20acveadu
# ZTF20acuspji
# ZTF20acuoxrx
# ZTF20acukxat
# ZTF20acueziy
# ZTF20acudkao
# ZTF20actquzl
# ZTF20achpcvt
# ZTF20adadshh
# ZTF20adadffg
# ZTF20aczfwjj
# ZTF20acyybvq
# ZTF20acxooam
# ZTF20acwkvgj
# ZTF20aczsjzc
# ZTF20aczhajq
# ZTF20acyvbhj
# ZTF20acwpixx
# ZTF20acyzsol
# ZTF20acxbnjd
# ZTF20acvdqtg
# ZTF20acuowxj
# ZTF20acxmxth
# ZTF20acyrhbo
# ZTF20acyybwo
# ZTF20acynaba
# ZTF20acwxbyr
# ZTF20acprmuv
# ZTF20acwyoxc
# ZTF20acwyihb
# ZTF20acwqndp
# ZTF20acwomqh
# ZTF20acuobve
# ZTF20acxpurh
# ZTF20acwpaov
# ZTF20acwdnbw
# ZTF20acvkjrm
# ZTF20acvbcrd
# ZTF20acxbbaj
# ZTF20acwncbd
# ZTF20acwkwqn
# ZTF20acuzlib
# ZTF20acusneh
# ZTF20actvfgr
# ZTF20acxlaih
# ZTF20acwozwz
# ZTF20acwfcfs
# ZTF20acumrio
# ZTF20actvpyc
# ZTF20actnzzk
# ZTF20acpevli
# ZTF20acoxtxr
# ZTF20actpuan
# ZTF20actljfs
# ZTF20acxnxbh
# ZTF20acwoamm
# ZTF20acurrzb
# ZTF20acxkfrm
# ZTF20acvejem
# ZTF20acqnfzn
# ZTF20acqhysq
# ZTF20acpkses
# ZTF20acvbrbv
# ZTF20actnzxm
# ZTF20acqnthg
# ZTF20acpzaoa
# ZTF20acpvxmk
# ZTF20acpksoc
# ZTF20acpeldz
# ZTF20acvkqxy
# ZTF20actkmks
# ZTF19aanbpus
# ZTF20actodrq
# ZTF20actfeym
# ZTF20acusqsp
# ZTF20aculruc
# ZTF20actoakx
# ZTF20acrbpqd
# ZTF20acpqagp
# ZTF20acviwcr
# ZTF20acvagdq
# ZTF20acurtpj
# ZTF20acuimtq
# ZTF20acuaqlf
# ZTF20actawpa
# ZTF20acsfdnn
# ZTF20acplkub
# ZTF20acuzjqk
# ZTF20actfoxr
# ZTF20acsesce
# ZTF20acrufey
# ZTF20acrqeje
# ZTF20acordqz
# ZTF20actpbck
# ZTF20acpklpq
# ZTF20acrhrcy
# ZTF20acqvwzb
# ZTF20aclnqle
# ZTF20acuiuvw
# ZTF20acucbek
# ZTF20actocyw
# ZTF20acpgnsn
# ZTF20acgyvgs
# ZTF20acpgokr
# ZTF20acrxrfv
# ZTF20acrudzk
# ZTF20acqvwzm
# ZTF20acquetr
# ZTF20acrdemq
# ZTF20acqlfwb
# ZTF20acqexmr
# ZTF20acphcdv
# ZTF20acpgnej
# ZTF20acqzjqz
# ZTF20acpkjsn
# ZTF20acpbnzr
# ZTF20aclwwhz
# ZTF20abvyare
# ZTF20acplqek
# ZTF20acpgzif
# ZTF18aabbemk
# ZTF20acpkled
# ZTF20acowata
# ZTF20acoredl
# ZTF20acfaonm
# ZTF20acowpur
# ZTF20acoyyly
# ZTF20abzpxxu
# ZTF20abyjoxb
# ZTF20abupbub

# %%
def get_obsrun(run_id):
    
    url = BASEURL+'api/observing_run/'+run_id
    response = api('GET',url)
    
    return response

# %%
def get_offset(obj_id):
    
    url = BASEURL+'api/sources/'+obj_id+'/offsets'
    
    #data = {  "facility": 'P200'}

    response = api('GET',url)
    #response = api('GET',url,  data=data)
    
    return response

# %%
def get_png(obj_id):
    
    url = BASEURL+'api/sources/'+obj_id+'/finder'
    
    #data = {  "facility": 'P200'}

    response = api('GET',url)
    #response = api('GET',url,  data=data)
    
    return response

# %%
sources = ['ZTF21aaepqnb', 'ZTF20acpevlh', 'ZTF20abdzjpn', 'ZTF19acbwjjz', 'ZTF19aawmhbu', 'ZTF19aafnfis', 'ZTF19aaednlp']
           
for source in sources:
    
    a = get_IAUname(source)
    
    print (source, a)
# Out:
# ZTF21aaepqnb AT 2021akk
# ZTF20acpevlh AT 2020zcj
# ZTF20abdzjpn AT 2020lry
# ZTF19acbwjjz AT 2019rrd
# ZTF19aawmhbu AT 2019hth
# ZTF19aafnfis AT 2019aafa
# ZTF19aaednlp AT 2019aae

# %%
f = ascii.read("RCF_sources_copy.ascii") #ascii file containing the names of sources and their saved dates
sources = f['col1']

#sources = ['ZTF21aagqdvr']

for source in sources:
    
    a = get_all_spectra_len(source)
    
    if a == 0:
        continue
        
    else:
        print (source, a)
# Out:
# ZTF21aaipypa 2
# ZTF21aagxmfv 1
# ZTF20acqgklx 2
# ZTF21aagsihi 1
# ZTF21aagpymw 2
# ZTF21aagoeny 2
# ZTF21aabyifm 1
# ZTF20acytgxf 5
# ZTF21aagtpro 2
# ZTF21aagqcfs 1
# ZTF21aagkhwf 1
# ZTF21aagbpvf 2
# ZTF21aabpnlm 5
# ZTF21aaeoqxf 7
# ZTF20acpjbgc 2
# ZTF21aacvhsc 1
# ZTF21aadkhte 8
# ZTF21aabjfbc 4
# ZTF21aaarmti 1
# ZTF21aaarlbp 1
# ZTF20acyxrez 3
# ZTF21aaabviz 1
# ZTF21aaabuoj 1
# ZTF21aabpszb 2
# ZTF20acyyavb 2
# ZTF20acuhgar 2
# ZTF20acvebcu 1
# ZTF20acrzwvx 2
# ZTF21aaaubig 3
# ZTF21aaabtyq 1
# ZTF20acwpibi 2
# ZTF21aaampui 6
# ZTF20adadrhw 8
# ZTF20acyqzeu 2
# ZTF20acxdawc 1
# ZTF20acwqqjs 1
# ZTF20acwobku 9
# ZTF20acuosvy 1
# ZTF20acuhren 1
# ZTF20actpqgc 6
# ZTF20acynllu 2
# ZTF20acorjop 1
# ZTF20acxvvnf 1
# ZTF20acrinvz 3
# ZTF20acpjfln 3
# ZTF20acynjjo 3
# ZTF20acwujgz 2
# ZTF20acxzqyp 2
# ZTF20acxncha 3
# ZTF20actdeqw 4
# ZTF20acwmpsj 2
# ZTF20acwcfvx 1
# ZTF20acvmzfv 2
# ZTF20acufmte 3
# ZTF20acwgxhk 3
# ZTF20acumekm 2
# ZTF20actekrw 5
# ZTF20acpqbfu 2
# ZTF20acvziuf 2
# ZTF20acvjagm 10
# ZTF20actskcf 2
# ZTF20acpvbbh 5
# ZTF20acuzfpk 1
# ZTF20acphdcg 7
# ZTF20acumxrh 2
# ZTF20actnuls 4
# ZTF20acugxbm 1
# ZTF20acqntkr 2
# ZTF20acqksdi 3
# ZTF20actqnhg 12
# ZTF20actiymd 2
# ZTF20actddoh 2
# ZTF20acphvzi 1
# ZTF20acggqfs 1
# ZTF20acrerzb 2
# ZTF20acrcewc 1
# ZTF20acqzpta 1
# ZTF20acpumut 1
# ZTF20acpkqhq 1
# ZTF20acpmxdg 1
# ZTF20acqzjqz 3
# ZTF20acpylns 1
# ZTF20acplhku 2
# ZTF20acpkjsn 1
# ZTF20acqoiyt 4
# ZTF20acqelhh 2
# ZTF20acpprmy 1
# ZTF20acpjcoe 1
# ZTF20acphdbu 1
# ZTF20acphccy 1
# ZTF20acpjqxp 2
# ZTF20acpiywu 2
# ZTF20acpbnzr 1
# ZTF20acowuix 2
# ZTF20aciojzg 1
# ZTF20acpujxl 2
# ZTF20acpkled 1
# ZTF20acowata 1
# ZTF20acoredl 2
# ZTF20acfaonm 1
# ZTF20acoyrlm 1
# ZTF20acoykif 1
# ZTF20acowpur 1

# %%
get_classification('ZTF21aaanbla')
# Out:
# ('No Classification found', 'None')

# %%
len(get_source_api('ZTF20abjgqic')['comments'])
# Out:
# 7

# %%
get_required_spectrum_id('ZTF21aagsihi')
# Out:
# Please choose from the following spectra:
#
# 1 ) spectrum name:  ZTF21aagsihi_20210215.w.txt spectrum date: 2021-02-16
# Choose spectrum to upload: 1
# 1425

# %%
a = get_spectrum_api('1425')
print (a['data'])
# Out:
# {'modified': '2021-02-16T09:58:59.603207', 'assignment_id': None, 'wavelengths': [4020.0, 4029.2, 4038.4, 4047.6, 4056.8, 4066.0, 4075.2, 4084.4, 4093.6, 4102.8, 4112.0, 4121.2, 4130.4, 4139.6, 4148.8, 4158.0, 4167.2, 4176.4, 4185.6, 4194.8, 4204.0, 4213.2, 4222.4, 4231.6, 4240.8, 4250.0, 4259.2, 4268.4, 4277.6, 4286.8, 4296.0, 4305.2, 4314.4, 4323.6, 4332.8, 4342.0, 4351.2, 4360.4, 4369.6, 4378.8, 4388.0, 4397.2, 4406.4, 4415.6, 4424.8, 4434.0, 4443.2, 4452.4, 4461.6, 4470.8, 4480.0, 4489.2, 4498.4, 4507.6, 4516.8, 4526.0, 4535.2, 4544.4, 4553.6, 4562.8, 4572.0, 4581.2, 4590.4, 4599.6, 4608.8, 4618.0, 4627.2, 4636.4, 4645.6, 4654.8, 4664.0, 4673.2, 4682.4, 4691.6, 4700.8, 4710.0, 4719.2, 4728.4, 4737.6, 4746.8, 4756.0, 4765.2, 4774.4, 4783.6, 4792.8, 4802.0, 4811.2, 4820.4, 4829.6, 4838.8, 4848.0, 4857.2, 4866.4, 4875.6, 4884.8, 4894.0, 4903.2, 4912.4, 4921.6, 4930.8, 4940.0, 4949.2, 4958.4, 4967.6, 4976.8, 4986.0, 4995.2, 5004.4, 5013.6, 5022.8, 5032.0, 5041.2, 5050.4, 5059.6, 5068.8, 5078.0, 5087.2, 5096.4, 5105.6, 5114.8, 5124.0, 5133.2, 5142.4, 5151.6, 5160.8, 5170.0, 5179.2, 5188.4, 5197.6, 5206.8, 5216.0, 5225.2, 5234.4, 5243.6, 5252.8, 5262.0, 5271.2, 5280.4, 5289.6, 5298.8, 5308.0, 5317.2, 5326.4, 5335.6, 5344.8, 5354.0, 5363.2, 5372.4, 5381.6, 5390.8, 5400.0, 5409.2, 5418.4, 5427.6, 5436.8, 5446.0, 5455.2, 5464.4, 5473.6, 5482.8, 5492.0, 5501.2, 5510.4, 5519.6, 5528.8, 5538.0, 5547.2, 5556.4, 5565.6, 5574.8, 5584.0, 5593.2, 5602.4, 5611.6, 5620.8, 5630.0, 5639.2, 5648.4, 5657.6, 5666.8, 5676.0, 5685.2, 5694.4, 5703.6, 5712.8, 5722.0, 5731.2, 5740.4, 5749.6, 5758.8, 5768.0, 5777.2, 5786.4, 5795.6, 5804.8, 5814.0, 5823.2, 5832.4, 5841.6, 5850.8, 5860.0, 5869.2, 5878.4, 5887.6, 5896.8, 5906.0, 5915.2, 5924.4, 5933.6, 5942.8, 5952.0, 5961.2, 5970.4, 5979.6, 5988.8, 5998.0, 6007.2, 6016.4, 6025.6, 6034.8, 6044.0, 6053.2, 6062.4, 6071.6, 6080.8, 6090.0, 6099.2, 6108.4, 6117.6, 6126.8, 6136.0, 6145.2, 6154.4, 6163.6, 6172.8, 6182.0, 6191.2, 6200.4, 6209.6, 6218.8, 6228.0, 6237.2, 6246.4, 6255.6, 6264.8, 6274.0, 6283.2, 6292.4, 6301.6, 6310.8, 6320.0, 6329.2, 6338.4, 6347.6, 6356.8, 6366.0, 6375.2, 6384.4, 6393.6, 6402.8, 6412.0, 6421.2, 6430.4, 6439.6, 6448.8, 6458.0, 6467.2, 6476.4, 6485.6, 6494.8, 6504.0, 6513.2, 6522.4, 6531.6, 6540.8, 6550.0, 6559.2, 6568.4, 6577.6, 6586.8, 6596.0, 6605.2, 6614.4, 6623.6, 6632.8, 6642.0, 6651.2, 6660.4, 6669.6, 6678.8, 6688.0, 6697.2, 6706.4, 6715.6, 6724.8, 6734.0, 6743.2, 6752.4, 6761.6, 6770.8, 6780.0, 6789.2, 6798.4, 6807.6, 6816.8, 6826.0, 6835.2, 6844.4, 6853.6, 6862.8, 6872.0, 6881.2, 6890.4, 6899.6, 6908.8, 6918.0, 6927.2, 6936.4, 6945.6, 6954.8, 6964.0, 6973.2, 6982.4, 6991.6, 7000.8, 7010.0, 7019.2, 7028.4, 7037.6, 7046.8, 7056.0, 7065.2, 7074.4, 7083.6, 7092.8, 7102.0, 7111.2, 7120.4, 7129.6, 7138.8, 7148.0, 7157.2, 7166.4, 7175.6, 7184.8, 7194.0, 7203.2, 7212.4, 7221.6, 7230.8, 7240.0, 7249.2, 7258.4, 7267.6, 7276.8, 7286.0, 7295.2, 7304.4, 7313.6, 7322.8, 7332.0, 7341.2, 7350.4, 7359.6, 7368.8, 7378.0, 7387.2, 7396.4, 7405.6, 7414.8, 7424.0, 7433.2, 7442.4, 7451.6, 7460.8, 7470.0, 7479.2, 7488.4, 7497.6, 7506.8, 7516.0, 7525.2, 7534.4, 7543.6, 7552.8, 7562.0, 7571.2, 7580.4, 7589.6, 7598.8, 7608.0, 7617.2, 7626.4, 7635.6, 7644.8, 7654.0, 7663.2, 7672.4, 7681.6, 7690.8, 7700.0, 7709.2, 7718.4, 7727.6, 7736.8, 7746.0, 7755.2, 7764.4, 7773.6, 7782.8, 7792.0, 7801.2, 7810.4, 7819.6, 7828.8, 7838.0, 7847.2, 7856.4, 7865.6, 7874.8, 7884.0, 7893.2, 7902.4, 7911.6, 7920.8, 7930.0, 7939.2, 7948.4, 7957.6, 7966.8, 7976.0, 7985.2, 7994.4], 'altdata': {}, 'fluxes': [0.9428958013480802, 0.8773106666111716, 0.6723723625902095, 0.5243708060877241, 0.7862650531876964, 0.6750019116305646, 0.581699086346403, 0.49731507664967756, 0.625129964514136, 0.615806957869279, 0.7355935743247591, 0.6142038685185203, 0.6853484875329727, 0.6522371942883014, 0.7639380001318654, 0.7738627870210065, 0.8128198216894904, 0.7694623668616943, 0.7803428261590156, 0.8416582498561722, 0.8614767944906763, 0.8457426 ...
